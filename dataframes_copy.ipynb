# %%
import pandas as pd
from unidecode import unidecode

# %%
formulaire = pd.read_csv("formulaire.csv")
formulaire.columns
# Out:
# Index(['Horodateur', 'Score', 'Nom de famille', 'Prénom', 'Genre',
#        'Date de naissance', 'Nationalité',
#        'Avez-vous redoublé le master ? Si oui, indiquez quelle année et quel niveau. ',
#        'Dans quelle université étiez-vous inscrits au M1 ? ',
#        'Dans quel parcours êtes-vous inscrits au M2 ?',
#        'Disposez vous ou avez-vous disposé d'un aménagement handicap pour le master (tiers-temps, autres...) ?',
#        'Si vous êtes inscrits (ou avez été inscrits) dans un autre établissement pendant le master, indiquez lequel :\n\nExemple :\nÉtudiant en M2 TAL Ingénierie Multilingue et à 42 en même temps.',
#        'Si vous avez obtenu un baccalauréat français, quelle était votre filière : ',
#        'Indiquez si cette licence appartient à l'une des mentions suivantes :',
# ...

# %%
prof = {"nom_prof": [
    "DUPONT",
    "BATTISTELLI",
    "ESHKOL-TARAVELLA", 
    "GROBOL",
    "KAHANE", 
    "MAGISTRY", 
    "NOUVEL", 
    "WANG", 
    "GENDROT", 
    "HERRERA", 
    "WANG", 
    "BOGLIOTTI", 
    "VILLEOING", 
    "STRICKER", 
    "DEHOUCK", 
    "JACOBSON", 
    "SAUVAGE", 
    "ZWEIGENBAUM", 
    "KOSMALA" , 
    "VALETTE", 
    "GABOR", 
    "LICHAO", 
    "JACQUEMARD",
    "ROULOIS",
    "MONNIN-TUILLIER",
    "AMSILI",
    "JOURDAIN", 
    "AOUINA", 
    "LECAILLIEZ",
    "AKSEN", 
    "GAUMET", 
    "GROUIN", 
    "KUBIK",
    "BONNAFOUS", 
    "ABROUGUI", 
    "PAROUBECK",
    "RAINERIE"],
        "prenom_prof": ["Yoann", "Delphine", "Iris", "Loïc", "Sylvain", "Pierre", "Damien", "Ilaine", "Cedric", "Santiago", "Xibin", "Caroline", "Florence", "Armand", "Mathieu", "Michel", "Eve", "Pierre", "Loulou", "Mathieu", "Kata", "Zhu","Florent", "Alexandre", "Chloé", "Pascal", "Louis", "Ons","Louis", "Hatice", "Sophie", "Cyril", "Karolina", "Marie-Paule", "Rim", "Patrick", "Sophie"],
        "etablissement": ["SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "SorbonneNouvelle", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco","Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Nanterre"],
		"genre" : [
      "Homme",
      "Femme",
      "Femme",
      "Autre", 
      "Homme", 
      "Homme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Homme", 
      "Homme",
      "Femme", 
      "Femme", 
      "Homme", 
      "Homme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Homme",
      "Homme",
      "Homme",
      "Femme",
      "Homme",
      "Homme", 
      "Femme", 
      "Homme",
      "Femme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Femme",
      "Femme",
      "Homme"],
		"cours": [
      ["PPE1", "PPE2", "Introduction a la fouille de textes"],
      ["Modelisation automatique pour l'analyse de textes","Annotations semantiques et applications en recherche d'information", "Ingenierie des connaissances", "Linguistique outillee et traitements statistiques"],
      ["Programmation et algorithmique 1", "Bases de donnees pour linguistes", "Enrichissement de corpus", "De la modelisation au traitement automatique des donnees linguistiques", "Ingenierie des connaissances", "Langages du web semantique"],
      ["Mathematiques pour le TAL", "Apprentissage automatique", "Arbres, graphes", "Interfaces pour le web"],
      ["Modelisation des langues"],
      ["PPE1", "PPE2"],
      ["Langages reguliers", "Statistiques textuelles", "Traitement statistique de corpus"],
      ["Gest. Info Multilinguisme", "Ecriture et multilinguisme"],
      ["Synthese de la parole", "CNN", "Phonetique physiologique et acoustique"],
      ["Corpus arbores et parsing"], 
      ["Recueil de données et statistiques"],
      ["Linguistique de la langue de signes"], 
      ["Morphologie"],
      ["NLP in english", "Langues vivantes etrangeres"], 
      ["Programmation et algorithmique 2"],
      ["Document structure"],
      ["Outils de traitement de corpus"], 
      ["Corpus paralleles et comparables"], 
      ["Anglais de specialite"],
      ["Semantique lexicale et textuelle", "Genres, textes et usages", "Semantique de textes multilangues"],
      ["Lexique et morphologie"], 
      ["Pratiques textuelles et traduction", "Traductologie"],
      ["Programmation objet"],
      ["Langages de script (python inalco)"],
      ["Extraction d'information"],
      ["Semantique computationnelle"], 
      ["Langages de script"], 
      ["Acquisition, modelisation/representation"],
      ["Programmation objet 1"],
      ["Langue de signes"], 
      ["Conduite de projet de traduction 1"],
      ["Fouille de textes 1"], 
      ["Outils de TAO 1"], 
      ["Traduction technique 1"], 
      ["Documents structures"],
      ["Calculabilite"],
      ["Large corpus linguistics"]
      
      
            ],
        "directeur_memoire_de" : [None,["Florian PHILIPPE"], None, ["Patricia AUGUSTYN", "Marie DELPORTE-LANDAT", "Florian PHILIPPE"], ["Ioana-Madalina SILAI", "Maria Paz BOTERO"], None, None, None, ["Lise BRISSET"], None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None ]
        
}

# df_prof = pd.DataFrame(prof)
# df_prof.to_csv("prof_try.csv", index=False)
for cle, value in prof.items():
    print(len(value))

for (i, a), (j, b) in zip(enumerate(prof['prenom_prof']), enumerate(prof['directeur_memoire_de'])):
    print(f"{i, a}, {j, b}")
# Out:
# 37
# 37
# 37
# 36
# 37
# 36
# (0, 'Yoann'), (0, None)
# (1, 'Delphine'), (1, ['Florian PHILIPPE'])
# (2, 'Iris'), (2, None)
# (3, 'Loïc'), (3, ['Patricia AUGUSTYN', 'Marie DELPORTE-LANDAT', 'Florian PHILIPPE'])
# (4, 'Sylvain'), (4, ['Ioana-Madalina SILAI', 'Maria Paz BOTERO'])
# (5, 'Pierre'), (5, None)
# (6, 'Damien'), (6, None)
# (7, 'Ilaine'), (7, None)
# (8, 'Cedric'), (8, ['Lise BRISSET'])
# (9, 'Santiago'), (9, None)
# (10, 'Xibin'), (10, None)
# (11, 'Caroline'), (11, None)
# (12, 'Florence'), (12, None)
# (13, 'Armand'), (13, None)
# (14, 'Mathieu'), (14, None)
# (15, 'Michel'), (15, None)
# (16, 'Eve'), (16, None)
# (17, 'Pierre'), (17, None)
# (18, 'Loulou'), (18, None)
# (19, 'Mathieu'), (19, None)
# (20, 'Kata'), (20, None)
# (21, 'Zhu'), (21, None)
# (22, 'Florent'), (22, None)
# (23, 'Alexandre'), (23, None)
# (24, 'Chloé'), (24, None)
# (25, 'Pascal'), (25, None)
# (26, 'Louis'), (26, None)
# (27, 'Ons'), (27, None)
# (28, 'Louis'), (28, None)
# ...

# %%
def normalisation_m1_s1(list_courses):

    ### On sépare les cours, on enlève les diacritiques et on met tout en minuscule
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    ### On renomme ou on uniformise les cours pour une meilleure correspondance
    dico_correspondance = {
        "ppe 1" : "ppe1",
        "langages regulieres" : "Langages reguliers",
        "gest. info multilinguisme (gim)" : "gest. info multilinguisme",
        "programmation et algorithmique 1 (python nanterre)" : "programmation et algorithmique 1",
        "modalisation automatique pour l'analyse de textes" : "modelisation automatique pour l'analyse de textes",
        "programmation objet" : "programmation objet 1",
        "pratiques textuelles" : "pratiques textuelles et traduction",
        "langues vivantes" : "langues vivantes etrangeres",
    }

    cleaned_courses = []
    for course in list_courses:
        if course != "linguistique au choix" and course != "principes de bases de données":
            if course in dico_correspondance.keys():
                cleaned_courses.append(dico_correspondance[course])
            else:
                cleaned_courses.append(course)

    print(cleaned_courses)

    return cleaned_courses

# %%
### POUR LES COURS OBLIGATOIRES DU M1 S1
formulaire["normalised_m1_s1_courses"] = formulaire["Quels cours avez-vous suivis au premier semestre du M1 ?"].apply(normalisation_m1_s1)
# Out:
# ['Langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de scripts (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ...

# %%
def normalisation_m1_s1_optional(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    dico_correspondance = {
        "recueil de donnees et statistiques (nanterre)" : "recueil de données et statistiques",
        "lexique et morphologie (inalco)" : "lexique et morphologie"
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)

    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m1_s1_optionnal"] = formulaire["Quelles ont été vos options de linguistique au premier semestre du M1 ?\nSéparer les cours par des virgules. "].apply(normalisation_m1_s1_optional)

# %%
def normalisation_m1_s1_extra(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    dico_correspondance = {
        "recueil de donnees et statistiques (nanterre)" : "recueil de données et statistiques",
        "lexique et morphologie (inalco)" : "lexique et morphologie"
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)
    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m1_s1_extra"] = formulaire["Avons-nous oublié quelque cours au premier semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].apply(normalisation_m1_s1_extra)

# %%
def normalisation_m1_s2(list_courses):

    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    dico_correspondance = {
        "anglais de specialite" : "anglais de specialite 2"
    }

    

    return list_courses

# %%
formulaire["normalised_m1_s2_courses"] = formulaire["Quels cours avez-vous suivis au second semestre du M1 ?"].apply(normalisation_m1_s2)

# %%
prof = {"nom_prof": ["DUPONT", "BATTISTELLI", "ESHKOL-TARAVELLA", "GROBOL", "KAHANE", "MAGISTRY", "NOUVEL", "WANG", "GENDROT", "HERRERA", "WANG", "BOGLIOTTI", "VILLEOING", "STRICKER", "DEHOUCK", "JACOBSON", "SAUVAGE", "ZWEIGENBAUM", "KOSMALA" , "VALETTE", "GABOR", "LICHAO", "JACQUEMARD", "ROULOIS", "MONNIN-TUILLIER", "AMSILI", "JOURDAIN", "AOUINA", "LECAILLIEZ", "AKSEN", "GAUMET", "GROUIN", "KUBIK", "BONNAFOUS", "ABROUGUI", "PAROUBECK"],
        "prenom_prof": ["Yoann", "Delphine", "Iris", "Loïc", "Sylvain", "Pierre", "Damien", "Ilaine", "Cedric", "Santiago", "Xibin", "Caroline", "Florence", "Armand", "Mathieu", "Michel", "Eve", "Pierre", "Loulou", "Mathieu", "Kata", "Zhu","Florent", "Alexandre", "Chloé", "Pascal", "Louis", "Ons","Louis", "Hatice", "Sophie", "Cyril", "Karolina", "Marie-Paule", "Rim", "Patrick"],
        "etablissement": ["SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "SorbonneNouvelle", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco","Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco"],
		"genre" : [],
		"cours": [[],],
        "directeur_memoire_de" : [],}


# Faire un Id avec Lastname + Firstname

# %%
#===== Initialisation du dictionnaire des cours =====#
cours = {"nom_cours": [],
         "professeur": [],
         "etablissement": [],
         "annee": [],
         "horaires": [],
         "evaluation": [],
         "list_eleves": []}

# %%
#===== Remplissage du dictionnaire des cours =====#

courses_m1_s1 = formulaire["Quels cours avez-vous suivis au premier semestre du M1 ?"].to_list()
courses_m1_s2 = formulaire["Quels cours avez-vous suivis au second semestre du M1 ?"].to_list()
courses_m2_s1 = formulaire["Quels cours avez-vous suivis au premier semestre du M2 ?"].to_list()

mandatory_courses = courses_m1_s1 + courses_m1_s2 + courses_m2_s1
mandatory_courses = [value for sublist in mandatory_courses for value in sublist.split(", ")]
mandatory_courses = list(set(mandatory_courses))

optional_courses_m1_s1 = formulaire["Quelles ont été vos options de linguistique au premier semestre du M1 ?\nSéparer les cours par des virgules. "].dropna().to_list()
optional_courses_m1_s1 = optional_courses_m1_s1 + formulaire["Avons-nous oublié quelque cours au premier semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].dropna().to_list()
optional_courses_m1_s2 = formulaire["Avons-nous oublié quelque cours au second semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].dropna().to_list()
optional_courses_m2_s1 = formulaire["Avons-nous oublié quelque cours au premier semestre du M2 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].dropna().to_list()
optional_courses = optional_courses_m1_s1 + optional_courses_m1_s2 + optional_courses_m2_s1
optional_courses = [value for sublist in optional_courses for value in sublist.split(", ")]
optional_courses = list(set(optional_courses))

cours = mandatory_courses + optional_courses
cours = list(set(cours))
cours

# %%
dico_stage = {"nom_stage": [],
              "nom_etudiant": [],
              "type_organisme": [],
              "nom_organisme": [],
              "duree": [],
              "sujet": [],
              "tuteur": [],
              "note": [],
              "type_contrat": [],
              }

# %%
dico_parcours = {"nom_parcours": ["M1_Nanterre_23-24", "M1_Inalco_23-24", "M1_Sorbonne_23-24", "M2_RD_Nanterre_24-25", "M2_RD_Inalco_24-25", "M2_RD_Sorbonne_24-25", "M2_Alterance_24-25", "M2_IM_24-25", "M2_TetraDom_24-25"],
                 "etablissement": ["Nanterre", "Inalco", "SorbonneNouvelle", "Nanterre", "Inalco", "SorbonneNouvelle", "Nanterre", "Inalco", "Inalco"],
                 "liste_eleves" : [[]],
                 "annee" : ["2023-2024", "2023-2024", "2023-2024", "2024-2025", "2024-2025", "2024-2025", "2024-2025", "2024-2025", "2024-2025"],}

# %%
eleves = {}

df_eleves = pd.DataFrame(eleves)

df_eleves['id'] = formulaire['Prénom'].str.strip().str.replace(' ', '_') + '_' + formulaire['Nom de famille'].str.replace('-', '_')
df_eleves['prenom'] = formulaire['Prénom']
df_eleves['nom'] = formulaire['Nom de famille']
df_eleves['genre'] = formulaire['Genre']
df_eleves['date_naissance'] = formulaire['Date de naissance']
df_eleves['nationalite'] = formulaire['Nationalité']
df_eleves['redoublement'] = formulaire['Avez-vous redoublé le master ? Si oui, indiquez quelle année et quel niveau. '].str.lower()
df_eleves['inscription_M1'] = formulaire['Dans quelle université étiez-vous inscrits au M1 ? ']
df_eleves['parcours_M2'] = formulaire['Dans quel parcours êtes-vous inscrits au M2 ?']
df_eleves['tiers_temps'] = formulaire['Disposez vous ou avez-vous disposé d\'un aménagement handicap pour le master (tiers-temps, autres...) ?'].str.lower()
df_eleves['inscription_simultanee'] = formulaire['Si vous êtes inscrits (ou avez été inscrits) dans un autre établissement pendant le master, indiquez lequel :\n\nExemple :\nÉtudiant en M2 TAL Ingénierie Multilingue et à 42 en même temps.']
df_eleves['BAC'] = formulaire['Si vous avez obtenu un baccalauréat français, quelle était votre filière : ']
df_eleves['licence'] = formulaire['Avez-vous déjà une licence ?\nSi oui, veuillez indiquer son nom original (langue d\'origine) au format :\nNOM, UNIVERSITÉ\n\nExemple:\nLicence en biologie, Université Paris Saclay']
df_eleves['mention_licence'] = formulaire['Indiquez si cette licence appartient à l\'une des mentions suivantes :']
df_eleves['autre_master'] = formulaire['Avez-vous déjà un master ?\nSi oui, veuillez indiquer son nom original (langue d\'origine) au format :\nNOM, UNIVERSITÉ\n\nExemple:\nMaster Linguistique Anglaise, Université Sorbonne Nouvelle']
df_eleves['mention_master_precedent'] = formulaire['Indiquez si ce master appartient à une des mentions suivantes : ']
df_eleves['autres_diplomes'] = formulaire['Si vous avez obtenu un autre type de diplôme (hors licence et master), indiquez son nom original (langue d\'origine) au format :\nNOM, ÉTABLISSEMENT\n\nExemple:\nBTS en communication, Lycée Paul Eluard, Saint-Denis']
df_eleves['job_etudiant'] = formulaire['Si vous travaillez (ou avez travaillé) pendant le master, indiquez sur quel poste (hors stage TAL) :\n\nExemple :\nActuellement employé polyvalent à Décathlon.']
df_eleves['profession_avant'] = formulaire['Si vous avez exercé une activité professionnelle de longue durée avant le master (reconversion, reprise d\'études ou autres), indiquez laquelle :\n\nExemple:\nProfesseure à l\'alliance française de Bogotá. ']

# df_eleves['cours_m1_s1'] = formulaire[]
# df_eleves['cours_m1_s2'] = formulaire[]
# df_eleves['cours_m2_s1'] = formulaire[]

df_eleves['prefere_cours'] = formulaire['Si vous deviez élire le meilleur cours de tout le master, lequel choisiriez-vous ? ']
df_eleves['prefere_sujet'] = formulaire['Quels sont vos sujets préférés en cours ? ']
df_eleves['prefere_evaluation'] = formulaire['Quelle(s) modalité(s) d\'évaluation préférez-vous ?']
df_eleves['suggestion_maquette'] = formulaire['Quel aspect aimeriez-vous voir plus mis en avant pendant le master ? Ça peut être un sujet en particulier, des compétences spécifiques ou autre.']
df_eleves['ennemi_jure'] = formulaire['Qui est votre ennemi juré dans le master parmi les élèves (soyez pas sérieux c\'est pour rigoler) ? ']
df_eleves['sante_avant'] = formulaire['Sur combien notez-vous votre santé mentale avant le master ?']
df_eleves['sante_apres'] = formulaire['Sur combien notez-vous votre santé mentale après le master ? ']
df_eleves['quota_pleure'] = formulaire['À quelle fréquence pleurez-vous à cause du master ?\nex: x/mois ou x/semaine ou x/jour ...']
df_eleves['heures_sommeil'] = formulaire['Combien d\'heures par nuit dormez-vous en moyenne ?']
df_eleves['difficulte_M1'] = formulaire['Sur combien notez-vous la difficulté du M1 ?']
df_eleves['difficulte_alternance'] = formulaire['Sur combien notez-vous la difficulté du M2 parcours Alternance ?']
df_eleves['difficulte_IM'] = formulaire['Sur combien notez-vous la difficulté du M2 parcours Ingénierie Multilingue ?']
df_eleves['difficulte_RD'] = formulaire['Sur combien notez-vous la difficulté du M2 parcours Recherche et Développement ?']
df_eleves['difficulte_tetradom'] = formulaire['Sur combien notez-vous la difficulté du M2 parcours Technologies de la Traduction et Traitement des Données Multilingues ?']
df_eleves['jeter_linux'] = formulaire['Pour les adeptes de Linux, voulez-vous régulièrement jeter votre ordinateur par la fenêtre ?']
df_eleves['jeter_mac'] = formulaire['Pour les adeptes de Mac, voulez-vous régulièrement jeter votre ordinateur par la fenêtre ?']
df_eleves['admin_nanterre'] = formulaire['Pour les étudiants de Nanterre, sur combien notez-vous l\'efficacité de votre administration ?']
df_eleves['admin_sorbonne'] = formulaire['Pour les étudiants de la Sorbonne-Nouvelle, sur combien notez-vous l\'efficacité de votre administration ?']
df_eleves['admin_inalco'] = formulaire['Pour les étudiants de l\'INALCO, sur combien notez-vous l\'efficacité de votre administration ?']
df_eleves['conseil_eleve'] = formulaire['Quel conseil donneriez-vous aux futurs élèves pour survivre au master TAL ?']
df_eleves['recommandation'] = formulaire['À qui recommanderiez-vous le master TAL ?']
df_eleves['conseil_prof'] = formulaire['Quel conseil donneriez-vous aux professeurs du master TAL ? ']
print(df_eleves['id'])

df_eleves.to_csv("dataframe_eleves.csv", index=False)
# Out:
# 0             Pauline_DÉGEZ
# 1         Perrine_QUENNEHEN
# 2             Ashley_RATIER
# 3          Valentine_FLEITH
# 4     Débora_VAN_DEN_ZANDE
# 5         Patricia_AUGUSTYN
# 6      Ioana_Madalina_SILAI
# 7     Marie_DELPORTE_LANDAT
# 8          Florian_PHILIPPE
# 9             Lydia_BELHOUL
# 10              Liza_FRETEL
# 11            Lucile_BESSAC
# 12           Kehina_MANSERI
# 13         Maria_Paz_BOTERO
# 14       Alix_SIRVEN_VIÉNOT
# 15          Solomiia_ KOROL
# 16                 Yu_ZHANG
# 17            Manon_GROUVÈS
# 18                Keming_YI
# 19              Xinlei_CHEN
# 20             Lise_BRISSET
# 21            Nicolas_NGAUV
# 22         Melissa_MAHMOUDI
# 23             Yuntian_SHEN
# Name: id, dtype: object

# %%
stage = {}

df_stage = pd.DataFrame(stage)
df_stage['id'] = f"{df_eleves['id']}_{formulaire['Quel était le nom de l\'organisme d\'accueil ? ']}"

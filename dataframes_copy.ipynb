# %%
import pandas as pd
from unidecode import unidecode
import json

# %% [markdown]
# # ON IMPORTE LE FORMULAIRE

# %%
formulaire = pd.read_csv("formulaire.csv")
formulaire.columns
# Out:
# Index(['Horodateur', 'Score', 'Nom de famille', 'Prénom', 'Genre',
#        'Date de naissance', 'Nationalité',
#        'Avez-vous redoublé le master ? Si oui, indiquez quelle année et quel niveau. ',
#        'Dans quelle université étiez-vous inscrits au M1 ? ',
#        'Dans quel parcours êtes-vous inscrits au M2 ?',
#        'Disposez vous ou avez-vous disposé d'un aménagement handicap pour le master (tiers-temps, autres...) ?',
#        'Si vous êtes inscrits (ou avez été inscrits) dans un autre établissement pendant le master, indiquez lequel :\n\nExemple :\nÉtudiant en M2 TAL Ingénierie Multilingue et à 42 en même temps.',
#        'Si vous avez obtenu un baccalauréat français, quelle était votre filière : ',
#        'Indiquez si cette licence appartient à l'une des mentions suivantes :',
#        'Avez-vous déjà un master ?\nSi oui, veuillez indiquer son nom original (langue d'origine) au format :\nNOM, UNIVERSITÉ\n\nExemple:\nMaster Linguistique Anglaise, Université Sorbonne Nouvelle',
#        'Si vous travaillez (ou avez travaillé) pendant le master, indiquez sur quel poste (hors stage TAL) :\n\nExemple :\nActuellement employé polyvalent à Décathlon.',
#        'Si vous avez exercé une activité professionnelle de longue durée avant le master (reconversion, reprise d'études ou autres), indiquez laquelle :\n\nExemple:\nProfesseure à l'alliance française de Bogotá. ',
#        'Avez-vous eu un premier stage en NLP pendant le M1 ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?1',
#        'Quel était le nom de l'organisme d'accueil ?1',
#        'Quelle était la durée du stage ?1', 'Quel était le sujet du stage ?1',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :1',
#        'Avez-vous eu un second stage en NLP pendant le M1 ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?2',
#        'Quel était le nom de l'organisme d'accueil ?2 ',
#        'Quelle était la durée du stage ?2', 'Quel était le sujet du stage ?2',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :2',
#        'Avez-vous eu un stage en NLP pendant le M2 (hors celui du second semestre à venir) ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?3',
#        'Quel était le nom de l'organisme d'accueil ?3 ',
#        'Quelle était la durée du stage ?3', 'Quel était le sujet du stage ?3',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :3',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M1 numéro 1',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M1 numéro 2',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M2',
#        'Pour les M2 en parcours recherche, IM ou TETRADOM, avez-vous déjà trouvé un stage ?',
#        'Si oui, serez-vous en entreprise, laboratoire ou autre ?',
#        'Quel est le nom de l'organisme d'accueil ?',
#        'Quelle sera la durée du stage ?',
#        'Pour les M2 en parcours recherche, le sujet de votre mémoire est-il lié à votre stage de M2 ?',
#        'Pour les M2 en parcours recherche, si vous le connaissez déjà, quel est le sujet de votre mémoire ?',
#        'Pour les M2 en parcours recherche, si vous les connaissez déjà, qui sont vos directeurs de mémoire ? ',
#        'Pour les M2 en parcours alternance, avez-vous trouvé une alternance, un stage, ou autre ?',
#        'Pour les M2 en parcours alternance ayant trouvé une alternance, dans quel organisme êtes-vous ?',
#        'Quelle sont vos missions ?',
#        'Pour les M2 en parcours alternance ayant trouvé un stage, dans quel organisme êtes-vous/serez-vous ?',
#        'Quelle est/sera la durée du stage ?',
#        'Quelles sont/seront vos missions ?',
#        'Quels cours avez-vous suivis au premier semestre du M1 ?',
#        'Quelles ont été vos options de linguistique au premier semestre du M1 ?\nSéparer les cours par des virgules. ',
#        'Avons-nous oublié quelque cours au premier semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels cours avez-vous suivis au second semestre du M1 ?',
#        'Avons-nous oublié quelque cours au second semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels cours avez-vous suivis au premier semestre du M2 ?',
#        'Avons-nous oublié quelque cours au premier semestre du M2 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels sont vos sujets préférés en cours ? ',
#        'Quelle(s) modalité(s) d'évaluation préférez-vous ?',
#        'Quel aspect aimeriez-vous voir plus mis en avant pendant le master ? Ça peut être un sujet en particulier, des compétences spécifiques ou autre.',
#        'Qui est votre ennemi juré dans le master parmi les élèves (soyez pas sérieux c'est pour rigoler) ? ',
#        'Sur combien notez-vous votre santé mentale avant le master ?',
#        'Sur combien notez-vous votre santé mentale après le master ? ',
#        'À quelle fréquence pleurez-vous à cause du master ?\nex: x/mois ou x/semaine ou x/jour ...',
#        'Combien d'heures par nuit dormez-vous en moyenne ?',
#        'Sur combien notez-vous la difficulté du M1 ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Recherche et Développement ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Alternance ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Ingénierie Multilingue ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Technologies de la Traduction et Traitement des Données Multilingues ?',
#        'Pour les adeptes de Linux, voulez-vous régulièrement jeter votre ordinateur par la fenêtre ?',
#        'Pour les adeptes de Mac, voulez-vous régulièrement jeter votre ordinateur par la fenêtre ?',
#        'Si vous deviez élire le meilleur cours de tout le master, lequel choisiriez-vous ? ',
#        'Pour les étudiants de Nanterre, sur combien notez-vous l'efficacité de votre administration ?',
#        'Pour les étudiants de la Sorbonne-Nouvelle, sur combien notez-vous l'efficacité de votre administration ?',
#        'Pour les étudiants de l'INALCO, sur combien notez-vous l'efficacité de votre administration ?',
#        'Quel conseil donneriez-vous aux futurs élèves pour survivre au master TAL ?',
#        'À qui recommanderiez-vous le master TAL ?',
#        'Quel conseil donneriez-vous aux professeurs du master TAL ? ',
#        'Avez-vous eu une expérience professionnelle en lien avec le master pendant le M1 ou le M2 ? (hors alternance et stage)',
#        'Quel était le nom de l'organisme employeur ?',
#        'Quel était le type de contrat ? ',
#        'Quelles étaient vos missions lors de cette expérience ?\n',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu Master in social studies, Cambridge University à la question précédente.\n\nVeuillez ici répondre :\nMaster en Sciences Sociales, Université de Cambridge',
#        'Indiquez si ce master appartient à une des mentions suivantes : ',
#        'Si vous avez obtenu un autre type de diplôme (hors licence et master), indiquez son nom original (langue d'origine) au format :\nNOM, ÉTABLISSEMENT\n\nExemple:\nBTS en communication, Lycée Paul Eluard, Saint-Denis',
#        'Avez-vous déjà une licence ?\nSi oui, veuillez indiquer son nom original (langue d'origine) au format :\nNOM, UNIVERSITÉ\n\nExemple:\nLicence en biologie, Université Paris Saclay',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu Bachelor in social studies, Cambridge University à la question précédente.\n\nVeuillez ici répondre :\nLicence en Sciences Sociales, Université de Cambridge',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu NVQ hairstylist, Freddie Mercury High School, Cambridge à la question précédente.\n\nVeuillez ici répondre :\nCAP coiffure, Lycée Freddie Mercury, Cambridge',
#        'Colonne 84'],
#       dtype='object')

# %% [markdown]
# # CRÉATION DU DICO ET DE LA DATAFRAME PROF !

# %%
dico_prof = {"nom_prof": [
    "DUPONT",
    "BATTISTELLI",
    "ESHKOL-TARAVELLA", 
    "GROBOL",
    "KAHANE", 
    "MAGISTRY", 
    "NOUVEL", 
    "WANG", 
    "GENDROT", 
    "HERRERA", 
    "WANG", 
    "BOGLIOTTI", 
    "VILLEOING", 
    "STRICKER", 
    "DEHOUCK", 
    "JACOBSON", 
    "SAUVAGE", 
    "ZWEIGENBAUM", 
    "KOSMALA" , 
    "VALETTE", 
    "GABOR", 
    "LICHAO", 
    "JACQUEMARD",
    "ROULOIS",
    "MONNIN-TUILLIER",
    "AMSILI",
    "JOURDAIN", 
    "AOUINA", 
    "LECAILLIEZ",
    "AKSEN", 
    "GAUMET", 
    "GROUIN", 
    "KUBIK",
    "BONNAFOUS", 
    "ABROUGUI", 
    "PAROUBECK",
    "RAINERIE", 
    "SEMMAR",
    "LASON",
    "NUT",
    "CARCENAC",
    "LEE",
    "HUP",
    "COSTA",
    "CORI",
    "LEHMANN",
    "PICCOLI"
    ],
        "prenom_prof": ["Yoann", "Delphine", "Iris", "Loïc", "Sylvain", "Pierre", "Damien", "Ilaine", "Cedric", "Santiago", "Xibin", "Caroline", "Florence", "Armand", "Mathieu", "Michel", "Eve", "Pierre", "Loulou", "Mathieu", "Kata", "Zhu","Florent", "Alexandre", "Chloé", "Pascal", "Louis", "Ons","Louis", "Hatice", "Sophie", "Cyril", "Karolina", "Marie-Paule", "Rim", "Patrick", "Sophie", "Nasredine", "Natalia", "Suppya", "Benoît", "Kyung", "Christophe", "James", "Marcel", "Sabine", "Vanessa"],
        "etablissement": ["SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "SorbonneNouvelle", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco","Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Nanterre", "SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre"],
		"genre" : [
      "Homme",
      "Femme",
      "Femme",
      "Autre", 
      "Homme", 
      "Homme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Homme", 
      "Homme",
      "Femme", 
      "Femme", 
      "Homme", 
      "Homme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Homme",
      "Homme",
      "Homme",
      "Femme",
      "Homme",
      "Homme", 
      "Femme", 
      "Homme",
      "Femme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Femme",
      "Femme",
      "Homme",
      "Femme",
        "Homme",
        "Femme",
      "Femme",
      "Homme",
      "Femme",
      "Homme",
      "Homme",
      "Homme",
      "Femme",
      "Femme",
      ],
		"cours": [
      ["PPE1", "PPE2", "Introduction a la fouille de textes"],
      ["Modelisation automatique pour l'analyse de textes","Annotations semantiques et applications en recherche d'information", "Ingenierie des connaissances", "Linguistique outillee et traitements statistiques"],
      ["Programmation et algorithmique 1", "Bases de donnees pour linguistes", "Enrichissement de corpus", "De la modelisation au traitement automatique des donnees linguistiques", "Ingenierie des connaissances", "Langages du web semantique", "seminaire: tal et linguistique de corpus"],
      ["Mathematiques pour le TAL", "Apprentissage automatique", "Arbres graphes", "Interfaces pour le web"],
      ["Modelisation des langues"],
      ["PPE1", "PPE2"],
      ["Langages reguliers", "Statistiques textuelles", "Traitement statistique de corpus"],
      ["Gest. Info Multilinguisme", "Ecriture et multilinguisme"],
      ["Synthese de la parole", "CNN", "Phonetique physiologique et acoustique"],
      ["Corpus arbores et parsing"], 
      ["Recueil de donnees et statistiques"],
      ["Linguistique de la lsf"], 
      ["Morphologie"],
      ["NLP in english", "Langues vivantes etrangeres"], 
      ["Programmation et algorithmique 2"],
      ["Document structure"],
      ["Outils de traitement de corpus"], 
      ["Corpus paralleles et comparables"], 
      ["Anglais de specialite 2"],
      ["Semantique lexicale et textuelle", "Genres textes et usages", "Semantique des textes multilingues 1"],
      ["Lexique et morphologie"], 
      ["Pratiques textuelles et traduction", "Traductologie 1"],
      ["Programmation objet 1", "Programmation objet 2"],
      ["Langages de script (python inalco)", "langages de script (roulois)"],
      ["Extraction d'informations"],
      ["Semantique computationnelle"], 
      ["Langages de script (jourdain)"], 
      ["Acquisition modelisation/representation"],
      ["programmation orientee objet 1"],
      ["Langue des signes"], 
      ["Conduite de projet de traduction 1"],
      ["Fouille de textes 1"], 
      ["Outils de TAO 1"], 
      ["Traduction technique 1"], 
      ["Documents structures"],
      ["Calculabilite"],
      ["Large corpus linguistics"],
      ["Traduction automatique et assistee"],
      ["Polonais"],
      ["Khmer"],
      ["Gestion de projets"],
      ["Coreen"],
      ["Anglais pro"],
      ["sociolinguistique"],
      ["methodologie de la recherche"],
      ["changements linguistiques"],
      ["changements linguistiques"],
    #   ["actualite dans le monde anglophone"]

      
      
            ],
        "directeur_memoire_de" : [None,["Florian PHILIPPE"], None, ["Patricia AUGUSTYN", "Marie DELPORTE-LANDAT", "Florian PHILIPPE"], ["Ioana-Madalina SILAI", "Maria Paz BOTERO"], None, None, None, ["Lise BRISSET"], None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
        
}

# print(len(prof["nom_prof"]), len(prof["prenom_prof"]), len(prof["etablissement"]), len(prof["genre"]), len(prof["cours"]), len(prof["directeur_memoire_de"]))

df_prof = pd.DataFrame(dico_prof)
df_prof.to_csv("df_prof.csv", index=False)
# for cle, value in prof.items():
#     print(len(value))

# for (i, a), (j, b) in zip(enumerate(prof['prenom_prof']), enumerate(prof['genre'])):
#     print(f"{i, a}, {j, b}")

# %% [markdown]
# # ON NORMALISE LES COLONNES AVEC LES COURS SUIVIS !!! DONC ON CRÉER DES NOUVELLES COLONNES AVEC LES COURS SUIVIS PAR TOUT LE MONDRE POUR CHAQUE SEMESTRE ET TYPE DE COURS !
# # LE NOM DES COURS NORMALISÉS CORRESPONDENT AUX NOMS DANS LA DF PROFS !

# %%
def normalisation_m1_s1(list_courses):

    ### On sépare les cours, on enlève les diacritiques et on met tout en minuscule
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    ### On renomme ou on uniformise les cours pour une meilleure correspondance
    dico_correspondance = {
        "ppe 1" : "ppe1",
        "langages regulieres" : "langages reguliers",
        "Langages reguliers" : "langages reguliers",
        "gest. info multilinguisme (gim)" : "gest. info multilinguisme",
        "programmation et algorithmique 1 (python nanterre)" : "programmation et algorithmique 1",
        "modalisation automatique pour l'analyse de textes" : "modelisation automatique pour l'analyse de textes",
        "programmation objet" : "programmation objet 1",
        "pratiques textuelles" : "pratiques textuelles et traduction",
        "langues vivantes" : "langues vivantes etrangeres",
        "base de donnees pour linguistes" : "bases de donnees pour linguistes", 
        "langages de scripts (python inalco)" : "langages de script (python inalco)",
    }

    cleaned_courses = []
    for course in list_courses:
        if course != "linguistique au choix" and course != "principes de bases de données":
            if course in dico_correspondance.keys():
                cleaned_courses.append(dico_correspondance[course])
            else:
                cleaned_courses.append(course)

    print(cleaned_courses)

    return cleaned_courses

# %%
### POUR LES COURS OBLIGATOIRES DU M1 S1
formulaire["normalised_m1_s1_courses"] = formulaire["Quels cours avez-vous suivis au premier semestre du M1 ?"].apply(normalisation_m1_s1)
# Out:
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de script (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'lexique et morphologie']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'corpus arbores et parsing', 'langages de script (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'principes de bases de donnees', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de script (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'principes de bases de donnees', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'lexique et morphologie']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'lexique et morphologie']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de script (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'principes de bases de donnees', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de script (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de script (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'langages de script (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'principes de bases de donnees']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'bases de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']

# %%
def normalisation_m1_s1_optional(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    dico_correspondance = {
        "recueil de donnees et statistiques (nanterre)" : "recueil de donnees et statistiques",
        "lexique et morphologie (inalco)" : "lexique et morphologie",
        "nlp in english" : "langues vivantes etrangeres",
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)

    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m1_s1_optionnal"] = formulaire["Quelles ont été vos options de linguistique au premier semestre du M1 ?\nSéparer les cours par des virgules. "].apply(normalisation_m1_s1_optional)
# Out:
# ['recueil de donnees et statistiques', 'morphologie']
# []
# ['morphologie', 'recueil de donnees et statistiques']
# ['recueil de donnees et statistiques', 'morphologie']
# ['morphologie', 'recueil de donnees et statistiques']
# ['sociolinguistique', 'phonetique physiologique et acoustique']
# ['large corpus linguistics', 'langues vivantes etrangeres']
# ['recueil de donnees et statistiques', 'phonetique physiologique et acoustique']
# ['morphologie', 'recueil de donnees et statistiques']
# ['morphologie', 'recueil de donnees et statistiques']
# []
# ['langues vivantes etrangeres']
# ['recueil de donnees et statistiques', 'linguistique de la lsf']
# ['recueil de donnees et statistiques', 'morphologie']
# ['morphologie', 'changements linguistiques']
# []
# ['morphologie']
# ['recueil de donnees et statistiques', 'lexique et morphologie']
# []
# []
# ['sens multiple', 'phonetique physiologique et acoustique']
# []
# ['morphologie', 'redaction professionnelle']
# []
# ['morphologie', 'statistiques']

# %%
def normalisation_m1_s1_extra(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    dico_correspondance = {
        "recueil de donnees et statistiques (nanterre)" : "recueil de données et statistiques",
        "lexique et morphologie (inalco)" : "lexique et morphologie"
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)
    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m1_s1_extra"] = formulaire["Avons-nous oublié quelque cours au premier semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].apply(normalisation_m1_s1_extra)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
def normalisation_m1_s2(list_courses):

    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    dico_correspondance = {
        "anglais de specialite" : "anglais de specialite 2",
        "programmation objet" : "programmation objet 2",
        "outil de traitement de corpus" : "outils de traitement de corpus"
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)
    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m1_s2_courses"] = formulaire["Quels cours avez-vous suivis au second semestre du M1 ?"].apply(normalisation_m1_s2)
# Out:
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2']
# ['corpus paralleles et comparables', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', "extraction d'informations", 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'ppe2', 'programmation et algorithmique 2', 'anglais de specialite 2', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'anglais de specialite 2', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'anglais de specialite 2', 'traduction automatique et assistee', 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']

# %%
def normalisation_m1_s2_extra(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    print(list_courses)
    return list_courses

# %%
formulaire["normalised_m1_s2_extra"] = formulaire["Avons-nous oublié quelque cours au second semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].apply(normalisation_m1_s2_extra)
# Out:
# []
# []
# []
# []
# ['coreen']
# ['polonais']
# []
# []
# ['nlp in english']
# []
# []
# []
# []
# []
# ['nlp in english']
# []
# []
# ['khmer']
# []
# []
# []
# []
# []
# []
# []

# %%
def normalisation_m2_s1(list_courses):
    
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    dico_correspondance = {
        "annotation semantiques et applications en recherche d'information (nanterre)" : "annotations semantiques et applications en recherche d'information",
        "ingenierie de connaissances(nanterre)" : "ingenierie des connaissances", 
        "de la modelisation au traitement automatique des donnees linguistiques (nanterre)" : "de la modelisation au traitement automatique des donnees linguistiques",
        "seminaire: tal et linguistique de corpus (nanterre)" : "seminaire: tal et linguistique de corpus",
        "apprentissage automatique (nanterre)" : "apprentissage automatique",
        "arbres graphes (nanterre)" : "arbres graphes",
        "interfaces pour le web (nanterre)" : "interfaces pour le web",
        "modelisation des langues (nanterre)" : "modelisation des langues",
        "langages du web semantique (nanterre)" : "langages du web semantique",
        "linguistique outille et traitements statistiques (nanterre)" : "linguistique outillee et traitements statistiques",
        "gestion de projets (nanterre)" : "gestion de projets",
        "traitement automatique de corpus (inalco)" : "traitement statistique de corpus",
        "genres textes et usages (inalco)" : "genres textes et usages",
        "semantique des textes multilingues 1 (inalco)" : "semantique des textes multilingues 1",
        "lexicologie terminologie et dictionnairique (inalco)" : "lexicologie terminologie et dictionnairique",
        "acquisition modelisation/representation (inalco)" : "acquisition modelisation/representation",
        "langages de script (inalco) (avec m.jourdain louis)" : "langages de script (jourdain)",
        "langages de script (inalco) (avec m. roulois alexandre)" : "langages de script (roulois)",
        "documents structures (inalco)" : "documents structures",
        "cnn (sorbonne nouvelle)" : "cnn",
        "calculabilite (inalco)" : "calculabilite",
        "methodologie de la recherche (nanterre)" : "methodologie de la recherche",
        "conduite de projet de traduction (inalco)" : "conduite de projet de traduction 1",
        "programmation objet 1 (inalco)" : "programmation orientee objet 1",
        "semantique computationnelle (sorbonne nouvelle)" : "semantique computationnelle",
        "anglais (pro) (nanterre)" : "anglais pro",
        "outils de tao 1 (inalco)" : "outils de tao 1",
        "traductologie 1 (inalco)" : "traductologie 1",
        "ecriture et multilinguisme (inalco)" : "ecriture et multilinguisme",
        'traduction technique 1 (inalco)': 'traduction technique 1',
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)

    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m2_s1_courses"] = formulaire['Quels cours avez-vous suivis au premier semestre du M2 ?'].apply(normalisation_m2_s1)
# Out:
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'documents structures', 'calculabilite', 'programmation orientee objet 1', 'cnn']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'interfaces pour le web', 'arbres graphes', 'genres textes et usages', 'semantique des textes multilingues 1']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'arbres graphes', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'documents structures', 'programmation orientee objet 1', 'cnn', 'semantique computationnelle']
# ['apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'arbres graphes', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'programmation orientee objet 1', 'cnn', 'mooc']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'interfaces pour le web', 'arbres graphes', 'traitement statistique de corpus', 'genres textes et usages', 'langages de script (jourdain)', 'programmation orientee objet 1', 'semantique computationnelle']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'conduite de projet de traduction 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (roulois)', 'outils de tao 1', 'traduction technique 1', 'documents structures', 'traductologie 1', 'ecriture et multilinguisme', 'calculabilite', 'programmation orientee objet 1']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'arbres graphes', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'cnn', 'semantique computationnelle', 'langue des signes']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'arbres graphes', 'anglais pro', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'programmation orientee objet 1', 'semantique computationnelle']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'arbres graphes', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'cnn', 'semantique computationnelle']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'interfaces pour le web', 'arbres graphes', 'anglais pro', 'traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'programmation orientee objet 1', 'semantique computationnelle']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'conduite de projet de traduction 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'documents structures', 'calculabilite', 'programmation orientee objet 1', 'cnn']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'documents structures', 'calculabilite', 'programmation orientee objet 1', 'cnn']
# ['apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'langages du web semantique', 'interfaces pour le web', 'arbres graphes', 'cnn', 'semantique computationnelle']
# ['genres textes et usages', 'semantique des textes multilingues 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'documents structures', 'calculabilite', 'programmation orientee objet 1', 'cnn']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'conduite de projet de traduction 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'cnn']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']

# %%
def normalisation_m2_s1_extra(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    dico_correspondance = {
        "traitement statistique de corpus (inalco)" : "traitement statistique de corpus",
        "actualite dans le monde anglophone (anglais sorbonne nouvelle )" : "actualite dans le monde anglophone",
        "fouille de textes (inalco)" : "fouille de textes 1"
    }

    cleaned_courses = []
    for course in list_courses:
        if course != "choix de linguistique" and course != "langue vivante":
            if course in dico_correspondance.keys():
                cleaned_courses.append(dico_correspondance[course])
            else:
                cleaned_courses.append(course)

    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m2_s1_extra"] = formulaire["Avons-nous oublié quelque cours au premier semestre du M2 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].apply(normalisation_m2_s1_extra)
# Out:
# []
# []
# []
# []
# []
# ['traitement statistique de corpus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['traitement statistique de corpus', 'sociolinguistique', 'actualite dans le monde anglophone']
# ['fouille de textes 1']
# []
# []
# []

# %% [markdown]
# # ON RÉ-ENREGISTRE LE FORMULAIRE DANS LE CSV MAIS AVEC LES NOUVELLES COLONNES

# %%
formulaire.to_csv("formulaire_cleaned.csv", index=False)

# %% [markdown]
# # ON CRÉE LA DATAFRAME COURS

# %%
#===== Initialisation du dictionnaire des cours =====#
dico_cours = {"nom_cours": [],
         "id_prof": [],
         "nom_prof" : [],
         "prenom_prof" : [],
         "etablissement": [],
         "annee": []}
        #  "horaires": [],
        #  "evaluation": [],
        #  "list_eleves": []}

# %%
#### En dessous c'est pour obtenir une liste des cours (unique) à partir de nos nouvelles colonnes normalisées !

# %%
#===== Remplissage du dictionnaire des cours =====#

courses_m1_s1 = formulaire["normalised_m1_s1_courses"].to_list()
courses_m1_s2 = formulaire["normalised_m1_s2_courses"].to_list()
courses_m2_s1 = formulaire["normalised_m2_s1_courses"].to_list()

mandatory_courses = courses_m1_s1 + courses_m1_s2 + courses_m2_s1
mandatory_courses = [value for sublist in mandatory_courses for value in sublist]
mandatory_courses = list(set(mandatory_courses))

optional_courses_m1_s1 = formulaire["normalised_m1_s1_optionnal"].dropna().to_list()
optional_courses_m1_s1 = optional_courses_m1_s1 + formulaire["normalised_m1_s1_extra"].dropna().to_list()
optional_courses_m1_s2 = formulaire["normalised_m1_s2_extra"].dropna().to_list()
optional_courses_m2_s1 = formulaire["normalised_m2_s1_extra"].dropna().to_list()
optional_courses = optional_courses_m1_s1 + optional_courses_m1_s2 + optional_courses_m2_s1
optional_courses = [value for sublist in optional_courses for value in sublist]
optional_courses = list(set(optional_courses))

cours = mandatory_courses + optional_courses
cours = list(set(cours))

if "statistiques" in cours:
    cours.remove("statistiques")
dico_cours["nom_cours"] = sorted(cours)
sorted(cours)
# Out:
# ['acquisition modelisation/representation',
#  'actualite dans le monde anglophone',
#  'anglais de specialite 2',
#  'anglais pro',
#  "annotations semantiques et applications en recherche d'information",
#  'apprentissage automatique',
#  'arbres graphes',
#  'bases de donnees pour linguistes',
#  'calculabilite',
#  'changements linguistiques',
#  'cnn',
#  'conduite de projet de traduction 1',
#  'coreen',
#  'corpus arbores et parsing',
#  'corpus paralleles et comparables',
#  'de la modelisation au traitement automatique des donnees linguistiques',
#  'document structure',
#  'documents structures',
#  'ecriture et multilinguisme',
#  'enrichissement de corpus',
#  "extraction d'informations",
#  'fouille de textes 1',
#  'genres textes et usages',
#  'gest. info multilinguisme',
#  'gestion de projets',
#  'ingenierie des connaissances',
#  'interfaces pour le web',
#  'introduction a la fouille de textes',
#  'khmer',
#  'langages de script (jourdain)',
#  'langages de script (python inalco)',
#  'langages de script (roulois)',
#  'langages du web semantique',
#  'langages reguliers',
#  'langue des signes',
#  'langues vivantes etrangeres',
#  'large corpus linguistics',
#  'lexicologie terminologie et dictionnairique',
#  'lexique et morphologie',
#  'linguistique de la lsf',
#  'linguistique outillee et traitements statistiques',
#  'mathematiques pour le tal',
#  'methodologie de la recherche',
#  "modelisation automatique pour l'analyse de textes",
#  'modelisation des langues',
#  'mooc',
#  'morphologie',
#  'nlp in english',
#  'outils de tao 1',
#  'outils de traitement de corpus',
#  'phonetique physiologique et acoustique',
#  'polonais',
#  'ppe1',
#  'ppe2',
#  'pratiques textuelles et traduction',
#  'principes de bases de donnees',
#  'programmation et algorithmique 1',
#  'programmation et algorithmique 2',
#  'programmation objet 1',
#  'programmation objet 2',
#  'programmation orientee objet 1',
#  'recueil de donnees et statistiques',
#  'redaction professionnelle',
#  'semantique computationnelle',
#  'semantique des textes multilingues 1',
#  'semantique lexicale et textuelle',
#  'seminaire: tal et linguistique de corpus',
#  'sens multiple',
#  'sociolinguistique',
#  'statistiques textuelles',
#  'synthese de la parole',
#  'traduction automatique et assistee',
#  'traduction technique 1',
#  'traductologie 1',
#  'traitement statistique de corpus']

# %%
## Dans le code en dessous en fait correspondre chaque cours à un professeur/à des professeurs pour qu'on ait la liste des profs qui enseignent chaque cours dans la df cours

# %%
for course in dico_cours["nom_cours"]:
    profs_noms = dico_prof["nom_prof"]
    profs_prenoms = dico_prof["prenom_prof"]
    courses = dico_prof["cours"]
    found = False
    print("On cherche le cours", course)

    for prof_nom, prof_prenom, subcourses in zip(profs_noms, profs_prenoms, courses):
        # print("on cherche le cours", course, "dans la liste de cours :")
        subcourses = [subcourse.lower() for subcourse in subcourses]
        # print(subcourses)
        # print("qui est rattachée à:")
        # print(prof_nom, prof_nom)
        if course in subcourses:
            if found == True:
                print(f"le cours {course} a été trouvé et on a déjà un prof")
                print("donc, found est égal à ", found)
                first_prof_nom = dico_cours["nom_prof"][-1]
                first_prof_prenom = dico_cours["prenom_prof"][-1]
                first_id_prof = dico_cours["id_prof"][-1]
                dico_cours["nom_prof"].pop()
                dico_cours["prenom_prof"].pop()
                dico_cours["id_prof"].pop()

                dico_cours["nom_prof"].append([first_prof_nom, prof_nom])
                dico_cours["prenom_prof"].append([first_prof_prenom, prof_prenom])
                dico_cours["id_prof"].append([f"{first_prof_prenom}_{first_prof_nom}", f"{prof_prenom}_{prof_nom}"])
            else:
                found = True
                dico_cours["nom_prof"].append(prof_nom)
                dico_cours["prenom_prof"].append(prof_prenom)
                dico_cours["id_prof"].append(f"{prof_prenom}_{prof_nom}")

            for key, value in dico_cours.items():
                print(key, value)
    
    if found == False:
        dico_cours["nom_prof"].append("")
        dico_cours["prenom_prof"].append("")
        dico_cours["id_prof"].append("")
    #     dico_cours["professeur"].append(df_prof["nom_prof"][df_prof["cours"].index(course)])
    # else:
    #     dico_cours["professeur"].append("Non défini")
# Out:
# On cherche le cours acquisition modelisation/representation
# nom_cours ['acquisition modelisation/representation', 'actualite dans le monde anglophone', 'anglais de specialite 2', 'anglais pro', "annotations semantiques et applications en recherche d'information", 'apprentissage automatique', 'arbres graphes', 'bases de donnees pour linguistes', 'calculabilite', 'changements linguistiques', 'cnn', 'conduite de projet de traduction 1', 'coreen', 'corpus arbores et parsing', 'corpus paralleles et comparables', 'de la modelisation au traitement automatique des donnees linguistiques', 'document structure', 'documents structures', 'ecriture et multilinguisme', 'enrichissement de corpus', "extraction d'informations", 'fouille de textes 1', 'genres textes et usages', 'gest. info multilinguisme', 'gestion de projets', 'ingenierie des connaissances', 'interfaces pour le web', 'introduction a la fouille de textes', 'khmer', 'langages de script (jourdain)', 'langages de script (python inalco)', 'langages de script (roulois)', 'langages du web semantique', 'langages reguliers', 'langue des signes', 'langues vivantes etrangeres', 'large corpus linguistics', 'lexicologie terminologie et dictionnairique', 'lexique et morphologie', 'linguistique de la lsf', 'linguistique outillee et traitements statistiques', 'mathematiques pour le tal', 'methodologie de la recherche', "modelisation automatique pour l'analyse de textes", 'modelisation des langues', 'mooc', 'morphologie', 'nlp in english', 'outils de tao 1', 'outils de traitement de corpus', 'phonetique physiologique et acoustique', 'polonais', 'ppe1', 'ppe2', 'pratiques textuelles et traduction', 'principes de bases de donnees', 'programmation et algorithmique 1', 'programmation et algorithmique 2', 'programmation objet 1', 'programmation objet 2', 'programmation orientee objet 1', 'recueil de donnees et statistiques', 'redaction professionnelle', 'semantique computationnelle', 'semantique des textes multilingues 1', 'semantique lexicale et textuelle', 'seminaire: tal et linguistique de corpus', 'sens multiple', 'sociolinguistique', 'statistiques textuelles', 'synthese de la parole', 'traduction automatique et assistee', 'traduction technique 1', 'traductologie 1', 'traitement statistique de corpus']
# id_prof ['Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Loïc_GROBOL', 'Iris_ESHKOL-TARAVELLA', 'Patrick_PAROUBECK', ['Sabine_LEHMANN', 'Vanessa_PICCOLI'], 'Cedric_GENDROT', 'Sophie_GAUMET', 'Kyung_LEE', 'Santiago_HERRERA', 'Pierre_ZWEIGENBAUM', 'Iris_ESHKOL-TARAVELLA', 'Michel_JACOBSON', 'Rim_ABROUGUI', 'Ilaine_WANG', 'Iris_ESHKOL-TARAVELLA', 'Chloé_MONNIN-TUILLIER', 'Cyril_GROUIN', 'Mathieu_VALETTE', 'Ilaine_WANG', 'Benoît_CARCENAC', ['Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA'], 'Loïc_GROBOL', 'Yoann_DUPONT', 'Suppya_NUT', 'Louis_JOURDAIN', 'Alexandre_ROULOIS', 'Alexandre_ROULOIS', 'Iris_ESHKOL-TARAVELLA', 'Damien_NOUVEL', 'Hatice_AKSEN', 'Armand_STRICKER', 'Sophie_RAINERIE', '', 'Kata_GABOR', 'Caroline_BOGLIOTTI', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Marcel_CORI', 'Delphine_BATTISTELLI', 'Sylvain_KAHANE', '', 'Florence_VILLEOING', 'Armand_STRICKER', 'Karolina_KUBIK', 'Eve_SAUVAGE', 'Cedric_GENDROT', 'Natalia_LASON', ['Yoann_DUPONT', 'Pierre_MAGISTRY'], ['Yoann_DUPONT', 'Pierre_MAGISTRY'], 'Zhu_LICHAO', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Florent_JACQUEMARD', 'Florent_JACQUEMARD', 'Louis_LECAILLIEZ', 'Xibin_WANG', '', 'Pascal_AMSILI', 'Mathieu_VALETTE', 'Mathieu_VALETTE', 'Iris_ESHKOL-TARAVELLA', '', 'James_COSTA', '', 'Damien_NOUVEL', 'Cedric_GENDROT', 'Nasredine_SEMMAR', 'Marie-Paule_BONNAFOUS', 'Zhu_LICHAO', 'Damien_NOUVEL', 'Ons_AOUINA']
# nom_prof ['AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI', 'GROBOL', 'GROBOL', 'ESHKOL-TARAVELLA', 'PAROUBECK', ['LEHMANN', 'PICCOLI'], 'GENDROT', 'GAUMET', 'LEE', 'HERRERA', 'ZWEIGENBAUM', 'ESHKOL-TARAVELLA', 'JACOBSON', 'ABROUGUI', 'WANG', 'ESHKOL-TARAVELLA', 'MONNIN-TUILLIER', 'GROUIN', 'VALETTE', 'WANG', 'CARCENAC', ['BATTISTELLI', 'ESHKOL-TARAVELLA'], 'GROBOL', 'DUPONT', 'NUT', 'JOURDAIN', 'ROULOIS', 'ROULOIS', 'ESHKOL-TARAVELLA', 'NOUVEL', 'AKSEN', 'STRICKER', 'RAINERIE', '', 'GABOR', 'BOGLIOTTI', 'BATTISTELLI', 'GROBOL', 'CORI', 'BATTISTELLI', 'KAHANE', '', 'VILLEOING', 'STRICKER', 'KUBIK', 'SAUVAGE', 'GENDROT', 'LASON', ['DUPONT', 'MAGISTRY'], ['DUPONT', 'MAGISTRY'], 'LICHAO', '', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'JACQUEMARD', 'JACQUEMARD', 'LECAILLIEZ', 'WANG', '', 'AMSILI', 'VALETTE', 'VALETTE', 'ESHKOL-TARAVELLA', '', 'COSTA', '', 'NOUVEL', 'GENDROT', 'SEMMAR', 'BONNAFOUS', 'LICHAO', 'NOUVEL', 'AOUINA']
# prenom_prof ['Ons', '', 'Loulou', 'Christophe', 'Delphine', 'Loïc', 'Loïc', 'Iris', 'Patrick', ['Sabine', 'Vanessa'], 'Cedric', 'Sophie', 'Kyung', 'Santiago', 'Pierre', 'Iris', 'Michel', 'Rim', 'Ilaine', 'Iris', 'Chloé', 'Cyril', 'Mathieu', 'Ilaine', 'Benoît', ['Delphine', 'Iris'], 'Loïc', 'Yoann', 'Suppya', 'Louis', 'Alexandre', 'Alexandre', 'Iris', 'Damien', 'Hatice', 'Armand', 'Sophie', '', 'Kata', 'Caroline', 'Delphine', 'Loïc', 'Marcel', 'Delphine', 'Sylvain', '', 'Florence', 'Armand', 'Karolina', 'Eve', 'Cedric', 'Natalia', ['Yoann', 'Pierre'], ['Yoann', 'Pierre'], 'Zhu', '', 'Iris', 'Mathieu', 'Florent', 'Florent', 'Louis', 'Xibin', '', 'Pascal', 'Mathieu', 'Mathieu', 'Iris', '', 'James', '', 'Damien', 'Cedric', 'Nasredine', 'Marie-Paule', 'Zhu', 'Damien', 'Ons']
# etablissement ['Inalco', 'SorbonneNouvelle', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'SorbonneNouvelle', 'Inalco', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco']
# annee ['2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2024-2025']
# id_cours ['acquisition_modelisation_representation_2024_2025', 'actualite_dans_le_monde_anglophone_2024_2025', 'anglais_de_specialite_2_2023_2024', 'anglais_pro_2024_2025', 'annotations_semantiques_et_applications_en_recherche_d_information_2024_2025', 'apprentissage_automatique_2024_2025', 'arbres_graphes_2024_2025', 'bases_de_donnees_pour_linguistes_2023_2024', 'calculabilite_2024_2025', 'changements_linguistiques_2023_2024', 'cnn_2024_2025', 'conduite_de_projet_de_traduction_1_2024_2025', 'coreen_2023_2024', 'corpus_arbores_et_parsing_2023_2024', 'corpus_paralleles_et_comparables_2023_2024', 'de_la_modelisation_au_traitement_automatique_des_donnees_linguistiques_2024_2025', 'document_structure_2023_2024', 'documents_structures_2024_2025', 'ecriture_et_multilinguisme_2024_2025', 'enrichissement_de_corpus_2023_2024', 'extraction_d_informations_2023_2024', 'fouille_de_textes_1_2024_2025', 'genres_textes_et_usages_2024_2025', 'gest__info_multilinguisme_2023_2024', 'gestion_de_projets_2024_2025', 'ingenierie_des_connaissances_2024_2025', 'interfaces_pour_le_web_2024_2025', 'introduction_a_la_fouille_de_textes_2023_2024', 'khmer_2023_2024', 'langages_de_script_(jourdain)_2024_2025', 'langages_de_script_(python_inalco)_2023_2024', 'langages_de_script_(roulois)_2024_2025', 'langages_du_web_semantique_2024_2025', 'langages_reguliers_2023_2024', 'langue_des_signes_2024_2025', 'langues_vivantes_etrangeres_2023_2024', 'large_corpus_linguistics_2023_2024', 'lexicologie_terminologie_et_dictionnairique_2024_2025', 'lexique_et_morphologie_2023_2024', 'linguistique_de_la_lsf_2023_2024', 'linguistique_outillee_et_traitements_statistiques_2024_2025', 'mathematiques_pour_le_tal_2023_2024', 'methodologie_de_la_recherche_2024_2025', 'modelisation_automatique_pour_l_analyse_de_textes_2023_2024', 'modelisation_des_langues_2024_2025', 'mooc_2023_2024', 'morphologie_2023_2024', 'nlp_in_english_2023_2024', 'outils_de_tao_1_2024_2025', 'outils_de_traitement_de_corpus_2023_2024', 'phonetique_physiologique_et_acoustique_2023_2024', 'polonais_2023_2024', 'ppe1_2023_2024', 'ppe2_2023_2024', 'pratiques_textuelles_et_traduction_2023_2024', 'principes_de_bases_de_donnees_2023_2024', 'programmation_et_algorithmique_1_2023_2024', 'programmation_et_algorithmique_2_2023_2024', 'programmation_objet_1_2023_2024', 'programmation_objet_2_2023_2024', 'programmation_orientee_objet_1_2024_2025', 'recueil_de_donnees_et_statistiques_2023_2024', 'redaction_professionnelle_2023_2024', 'semantique_computationnelle_2024_2025', 'semantique_des_textes_multilingues_1_2024_2025', 'semantique_lexicale_et_textuelle_2023_2024', 'seminaire:_tal_et_linguistique_de_corpus_2024_2025', 'sens_multiple_2023_2024', 'sociolinguistique_2023_2024', 'statistiques_2023_2024', 'statistiques_textuelles_2023_2024', 'synthese_de_la_parole_2023_2024', 'traduction_automatique_et_assistee_2024_2025', 'traduction_technique_1_2024_2025', 'traductologie_1_2024_2025']
# On cherche le cours actualite dans le monde anglophone
# On cherche le cours anglais de specialite 2
# nom_cours ['acquisition modelisation/representation', 'actualite dans le monde anglophone', 'anglais de specialite 2', 'anglais pro', "annotations semantiques et applications en recherche d'information", 'apprentissage automatique', 'arbres graphes', 'bases de donnees pour linguistes', 'calculabilite', 'changements linguistiques', 'cnn', 'conduite de projet de traduction 1', 'coreen', 'corpus arbores et parsing', 'corpus paralleles et comparables', 'de la modelisation au traitement automatique des donnees linguistiques', 'document structure', 'documents structures', 'ecriture et multilinguisme', 'enrichissement de corpus', "extraction d'informations", 'fouille de textes 1', 'genres textes et usages', 'gest. info multilinguisme', 'gestion de projets', 'ingenierie des connaissances', 'interfaces pour le web', 'introduction a la fouille de textes', 'khmer', 'langages de script (jourdain)', 'langages de script (python inalco)', 'langages de script (roulois)', 'langages du web semantique', 'langages reguliers', 'langue des signes', 'langues vivantes etrangeres', 'large corpus linguistics', 'lexicologie terminologie et dictionnairique', 'lexique et morphologie', 'linguistique de la lsf', 'linguistique outillee et traitements statistiques', 'mathematiques pour le tal', 'methodologie de la recherche', "modelisation automatique pour l'analyse de textes", 'modelisation des langues', 'mooc', 'morphologie', 'nlp in english', 'outils de tao 1', 'outils de traitement de corpus', 'phonetique physiologique et acoustique', 'polonais', 'ppe1', 'ppe2', 'pratiques textuelles et traduction', 'principes de bases de donnees', 'programmation et algorithmique 1', 'programmation et algorithmique 2', 'programmation objet 1', 'programmation objet 2', 'programmation orientee objet 1', 'recueil de donnees et statistiques', 'redaction professionnelle', 'semantique computationnelle', 'semantique des textes multilingues 1', 'semantique lexicale et textuelle', 'seminaire: tal et linguistique de corpus', 'sens multiple', 'sociolinguistique', 'statistiques textuelles', 'synthese de la parole', 'traduction automatique et assistee', 'traduction technique 1', 'traductologie 1', 'traitement statistique de corpus']
# id_prof ['Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Loïc_GROBOL', 'Iris_ESHKOL-TARAVELLA', 'Patrick_PAROUBECK', ['Sabine_LEHMANN', 'Vanessa_PICCOLI'], 'Cedric_GENDROT', 'Sophie_GAUMET', 'Kyung_LEE', 'Santiago_HERRERA', 'Pierre_ZWEIGENBAUM', 'Iris_ESHKOL-TARAVELLA', 'Michel_JACOBSON', 'Rim_ABROUGUI', 'Ilaine_WANG', 'Iris_ESHKOL-TARAVELLA', 'Chloé_MONNIN-TUILLIER', 'Cyril_GROUIN', 'Mathieu_VALETTE', 'Ilaine_WANG', 'Benoît_CARCENAC', ['Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA'], 'Loïc_GROBOL', 'Yoann_DUPONT', 'Suppya_NUT', 'Louis_JOURDAIN', 'Alexandre_ROULOIS', 'Alexandre_ROULOIS', 'Iris_ESHKOL-TARAVELLA', 'Damien_NOUVEL', 'Hatice_AKSEN', 'Armand_STRICKER', 'Sophie_RAINERIE', '', 'Kata_GABOR', 'Caroline_BOGLIOTTI', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Marcel_CORI', 'Delphine_BATTISTELLI', 'Sylvain_KAHANE', '', 'Florence_VILLEOING', 'Armand_STRICKER', 'Karolina_KUBIK', 'Eve_SAUVAGE', 'Cedric_GENDROT', 'Natalia_LASON', ['Yoann_DUPONT', 'Pierre_MAGISTRY'], ['Yoann_DUPONT', 'Pierre_MAGISTRY'], 'Zhu_LICHAO', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Florent_JACQUEMARD', 'Florent_JACQUEMARD', 'Louis_LECAILLIEZ', 'Xibin_WANG', '', 'Pascal_AMSILI', 'Mathieu_VALETTE', 'Mathieu_VALETTE', 'Iris_ESHKOL-TARAVELLA', '', 'James_COSTA', '', 'Damien_NOUVEL', 'Cedric_GENDROT', 'Nasredine_SEMMAR', 'Marie-Paule_BONNAFOUS', 'Zhu_LICHAO', 'Damien_NOUVEL', 'Ons_AOUINA', '', 'Loulou_KOSMALA']
# nom_prof ['AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI', 'GROBOL', 'GROBOL', 'ESHKOL-TARAVELLA', 'PAROUBECK', ['LEHMANN', 'PICCOLI'], 'GENDROT', 'GAUMET', 'LEE', 'HERRERA', 'ZWEIGENBAUM', 'ESHKOL-TARAVELLA', 'JACOBSON', 'ABROUGUI', 'WANG', 'ESHKOL-TARAVELLA', 'MONNIN-TUILLIER', 'GROUIN', 'VALETTE', 'WANG', 'CARCENAC', ['BATTISTELLI', 'ESHKOL-TARAVELLA'], 'GROBOL', 'DUPONT', 'NUT', 'JOURDAIN', 'ROULOIS', 'ROULOIS', 'ESHKOL-TARAVELLA', 'NOUVEL', 'AKSEN', 'STRICKER', 'RAINERIE', '', 'GABOR', 'BOGLIOTTI', 'BATTISTELLI', 'GROBOL', 'CORI', 'BATTISTELLI', 'KAHANE', '', 'VILLEOING', 'STRICKER', 'KUBIK', 'SAUVAGE', 'GENDROT', 'LASON', ['DUPONT', 'MAGISTRY'], ['DUPONT', 'MAGISTRY'], 'LICHAO', '', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'JACQUEMARD', 'JACQUEMARD', 'LECAILLIEZ', 'WANG', '', 'AMSILI', 'VALETTE', 'VALETTE', 'ESHKOL-TARAVELLA', '', 'COSTA', '', 'NOUVEL', 'GENDROT', 'SEMMAR', 'BONNAFOUS', 'LICHAO', 'NOUVEL', 'AOUINA', '', 'KOSMALA']
# prenom_prof ['Ons', '', 'Loulou', 'Christophe', 'Delphine', 'Loïc', 'Loïc', 'Iris', 'Patrick', ['Sabine', 'Vanessa'], 'Cedric', 'Sophie', 'Kyung', 'Santiago', 'Pierre', 'Iris', 'Michel', 'Rim', 'Ilaine', 'Iris', 'Chloé', 'Cyril', 'Mathieu', 'Ilaine', 'Benoît', ['Delphine', 'Iris'], 'Loïc', 'Yoann', 'Suppya', 'Louis', 'Alexandre', 'Alexandre', 'Iris', 'Damien', 'Hatice', 'Armand', 'Sophie', '', 'Kata', 'Caroline', 'Delphine', 'Loïc', 'Marcel', 'Delphine', 'Sylvain', '', 'Florence', 'Armand', 'Karolina', 'Eve', 'Cedric', 'Natalia', ['Yoann', 'Pierre'], ['Yoann', 'Pierre'], 'Zhu', '', 'Iris', 'Mathieu', 'Florent', 'Florent', 'Louis', 'Xibin', '', 'Pascal', 'Mathieu', 'Mathieu', 'Iris', '', 'James', '', 'Damien', 'Cedric', 'Nasredine', 'Marie-Paule', 'Zhu', 'Damien', 'Ons', '', 'Loulou']
# etablissement ['Inalco', 'SorbonneNouvelle', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'SorbonneNouvelle', 'Inalco', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco']
# annee ['2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2024-2025']
# id_cours ['acquisition_modelisation_representation_2024_2025', 'actualite_dans_le_monde_anglophone_2024_2025', 'anglais_de_specialite_2_2023_2024', 'anglais_pro_2024_2025', 'annotations_semantiques_et_applications_en_recherche_d_information_2024_2025', 'apprentissage_automatique_2024_2025', 'arbres_graphes_2024_2025', 'bases_de_donnees_pour_linguistes_2023_2024', 'calculabilite_2024_2025', 'changements_linguistiques_2023_2024', 'cnn_2024_2025', 'conduite_de_projet_de_traduction_1_2024_2025', 'coreen_2023_2024', 'corpus_arbores_et_parsing_2023_2024', 'corpus_paralleles_et_comparables_2023_2024', 'de_la_modelisation_au_traitement_automatique_des_donnees_linguistiques_2024_2025', 'document_structure_2023_2024', 'documents_structures_2024_2025', 'ecriture_et_multilinguisme_2024_2025', 'enrichissement_de_corpus_2023_2024', 'extraction_d_informations_2023_2024', 'fouille_de_textes_1_2024_2025', 'genres_textes_et_usages_2024_2025', 'gest__info_multilinguisme_2023_2024', 'gestion_de_projets_2024_2025', 'ingenierie_des_connaissances_2024_2025', 'interfaces_pour_le_web_2024_2025', 'introduction_a_la_fouille_de_textes_2023_2024', 'khmer_2023_2024', 'langages_de_script_(jourdain)_2024_2025', 'langages_de_script_(python_inalco)_2023_2024', 'langages_de_script_(roulois)_2024_2025', 'langages_du_web_semantique_2024_2025', 'langages_reguliers_2023_2024', 'langue_des_signes_2024_2025', 'langues_vivantes_etrangeres_2023_2024', 'large_corpus_linguistics_2023_2024', 'lexicologie_terminologie_et_dictionnairique_2024_2025', 'lexique_et_morphologie_2023_2024', 'linguistique_de_la_lsf_2023_2024', 'linguistique_outillee_et_traitements_statistiques_2024_2025', 'mathematiques_pour_le_tal_2023_2024', 'methodologie_de_la_recherche_2024_2025', 'modelisation_automatique_pour_l_analyse_de_textes_2023_2024', 'modelisation_des_langues_2024_2025', 'mooc_2023_2024', 'morphologie_2023_2024', 'nlp_in_english_2023_2024', 'outils_de_tao_1_2024_2025', 'outils_de_traitement_de_corpus_2023_2024', 'phonetique_physiologique_et_acoustique_2023_2024', 'polonais_2023_2024', 'ppe1_2023_2024', 'ppe2_2023_2024', 'pratiques_textuelles_et_traduction_2023_2024', 'principes_de_bases_de_donnees_2023_2024', 'programmation_et_algorithmique_1_2023_2024', 'programmation_et_algorithmique_2_2023_2024', 'programmation_objet_1_2023_2024', 'programmation_objet_2_2023_2024', 'programmation_orientee_objet_1_2024_2025', 'recueil_de_donnees_et_statistiques_2023_2024', 'redaction_professionnelle_2023_2024', 'semantique_computationnelle_2024_2025', 'semantique_des_textes_multilingues_1_2024_2025', 'semantique_lexicale_et_textuelle_2023_2024', 'seminaire:_tal_et_linguistique_de_corpus_2024_2025', 'sens_multiple_2023_2024', 'sociolinguistique_2023_2024', 'statistiques_2023_2024', 'statistiques_textuelles_2023_2024', 'synthese_de_la_parole_2023_2024', 'traduction_automatique_et_assistee_2024_2025', 'traduction_technique_1_2024_2025', 'traductologie_1_2024_2025']
# On cherche le cours anglais pro
# nom_cours ['acquisition modelisation/representation', 'actualite dans le monde anglophone', 'anglais de specialite 2', 'anglais pro', "annotations semantiques et applications en recherche d'information", 'apprentissage automatique', 'arbres graphes', 'bases de donnees pour linguistes', 'calculabilite', 'changements linguistiques', 'cnn', 'conduite de projet de traduction 1', 'coreen', 'corpus arbores et parsing', 'corpus paralleles et comparables', 'de la modelisation au traitement automatique des donnees linguistiques', 'document structure', 'documents structures', 'ecriture et multilinguisme', 'enrichissement de corpus', "extraction d'informations", 'fouille de textes 1', 'genres textes et usages', 'gest. info multilinguisme', 'gestion de projets', 'ingenierie des connaissances', 'interfaces pour le web', 'introduction a la fouille de textes', 'khmer', 'langages de script (jourdain)', 'langages de script (python inalco)', 'langages de script (roulois)', 'langages du web semantique', 'langages reguliers', 'langue des signes', 'langues vivantes etrangeres', 'large corpus linguistics', 'lexicologie terminologie et dictionnairique', 'lexique et morphologie', 'linguistique de la lsf', 'linguistique outillee et traitements statistiques', 'mathematiques pour le tal', 'methodologie de la recherche', "modelisation automatique pour l'analyse de textes", 'modelisation des langues', 'mooc', 'morphologie', 'nlp in english', 'outils de tao 1', 'outils de traitement de corpus', 'phonetique physiologique et acoustique', 'polonais', 'ppe1', 'ppe2', 'pratiques textuelles et traduction', 'principes de bases de donnees', 'programmation et algorithmique 1', 'programmation et algorithmique 2', 'programmation objet 1', 'programmation objet 2', 'programmation orientee objet 1', 'recueil de donnees et statistiques', 'redaction professionnelle', 'semantique computationnelle', 'semantique des textes multilingues 1', 'semantique lexicale et textuelle', 'seminaire: tal et linguistique de corpus', 'sens multiple', 'sociolinguistique', 'statistiques textuelles', 'synthese de la parole', 'traduction automatique et assistee', 'traduction technique 1', 'traductologie 1', 'traitement statistique de corpus']
# id_prof ['Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Loïc_GROBOL', 'Iris_ESHKOL-TARAVELLA', 'Patrick_PAROUBECK', ['Sabine_LEHMANN', 'Vanessa_PICCOLI'], 'Cedric_GENDROT', 'Sophie_GAUMET', 'Kyung_LEE', 'Santiago_HERRERA', 'Pierre_ZWEIGENBAUM', 'Iris_ESHKOL-TARAVELLA', 'Michel_JACOBSON', 'Rim_ABROUGUI', 'Ilaine_WANG', 'Iris_ESHKOL-TARAVELLA', 'Chloé_MONNIN-TUILLIER', 'Cyril_GROUIN', 'Mathieu_VALETTE', 'Ilaine_WANG', 'Benoît_CARCENAC', ['Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA'], 'Loïc_GROBOL', 'Yoann_DUPONT', 'Suppya_NUT', 'Louis_JOURDAIN', 'Alexandre_ROULOIS', 'Alexandre_ROULOIS', 'Iris_ESHKOL-TARAVELLA', 'Damien_NOUVEL', 'Hatice_AKSEN', 'Armand_STRICKER', 'Sophie_RAINERIE', '', 'Kata_GABOR', 'Caroline_BOGLIOTTI', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Marcel_CORI', 'Delphine_BATTISTELLI', 'Sylvain_KAHANE', '', 'Florence_VILLEOING', 'Armand_STRICKER', 'Karolina_KUBIK', 'Eve_SAUVAGE', 'Cedric_GENDROT', 'Natalia_LASON', ['Yoann_DUPONT', 'Pierre_MAGISTRY'], ['Yoann_DUPONT', 'Pierre_MAGISTRY'], 'Zhu_LICHAO', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Florent_JACQUEMARD', 'Florent_JACQUEMARD', 'Louis_LECAILLIEZ', 'Xibin_WANG', '', 'Pascal_AMSILI', 'Mathieu_VALETTE', 'Mathieu_VALETTE', 'Iris_ESHKOL-TARAVELLA', '', 'James_COSTA', '', 'Damien_NOUVEL', 'Cedric_GENDROT', 'Nasredine_SEMMAR', 'Marie-Paule_BONNAFOUS', 'Zhu_LICHAO', 'Damien_NOUVEL', 'Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP']
# nom_prof ['AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI', 'GROBOL', 'GROBOL', 'ESHKOL-TARAVELLA', 'PAROUBECK', ['LEHMANN', 'PICCOLI'], 'GENDROT', 'GAUMET', 'LEE', 'HERRERA', 'ZWEIGENBAUM', 'ESHKOL-TARAVELLA', 'JACOBSON', 'ABROUGUI', 'WANG', 'ESHKOL-TARAVELLA', 'MONNIN-TUILLIER', 'GROUIN', 'VALETTE', 'WANG', 'CARCENAC', ['BATTISTELLI', 'ESHKOL-TARAVELLA'], 'GROBOL', 'DUPONT', 'NUT', 'JOURDAIN', 'ROULOIS', 'ROULOIS', 'ESHKOL-TARAVELLA', 'NOUVEL', 'AKSEN', 'STRICKER', 'RAINERIE', '', 'GABOR', 'BOGLIOTTI', 'BATTISTELLI', 'GROBOL', 'CORI', 'BATTISTELLI', 'KAHANE', '', 'VILLEOING', 'STRICKER', 'KUBIK', 'SAUVAGE', 'GENDROT', 'LASON', ['DUPONT', 'MAGISTRY'], ['DUPONT', 'MAGISTRY'], 'LICHAO', '', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'JACQUEMARD', 'JACQUEMARD', 'LECAILLIEZ', 'WANG', '', 'AMSILI', 'VALETTE', 'VALETTE', 'ESHKOL-TARAVELLA', '', 'COSTA', '', 'NOUVEL', 'GENDROT', 'SEMMAR', 'BONNAFOUS', 'LICHAO', 'NOUVEL', 'AOUINA', '', 'KOSMALA', 'HUP']
# prenom_prof ['Ons', '', 'Loulou', 'Christophe', 'Delphine', 'Loïc', 'Loïc', 'Iris', 'Patrick', ['Sabine', 'Vanessa'], 'Cedric', 'Sophie', 'Kyung', 'Santiago', 'Pierre', 'Iris', 'Michel', 'Rim', 'Ilaine', 'Iris', 'Chloé', 'Cyril', 'Mathieu', 'Ilaine', 'Benoît', ['Delphine', 'Iris'], 'Loïc', 'Yoann', 'Suppya', 'Louis', 'Alexandre', 'Alexandre', 'Iris', 'Damien', 'Hatice', 'Armand', 'Sophie', '', 'Kata', 'Caroline', 'Delphine', 'Loïc', 'Marcel', 'Delphine', 'Sylvain', '', 'Florence', 'Armand', 'Karolina', 'Eve', 'Cedric', 'Natalia', ['Yoann', 'Pierre'], ['Yoann', 'Pierre'], 'Zhu', '', 'Iris', 'Mathieu', 'Florent', 'Florent', 'Louis', 'Xibin', '', 'Pascal', 'Mathieu', 'Mathieu', 'Iris', '', 'James', '', 'Damien', 'Cedric', 'Nasredine', 'Marie-Paule', 'Zhu', 'Damien', 'Ons', '', 'Loulou', 'Christophe']
# etablissement ['Inalco', 'SorbonneNouvelle', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'SorbonneNouvelle', 'Inalco', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco']
# annee ['2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2024-2025']
# id_cours ['acquisition_modelisation_representation_2024_2025', 'actualite_dans_le_monde_anglophone_2024_2025', 'anglais_de_specialite_2_2023_2024', 'anglais_pro_2024_2025', 'annotations_semantiques_et_applications_en_recherche_d_information_2024_2025', 'apprentissage_automatique_2024_2025', 'arbres_graphes_2024_2025', 'bases_de_donnees_pour_linguistes_2023_2024', 'calculabilite_2024_2025', 'changements_linguistiques_2023_2024', 'cnn_2024_2025', 'conduite_de_projet_de_traduction_1_2024_2025', 'coreen_2023_2024', 'corpus_arbores_et_parsing_2023_2024', 'corpus_paralleles_et_comparables_2023_2024', 'de_la_modelisation_au_traitement_automatique_des_donnees_linguistiques_2024_2025', 'document_structure_2023_2024', 'documents_structures_2024_2025', 'ecriture_et_multilinguisme_2024_2025', 'enrichissement_de_corpus_2023_2024', 'extraction_d_informations_2023_2024', 'fouille_de_textes_1_2024_2025', 'genres_textes_et_usages_2024_2025', 'gest__info_multilinguisme_2023_2024', 'gestion_de_projets_2024_2025', 'ingenierie_des_connaissances_2024_2025', 'interfaces_pour_le_web_2024_2025', 'introduction_a_la_fouille_de_textes_2023_2024', 'khmer_2023_2024', 'langages_de_script_(jourdain)_2024_2025', 'langages_de_script_(python_inalco)_2023_2024', 'langages_de_script_(roulois)_2024_2025', 'langages_du_web_semantique_2024_2025', 'langages_reguliers_2023_2024', 'langue_des_signes_2024_2025', 'langues_vivantes_etrangeres_2023_2024', 'large_corpus_linguistics_2023_2024', 'lexicologie_terminologie_et_dictionnairique_2024_2025', 'lexique_et_morphologie_2023_2024', 'linguistique_de_la_lsf_2023_2024', 'linguistique_outillee_et_traitements_statistiques_2024_2025', 'mathematiques_pour_le_tal_2023_2024', 'methodologie_de_la_recherche_2024_2025', 'modelisation_automatique_pour_l_analyse_de_textes_2023_2024', 'modelisation_des_langues_2024_2025', 'mooc_2023_2024', 'morphologie_2023_2024', 'nlp_in_english_2023_2024', 'outils_de_tao_1_2024_2025', 'outils_de_traitement_de_corpus_2023_2024', 'phonetique_physiologique_et_acoustique_2023_2024', 'polonais_2023_2024', 'ppe1_2023_2024', 'ppe2_2023_2024', 'pratiques_textuelles_et_traduction_2023_2024', 'principes_de_bases_de_donnees_2023_2024', 'programmation_et_algorithmique_1_2023_2024', 'programmation_et_algorithmique_2_2023_2024', 'programmation_objet_1_2023_2024', 'programmation_objet_2_2023_2024', 'programmation_orientee_objet_1_2024_2025', 'recueil_de_donnees_et_statistiques_2023_2024', 'redaction_professionnelle_2023_2024', 'semantique_computationnelle_2024_2025', 'semantique_des_textes_multilingues_1_2024_2025', 'semantique_lexicale_et_textuelle_2023_2024', 'seminaire:_tal_et_linguistique_de_corpus_2024_2025', 'sens_multiple_2023_2024', 'sociolinguistique_2023_2024', 'statistiques_2023_2024', 'statistiques_textuelles_2023_2024', 'synthese_de_la_parole_2023_2024', 'traduction_automatique_et_assistee_2024_2025', 'traduction_technique_1_2024_2025', 'traductologie_1_2024_2025']
# On cherche le cours annotations semantiques et applications en recherche d'information
# nom_cours ['acquisition modelisation/representation', 'actualite dans le monde anglophone', 'anglais de specialite 2', 'anglais pro', "annotations semantiques et applications en recherche d'information", 'apprentissage automatique', 'arbres graphes', 'bases de donnees pour linguistes', 'calculabilite', 'changements linguistiques', 'cnn', 'conduite de projet de traduction 1', 'coreen', 'corpus arbores et parsing', 'corpus paralleles et comparables', 'de la modelisation au traitement automatique des donnees linguistiques', 'document structure', 'documents structures', 'ecriture et multilinguisme', 'enrichissement de corpus', "extraction d'informations", 'fouille de textes 1', 'genres textes et usages', 'gest. info multilinguisme', 'gestion de projets', 'ingenierie des connaissances', 'interfaces pour le web', 'introduction a la fouille de textes', 'khmer', 'langages de script (jourdain)', 'langages de script (python inalco)', 'langages de script (roulois)', 'langages du web semantique', 'langages reguliers', 'langue des signes', 'langues vivantes etrangeres', 'large corpus linguistics', 'lexicologie terminologie et dictionnairique', 'lexique et morphologie', 'linguistique de la lsf', 'linguistique outillee et traitements statistiques', 'mathematiques pour le tal', 'methodologie de la recherche', "modelisation automatique pour l'analyse de textes", 'modelisation des langues', 'mooc', 'morphologie', 'nlp in english', 'outils de tao 1', 'outils de traitement de corpus', 'phonetique physiologique et acoustique', 'polonais', 'ppe1', 'ppe2', 'pratiques textuelles et traduction', 'principes de bases de donnees', 'programmation et algorithmique 1', 'programmation et algorithmique 2', 'programmation objet 1', 'programmation objet 2', 'programmation orientee objet 1', 'recueil de donnees et statistiques', 'redaction professionnelle', 'semantique computationnelle', 'semantique des textes multilingues 1', 'semantique lexicale et textuelle', 'seminaire: tal et linguistique de corpus', 'sens multiple', 'sociolinguistique', 'statistiques textuelles', 'synthese de la parole', 'traduction automatique et assistee', 'traduction technique 1', 'traductologie 1', 'traitement statistique de corpus']
# id_prof ['Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Loïc_GROBOL', 'Iris_ESHKOL-TARAVELLA', 'Patrick_PAROUBECK', ['Sabine_LEHMANN', 'Vanessa_PICCOLI'], 'Cedric_GENDROT', 'Sophie_GAUMET', 'Kyung_LEE', 'Santiago_HERRERA', 'Pierre_ZWEIGENBAUM', 'Iris_ESHKOL-TARAVELLA', 'Michel_JACOBSON', 'Rim_ABROUGUI', 'Ilaine_WANG', 'Iris_ESHKOL-TARAVELLA', 'Chloé_MONNIN-TUILLIER', 'Cyril_GROUIN', 'Mathieu_VALETTE', 'Ilaine_WANG', 'Benoît_CARCENAC', ['Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA'], 'Loïc_GROBOL', 'Yoann_DUPONT', 'Suppya_NUT', 'Louis_JOURDAIN', 'Alexandre_ROULOIS', 'Alexandre_ROULOIS', 'Iris_ESHKOL-TARAVELLA', 'Damien_NOUVEL', 'Hatice_AKSEN', 'Armand_STRICKER', 'Sophie_RAINERIE', '', 'Kata_GABOR', 'Caroline_BOGLIOTTI', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Marcel_CORI', 'Delphine_BATTISTELLI', 'Sylvain_KAHANE', '', 'Florence_VILLEOING', 'Armand_STRICKER', 'Karolina_KUBIK', 'Eve_SAUVAGE', 'Cedric_GENDROT', 'Natalia_LASON', ['Yoann_DUPONT', 'Pierre_MAGISTRY'], ['Yoann_DUPONT', 'Pierre_MAGISTRY'], 'Zhu_LICHAO', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Florent_JACQUEMARD', 'Florent_JACQUEMARD', 'Louis_LECAILLIEZ', 'Xibin_WANG', '', 'Pascal_AMSILI', 'Mathieu_VALETTE', 'Mathieu_VALETTE', 'Iris_ESHKOL-TARAVELLA', '', 'James_COSTA', '', 'Damien_NOUVEL', 'Cedric_GENDROT', 'Nasredine_SEMMAR', 'Marie-Paule_BONNAFOUS', 'Zhu_LICHAO', 'Damien_NOUVEL', 'Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI']
# nom_prof ['AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI', 'GROBOL', 'GROBOL', 'ESHKOL-TARAVELLA', 'PAROUBECK', ['LEHMANN', 'PICCOLI'], 'GENDROT', 'GAUMET', 'LEE', 'HERRERA', 'ZWEIGENBAUM', 'ESHKOL-TARAVELLA', 'JACOBSON', 'ABROUGUI', 'WANG', 'ESHKOL-TARAVELLA', 'MONNIN-TUILLIER', 'GROUIN', 'VALETTE', 'WANG', 'CARCENAC', ['BATTISTELLI', 'ESHKOL-TARAVELLA'], 'GROBOL', 'DUPONT', 'NUT', 'JOURDAIN', 'ROULOIS', 'ROULOIS', 'ESHKOL-TARAVELLA', 'NOUVEL', 'AKSEN', 'STRICKER', 'RAINERIE', '', 'GABOR', 'BOGLIOTTI', 'BATTISTELLI', 'GROBOL', 'CORI', 'BATTISTELLI', 'KAHANE', '', 'VILLEOING', 'STRICKER', 'KUBIK', 'SAUVAGE', 'GENDROT', 'LASON', ['DUPONT', 'MAGISTRY'], ['DUPONT', 'MAGISTRY'], 'LICHAO', '', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'JACQUEMARD', 'JACQUEMARD', 'LECAILLIEZ', 'WANG', '', 'AMSILI', 'VALETTE', 'VALETTE', 'ESHKOL-TARAVELLA', '', 'COSTA', '', 'NOUVEL', 'GENDROT', 'SEMMAR', 'BONNAFOUS', 'LICHAO', 'NOUVEL', 'AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI']
# prenom_prof ['Ons', '', 'Loulou', 'Christophe', 'Delphine', 'Loïc', 'Loïc', 'Iris', 'Patrick', ['Sabine', 'Vanessa'], 'Cedric', 'Sophie', 'Kyung', 'Santiago', 'Pierre', 'Iris', 'Michel', 'Rim', 'Ilaine', 'Iris', 'Chloé', 'Cyril', 'Mathieu', 'Ilaine', 'Benoît', ['Delphine', 'Iris'], 'Loïc', 'Yoann', 'Suppya', 'Louis', 'Alexandre', 'Alexandre', 'Iris', 'Damien', 'Hatice', 'Armand', 'Sophie', '', 'Kata', 'Caroline', 'Delphine', 'Loïc', 'Marcel', 'Delphine', 'Sylvain', '', 'Florence', 'Armand', 'Karolina', 'Eve', 'Cedric', 'Natalia', ['Yoann', 'Pierre'], ['Yoann', 'Pierre'], 'Zhu', '', 'Iris', 'Mathieu', 'Florent', 'Florent', 'Louis', 'Xibin', '', 'Pascal', 'Mathieu', 'Mathieu', 'Iris', '', 'James', '', 'Damien', 'Cedric', 'Nasredine', 'Marie-Paule', 'Zhu', 'Damien', 'Ons', '', 'Loulou', 'Christophe', 'Delphine']
# etablissement ['Inalco', 'SorbonneNouvelle', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'SorbonneNouvelle', 'Inalco', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco']
# annee ['2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2024-2025']
# id_cours ['acquisition_modelisation_representation_2024_2025', 'actualite_dans_le_monde_anglophone_2024_2025', 'anglais_de_specialite_2_2023_2024', 'anglais_pro_2024_2025', 'annotations_semantiques_et_applications_en_recherche_d_information_2024_2025', 'apprentissage_automatique_2024_2025', 'arbres_graphes_2024_2025', 'bases_de_donnees_pour_linguistes_2023_2024', 'calculabilite_2024_2025', 'changements_linguistiques_2023_2024', 'cnn_2024_2025', 'conduite_de_projet_de_traduction_1_2024_2025', 'coreen_2023_2024', 'corpus_arbores_et_parsing_2023_2024', 'corpus_paralleles_et_comparables_2023_2024', 'de_la_modelisation_au_traitement_automatique_des_donnees_linguistiques_2024_2025', 'document_structure_2023_2024', 'documents_structures_2024_2025', 'ecriture_et_multilinguisme_2024_2025', 'enrichissement_de_corpus_2023_2024', 'extraction_d_informations_2023_2024', 'fouille_de_textes_1_2024_2025', 'genres_textes_et_usages_2024_2025', 'gest__info_multilinguisme_2023_2024', 'gestion_de_projets_2024_2025', 'ingenierie_des_connaissances_2024_2025', 'interfaces_pour_le_web_2024_2025', 'introduction_a_la_fouille_de_textes_2023_2024', 'khmer_2023_2024', 'langages_de_script_(jourdain)_2024_2025', 'langages_de_script_(python_inalco)_2023_2024', 'langages_de_script_(roulois)_2024_2025', 'langages_du_web_semantique_2024_2025', 'langages_reguliers_2023_2024', 'langue_des_signes_2024_2025', 'langues_vivantes_etrangeres_2023_2024', 'large_corpus_linguistics_2023_2024', 'lexicologie_terminologie_et_dictionnairique_2024_2025', 'lexique_et_morphologie_2023_2024', 'linguistique_de_la_lsf_2023_2024', 'linguistique_outillee_et_traitements_statistiques_2024_2025', 'mathematiques_pour_le_tal_2023_2024', 'methodologie_de_la_recherche_2024_2025', 'modelisation_automatique_pour_l_analyse_de_textes_2023_2024', 'modelisation_des_langues_2024_2025', 'mooc_2023_2024', 'morphologie_2023_2024', 'nlp_in_english_2023_2024', 'outils_de_tao_1_2024_2025', 'outils_de_traitement_de_corpus_2023_2024', 'phonetique_physiologique_et_acoustique_2023_2024', 'polonais_2023_2024', 'ppe1_2023_2024', 'ppe2_2023_2024', 'pratiques_textuelles_et_traduction_2023_2024', 'principes_de_bases_de_donnees_2023_2024', 'programmation_et_algorithmique_1_2023_2024', 'programmation_et_algorithmique_2_2023_2024', 'programmation_objet_1_2023_2024', 'programmation_objet_2_2023_2024', 'programmation_orientee_objet_1_2024_2025', 'recueil_de_donnees_et_statistiques_2023_2024', 'redaction_professionnelle_2023_2024', 'semantique_computationnelle_2024_2025', 'semantique_des_textes_multilingues_1_2024_2025', 'semantique_lexicale_et_textuelle_2023_2024', 'seminaire:_tal_et_linguistique_de_corpus_2024_2025', 'sens_multiple_2023_2024', 'sociolinguistique_2023_2024', 'statistiques_2023_2024', 'statistiques_textuelles_2023_2024', 'synthese_de_la_parole_2023_2024', 'traduction_automatique_et_assistee_2024_2025', 'traduction_technique_1_2024_2025', 'traductologie_1_2024_2025']
# On cherche le cours apprentissage automatique
# nom_cours ['acquisition modelisation/representation', 'actualite dans le monde anglophone', 'anglais de specialite 2', 'anglais pro', "annotations semantiques et applications en recherche d'information", 'apprentissage automatique', 'arbres graphes', 'bases de donnees pour linguistes', 'calculabilite', 'changements linguistiques', 'cnn', 'conduite de projet de traduction 1', 'coreen', 'corpus arbores et parsing', 'corpus paralleles et comparables', 'de la modelisation au traitement automatique des donnees linguistiques', 'document structure', 'documents structures', 'ecriture et multilinguisme', 'enrichissement de corpus', "extraction d'informations", 'fouille de textes 1', 'genres textes et usages', 'gest. info multilinguisme', 'gestion de projets', 'ingenierie des connaissances', 'interfaces pour le web', 'introduction a la fouille de textes', 'khmer', 'langages de script (jourdain)', 'langages de script (python inalco)', 'langages de script (roulois)', 'langages du web semantique', 'langages reguliers', 'langue des signes', 'langues vivantes etrangeres', 'large corpus linguistics', 'lexicologie terminologie et dictionnairique', 'lexique et morphologie', 'linguistique de la lsf', 'linguistique outillee et traitements statistiques', 'mathematiques pour le tal', 'methodologie de la recherche', "modelisation automatique pour l'analyse de textes", 'modelisation des langues', 'mooc', 'morphologie', 'nlp in english', 'outils de tao 1', 'outils de traitement de corpus', 'phonetique physiologique et acoustique', 'polonais', 'ppe1', 'ppe2', 'pratiques textuelles et traduction', 'principes de bases de donnees', 'programmation et algorithmique 1', 'programmation et algorithmique 2', 'programmation objet 1', 'programmation objet 2', 'programmation orientee objet 1', 'recueil de donnees et statistiques', 'redaction professionnelle', 'semantique computationnelle', 'semantique des textes multilingues 1', 'semantique lexicale et textuelle', 'seminaire: tal et linguistique de corpus', 'sens multiple', 'sociolinguistique', 'statistiques textuelles', 'synthese de la parole', 'traduction automatique et assistee', 'traduction technique 1', 'traductologie 1', 'traitement statistique de corpus']
# id_prof ['Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Loïc_GROBOL', 'Iris_ESHKOL-TARAVELLA', 'Patrick_PAROUBECK', ['Sabine_LEHMANN', 'Vanessa_PICCOLI'], 'Cedric_GENDROT', 'Sophie_GAUMET', 'Kyung_LEE', 'Santiago_HERRERA', 'Pierre_ZWEIGENBAUM', 'Iris_ESHKOL-TARAVELLA', 'Michel_JACOBSON', 'Rim_ABROUGUI', 'Ilaine_WANG', 'Iris_ESHKOL-TARAVELLA', 'Chloé_MONNIN-TUILLIER', 'Cyril_GROUIN', 'Mathieu_VALETTE', 'Ilaine_WANG', 'Benoît_CARCENAC', ['Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA'], 'Loïc_GROBOL', 'Yoann_DUPONT', 'Suppya_NUT', 'Louis_JOURDAIN', 'Alexandre_ROULOIS', 'Alexandre_ROULOIS', 'Iris_ESHKOL-TARAVELLA', 'Damien_NOUVEL', 'Hatice_AKSEN', 'Armand_STRICKER', 'Sophie_RAINERIE', '', 'Kata_GABOR', 'Caroline_BOGLIOTTI', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Marcel_CORI', 'Delphine_BATTISTELLI', 'Sylvain_KAHANE', '', 'Florence_VILLEOING', 'Armand_STRICKER', 'Karolina_KUBIK', 'Eve_SAUVAGE', 'Cedric_GENDROT', 'Natalia_LASON', ['Yoann_DUPONT', 'Pierre_MAGISTRY'], ['Yoann_DUPONT', 'Pierre_MAGISTRY'], 'Zhu_LICHAO', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Florent_JACQUEMARD', 'Florent_JACQUEMARD', 'Louis_LECAILLIEZ', 'Xibin_WANG', '', 'Pascal_AMSILI', 'Mathieu_VALETTE', 'Mathieu_VALETTE', 'Iris_ESHKOL-TARAVELLA', '', 'James_COSTA', '', 'Damien_NOUVEL', 'Cedric_GENDROT', 'Nasredine_SEMMAR', 'Marie-Paule_BONNAFOUS', 'Zhu_LICHAO', 'Damien_NOUVEL', 'Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI', 'Loïc_GROBOL']
# nom_prof ['AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI', 'GROBOL', 'GROBOL', 'ESHKOL-TARAVELLA', 'PAROUBECK', ['LEHMANN', 'PICCOLI'], 'GENDROT', 'GAUMET', 'LEE', 'HERRERA', 'ZWEIGENBAUM', 'ESHKOL-TARAVELLA', 'JACOBSON', 'ABROUGUI', 'WANG', 'ESHKOL-TARAVELLA', 'MONNIN-TUILLIER', 'GROUIN', 'VALETTE', 'WANG', 'CARCENAC', ['BATTISTELLI', 'ESHKOL-TARAVELLA'], 'GROBOL', 'DUPONT', 'NUT', 'JOURDAIN', 'ROULOIS', 'ROULOIS', 'ESHKOL-TARAVELLA', 'NOUVEL', 'AKSEN', 'STRICKER', 'RAINERIE', '', 'GABOR', 'BOGLIOTTI', 'BATTISTELLI', 'GROBOL', 'CORI', 'BATTISTELLI', 'KAHANE', '', 'VILLEOING', 'STRICKER', 'KUBIK', 'SAUVAGE', 'GENDROT', 'LASON', ['DUPONT', 'MAGISTRY'], ['DUPONT', 'MAGISTRY'], 'LICHAO', '', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'JACQUEMARD', 'JACQUEMARD', 'LECAILLIEZ', 'WANG', '', 'AMSILI', 'VALETTE', 'VALETTE', 'ESHKOL-TARAVELLA', '', 'COSTA', '', 'NOUVEL', 'GENDROT', 'SEMMAR', 'BONNAFOUS', 'LICHAO', 'NOUVEL', 'AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI', 'GROBOL']
# prenom_prof ['Ons', '', 'Loulou', 'Christophe', 'Delphine', 'Loïc', 'Loïc', 'Iris', 'Patrick', ['Sabine', 'Vanessa'], 'Cedric', 'Sophie', 'Kyung', 'Santiago', 'Pierre', 'Iris', 'Michel', 'Rim', 'Ilaine', 'Iris', 'Chloé', 'Cyril', 'Mathieu', 'Ilaine', 'Benoît', ['Delphine', 'Iris'], 'Loïc', 'Yoann', 'Suppya', 'Louis', 'Alexandre', 'Alexandre', 'Iris', 'Damien', 'Hatice', 'Armand', 'Sophie', '', 'Kata', 'Caroline', 'Delphine', 'Loïc', 'Marcel', 'Delphine', 'Sylvain', '', 'Florence', 'Armand', 'Karolina', 'Eve', 'Cedric', 'Natalia', ['Yoann', 'Pierre'], ['Yoann', 'Pierre'], 'Zhu', '', 'Iris', 'Mathieu', 'Florent', 'Florent', 'Louis', 'Xibin', '', 'Pascal', 'Mathieu', 'Mathieu', 'Iris', '', 'James', '', 'Damien', 'Cedric', 'Nasredine', 'Marie-Paule', 'Zhu', 'Damien', 'Ons', '', 'Loulou', 'Christophe', 'Delphine', 'Loïc']
# etablissement ['Inalco', 'SorbonneNouvelle', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'SorbonneNouvelle', 'Inalco', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco']
# ...
# On cherche le cours traitement statistique de corpus
# nom_cours ['acquisition modelisation/representation', 'actualite dans le monde anglophone', 'anglais de specialite 2', 'anglais pro', "annotations semantiques et applications en recherche d'information", 'apprentissage automatique', 'arbres graphes', 'bases de donnees pour linguistes', 'calculabilite', 'changements linguistiques', 'cnn', 'conduite de projet de traduction 1', 'coreen', 'corpus arbores et parsing', 'corpus paralleles et comparables', 'de la modelisation au traitement automatique des donnees linguistiques', 'document structure', 'documents structures', 'ecriture et multilinguisme', 'enrichissement de corpus', "extraction d'informations", 'fouille de textes 1', 'genres textes et usages', 'gest. info multilinguisme', 'gestion de projets', 'ingenierie des connaissances', 'interfaces pour le web', 'introduction a la fouille de textes', 'khmer', 'langages de script (jourdain)', 'langages de script (python inalco)', 'langages de script (roulois)', 'langages du web semantique', 'langages reguliers', 'langue des signes', 'langues vivantes etrangeres', 'large corpus linguistics', 'lexicologie terminologie et dictionnairique', 'lexique et morphologie', 'linguistique de la lsf', 'linguistique outillee et traitements statistiques', 'mathematiques pour le tal', 'methodologie de la recherche', "modelisation automatique pour l'analyse de textes", 'modelisation des langues', 'mooc', 'morphologie', 'nlp in english', 'outils de tao 1', 'outils de traitement de corpus', 'phonetique physiologique et acoustique', 'polonais', 'ppe1', 'ppe2', 'pratiques textuelles et traduction', 'principes de bases de donnees', 'programmation et algorithmique 1', 'programmation et algorithmique 2', 'programmation objet 1', 'programmation objet 2', 'programmation orientee objet 1', 'recueil de donnees et statistiques', 'redaction professionnelle', 'semantique computationnelle', 'semantique des textes multilingues 1', 'semantique lexicale et textuelle', 'seminaire: tal et linguistique de corpus', 'sens multiple', 'sociolinguistique', 'statistiques textuelles', 'synthese de la parole', 'traduction automatique et assistee', 'traduction technique 1', 'traductologie 1', 'traitement statistique de corpus']
# id_prof ['Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Loïc_GROBOL', 'Iris_ESHKOL-TARAVELLA', 'Patrick_PAROUBECK', ['Sabine_LEHMANN', 'Vanessa_PICCOLI'], 'Cedric_GENDROT', 'Sophie_GAUMET', 'Kyung_LEE', 'Santiago_HERRERA', 'Pierre_ZWEIGENBAUM', 'Iris_ESHKOL-TARAVELLA', 'Michel_JACOBSON', 'Rim_ABROUGUI', 'Ilaine_WANG', 'Iris_ESHKOL-TARAVELLA', 'Chloé_MONNIN-TUILLIER', 'Cyril_GROUIN', 'Mathieu_VALETTE', 'Ilaine_WANG', 'Benoît_CARCENAC', ['Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA'], 'Loïc_GROBOL', 'Yoann_DUPONT', 'Suppya_NUT', 'Louis_JOURDAIN', 'Alexandre_ROULOIS', 'Alexandre_ROULOIS', 'Iris_ESHKOL-TARAVELLA', 'Damien_NOUVEL', 'Hatice_AKSEN', 'Armand_STRICKER', 'Sophie_RAINERIE', '', 'Kata_GABOR', 'Caroline_BOGLIOTTI', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Marcel_CORI', 'Delphine_BATTISTELLI', 'Sylvain_KAHANE', '', 'Florence_VILLEOING', 'Armand_STRICKER', 'Karolina_KUBIK', 'Eve_SAUVAGE', 'Cedric_GENDROT', 'Natalia_LASON', ['Yoann_DUPONT', 'Pierre_MAGISTRY'], ['Yoann_DUPONT', 'Pierre_MAGISTRY'], 'Zhu_LICHAO', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Florent_JACQUEMARD', 'Florent_JACQUEMARD', 'Louis_LECAILLIEZ', 'Xibin_WANG', '', 'Pascal_AMSILI', 'Mathieu_VALETTE', 'Mathieu_VALETTE', 'Iris_ESHKOL-TARAVELLA', '', 'James_COSTA', '', 'Damien_NOUVEL', 'Cedric_GENDROT', 'Nasredine_SEMMAR', 'Marie-Paule_BONNAFOUS', 'Zhu_LICHAO', 'Damien_NOUVEL', 'Ons_AOUINA', '', 'Loulou_KOSMALA', 'Christophe_HUP', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Loïc_GROBOL', 'Iris_ESHKOL-TARAVELLA', 'Patrick_PAROUBECK', ['Sabine_LEHMANN', 'Vanessa_PICCOLI'], 'Cedric_GENDROT', 'Sophie_GAUMET', 'Kyung_LEE', 'Santiago_HERRERA', 'Pierre_ZWEIGENBAUM', 'Iris_ESHKOL-TARAVELLA', 'Michel_JACOBSON', 'Rim_ABROUGUI', 'Ilaine_WANG', 'Iris_ESHKOL-TARAVELLA', 'Chloé_MONNIN-TUILLIER', 'Cyril_GROUIN', 'Mathieu_VALETTE', 'Ilaine_WANG', 'Benoît_CARCENAC', ['Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA'], 'Loïc_GROBOL', 'Yoann_DUPONT', 'Suppya_NUT', 'Louis_JOURDAIN', 'Alexandre_ROULOIS', 'Alexandre_ROULOIS', 'Iris_ESHKOL-TARAVELLA', 'Damien_NOUVEL', 'Hatice_AKSEN', 'Armand_STRICKER', 'Sophie_RAINERIE', '', 'Kata_GABOR', 'Caroline_BOGLIOTTI', 'Delphine_BATTISTELLI', 'Loïc_GROBOL', 'Marcel_CORI', 'Delphine_BATTISTELLI', 'Sylvain_KAHANE', '', 'Florence_VILLEOING', 'Armand_STRICKER', 'Karolina_KUBIK', 'Eve_SAUVAGE', 'Cedric_GENDROT', 'Natalia_LASON', ['Yoann_DUPONT', 'Pierre_MAGISTRY'], ['Yoann_DUPONT', 'Pierre_MAGISTRY'], 'Zhu_LICHAO', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Florent_JACQUEMARD', 'Florent_JACQUEMARD', 'Louis_LECAILLIEZ', 'Xibin_WANG', '', 'Pascal_AMSILI', 'Mathieu_VALETTE', 'Mathieu_VALETTE', 'Iris_ESHKOL-TARAVELLA', '', 'James_COSTA', 'Damien_NOUVEL', 'Cedric_GENDROT', 'Nasredine_SEMMAR', 'Marie-Paule_BONNAFOUS', 'Zhu_LICHAO', 'Damien_NOUVEL']
# nom_prof ['AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI', 'GROBOL', 'GROBOL', 'ESHKOL-TARAVELLA', 'PAROUBECK', ['LEHMANN', 'PICCOLI'], 'GENDROT', 'GAUMET', 'LEE', 'HERRERA', 'ZWEIGENBAUM', 'ESHKOL-TARAVELLA', 'JACOBSON', 'ABROUGUI', 'WANG', 'ESHKOL-TARAVELLA', 'MONNIN-TUILLIER', 'GROUIN', 'VALETTE', 'WANG', 'CARCENAC', ['BATTISTELLI', 'ESHKOL-TARAVELLA'], 'GROBOL', 'DUPONT', 'NUT', 'JOURDAIN', 'ROULOIS', 'ROULOIS', 'ESHKOL-TARAVELLA', 'NOUVEL', 'AKSEN', 'STRICKER', 'RAINERIE', '', 'GABOR', 'BOGLIOTTI', 'BATTISTELLI', 'GROBOL', 'CORI', 'BATTISTELLI', 'KAHANE', '', 'VILLEOING', 'STRICKER', 'KUBIK', 'SAUVAGE', 'GENDROT', 'LASON', ['DUPONT', 'MAGISTRY'], ['DUPONT', 'MAGISTRY'], 'LICHAO', '', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'JACQUEMARD', 'JACQUEMARD', 'LECAILLIEZ', 'WANG', '', 'AMSILI', 'VALETTE', 'VALETTE', 'ESHKOL-TARAVELLA', '', 'COSTA', '', 'NOUVEL', 'GENDROT', 'SEMMAR', 'BONNAFOUS', 'LICHAO', 'NOUVEL', 'AOUINA', '', 'KOSMALA', 'HUP', 'BATTISTELLI', 'GROBOL', 'GROBOL', 'ESHKOL-TARAVELLA', 'PAROUBECK', ['LEHMANN', 'PICCOLI'], 'GENDROT', 'GAUMET', 'LEE', 'HERRERA', 'ZWEIGENBAUM', 'ESHKOL-TARAVELLA', 'JACOBSON', 'ABROUGUI', 'WANG', 'ESHKOL-TARAVELLA', 'MONNIN-TUILLIER', 'GROUIN', 'VALETTE', 'WANG', 'CARCENAC', ['BATTISTELLI', 'ESHKOL-TARAVELLA'], 'GROBOL', 'DUPONT', 'NUT', 'JOURDAIN', 'ROULOIS', 'ROULOIS', 'ESHKOL-TARAVELLA', 'NOUVEL', 'AKSEN', 'STRICKER', 'RAINERIE', '', 'GABOR', 'BOGLIOTTI', 'BATTISTELLI', 'GROBOL', 'CORI', 'BATTISTELLI', 'KAHANE', '', 'VILLEOING', 'STRICKER', 'KUBIK', 'SAUVAGE', 'GENDROT', 'LASON', ['DUPONT', 'MAGISTRY'], ['DUPONT', 'MAGISTRY'], 'LICHAO', '', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'JACQUEMARD', 'JACQUEMARD', 'LECAILLIEZ', 'WANG', '', 'AMSILI', 'VALETTE', 'VALETTE', 'ESHKOL-TARAVELLA', '', 'COSTA', 'NOUVEL', 'GENDROT', 'SEMMAR', 'BONNAFOUS', 'LICHAO', 'NOUVEL']
# prenom_prof ['Ons', '', 'Loulou', 'Christophe', 'Delphine', 'Loïc', 'Loïc', 'Iris', 'Patrick', ['Sabine', 'Vanessa'], 'Cedric', 'Sophie', 'Kyung', 'Santiago', 'Pierre', 'Iris', 'Michel', 'Rim', 'Ilaine', 'Iris', 'Chloé', 'Cyril', 'Mathieu', 'Ilaine', 'Benoît', ['Delphine', 'Iris'], 'Loïc', 'Yoann', 'Suppya', 'Louis', 'Alexandre', 'Alexandre', 'Iris', 'Damien', 'Hatice', 'Armand', 'Sophie', '', 'Kata', 'Caroline', 'Delphine', 'Loïc', 'Marcel', 'Delphine', 'Sylvain', '', 'Florence', 'Armand', 'Karolina', 'Eve', 'Cedric', 'Natalia', ['Yoann', 'Pierre'], ['Yoann', 'Pierre'], 'Zhu', '', 'Iris', 'Mathieu', 'Florent', 'Florent', 'Louis', 'Xibin', '', 'Pascal', 'Mathieu', 'Mathieu', 'Iris', '', 'James', '', 'Damien', 'Cedric', 'Nasredine', 'Marie-Paule', 'Zhu', 'Damien', 'Ons', '', 'Loulou', 'Christophe', 'Delphine', 'Loïc', 'Loïc', 'Iris', 'Patrick', ['Sabine', 'Vanessa'], 'Cedric', 'Sophie', 'Kyung', 'Santiago', 'Pierre', 'Iris', 'Michel', 'Rim', 'Ilaine', 'Iris', 'Chloé', 'Cyril', 'Mathieu', 'Ilaine', 'Benoît', ['Delphine', 'Iris'], 'Loïc', 'Yoann', 'Suppya', 'Louis', 'Alexandre', 'Alexandre', 'Iris', 'Damien', 'Hatice', 'Armand', 'Sophie', '', 'Kata', 'Caroline', 'Delphine', 'Loïc', 'Marcel', 'Delphine', 'Sylvain', '', 'Florence', 'Armand', 'Karolina', 'Eve', 'Cedric', 'Natalia', ['Yoann', 'Pierre'], ['Yoann', 'Pierre'], 'Zhu', '', 'Iris', 'Mathieu', 'Florent', 'Florent', 'Louis', 'Xibin', '', 'Pascal', 'Mathieu', 'Mathieu', 'Iris', '', 'James', 'Damien', 'Cedric', 'Nasredine', 'Marie-Paule', 'Zhu', 'Damien']
# etablissement ['Inalco', 'SorbonneNouvelle', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Nanterre', 'Inalco', 'Nanterre', 'Inalco', 'Inalco', 'Inalco', 'SorbonneNouvelle', 'Inalco', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Nanterre', 'SorbonneNouvelle', 'SorbonneNouvelle', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco', 'Inalco']
# annee ['2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2023-2024', '2024-2025', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2023-2024', '2024-2025', '2024-2025', '2024-2025']
# id_cours ['acquisition_modelisation_representation_2024_2025', 'actualite_dans_le_monde_anglophone_2024_2025', 'anglais_de_specialite_2_2023_2024', 'anglais_pro_2024_2025', 'annotations_semantiques_et_applications_en_recherche_d_information_2024_2025', 'apprentissage_automatique_2024_2025', 'arbres_graphes_2024_2025', 'bases_de_donnees_pour_linguistes_2023_2024', 'calculabilite_2024_2025', 'changements_linguistiques_2023_2024', 'cnn_2024_2025', 'conduite_de_projet_de_traduction_1_2024_2025', 'coreen_2023_2024', 'corpus_arbores_et_parsing_2023_2024', 'corpus_paralleles_et_comparables_2023_2024', 'de_la_modelisation_au_traitement_automatique_des_donnees_linguistiques_2024_2025', 'document_structure_2023_2024', 'documents_structures_2024_2025', 'ecriture_et_multilinguisme_2024_2025', 'enrichissement_de_corpus_2023_2024', 'extraction_d_informations_2023_2024', 'fouille_de_textes_1_2024_2025', 'genres_textes_et_usages_2024_2025', 'gest__info_multilinguisme_2023_2024', 'gestion_de_projets_2024_2025', 'ingenierie_des_connaissances_2024_2025', 'interfaces_pour_le_web_2024_2025', 'introduction_a_la_fouille_de_textes_2023_2024', 'khmer_2023_2024', 'langages_de_script_(jourdain)_2024_2025', 'langages_de_script_(python_inalco)_2023_2024', 'langages_de_script_(roulois)_2024_2025', 'langages_du_web_semantique_2024_2025', 'langages_reguliers_2023_2024', 'langue_des_signes_2024_2025', 'langues_vivantes_etrangeres_2023_2024', 'large_corpus_linguistics_2023_2024', 'lexicologie_terminologie_et_dictionnairique_2024_2025', 'lexique_et_morphologie_2023_2024', 'linguistique_de_la_lsf_2023_2024', 'linguistique_outillee_et_traitements_statistiques_2024_2025', 'mathematiques_pour_le_tal_2023_2024', 'methodologie_de_la_recherche_2024_2025', 'modelisation_automatique_pour_l_analyse_de_textes_2023_2024', 'modelisation_des_langues_2024_2025', 'mooc_2023_2024', 'morphologie_2023_2024', 'nlp_in_english_2023_2024', 'outils_de_tao_1_2024_2025', 'outils_de_traitement_de_corpus_2023_2024', 'phonetique_physiologique_et_acoustique_2023_2024', 'polonais_2023_2024', 'ppe1_2023_2024', 'ppe2_2023_2024', 'pratiques_textuelles_et_traduction_2023_2024', 'principes_de_bases_de_donnees_2023_2024', 'programmation_et_algorithmique_1_2023_2024', 'programmation_et_algorithmique_2_2023_2024', 'programmation_objet_1_2023_2024', 'programmation_objet_2_2023_2024', 'programmation_orientee_objet_1_2024_2025', 'recueil_de_donnees_et_statistiques_2023_2024', 'redaction_professionnelle_2023_2024', 'semantique_computationnelle_2024_2025', 'semantique_des_textes_multilingues_1_2024_2025', 'semantique_lexicale_et_textuelle_2023_2024', 'seminaire:_tal_et_linguistique_de_corpus_2024_2025', 'sens_multiple_2023_2024', 'sociolinguistique_2023_2024', 'statistiques_2023_2024', 'statistiques_textuelles_2023_2024', 'synthese_de_la_parole_2023_2024', 'traduction_automatique_et_assistee_2024_2025', 'traduction_technique_1_2024_2025', 'traductologie_1_2024_2025']

# %%
cours = dico_cours["nom_cours"]
profs_noms = dico_cours["nom_prof"]
profs_prenoms = dico_cours["prenom_prof"]
id_profs = dico_cours["id_prof"]

for cour, nom, prenom, id_p in zip(cours, profs_noms, profs_prenoms, id_profs):
    print(cour, nom, prenom, id_p)
# Out:
# acquisition modelisation/representation AOUINA Ons Ons_AOUINA
# actualite dans le monde anglophone
# anglais de specialite 2 KOSMALA Loulou Loulou_KOSMALA
# anglais pro HUP Christophe Christophe_HUP
# annotations semantiques et applications en recherche d'information BATTISTELLI Delphine Delphine_BATTISTELLI
# apprentissage automatique GROBOL Loïc Loïc_GROBOL
# arbres graphes GROBOL Loïc Loïc_GROBOL
# bases de donnees pour linguistes ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# calculabilite PAROUBECK Patrick Patrick_PAROUBECK
# changements linguistiques ['LEHMANN', 'PICCOLI'] ['Sabine', 'Vanessa'] ['Sabine_LEHMANN', 'Vanessa_PICCOLI']
# cnn GENDROT Cedric Cedric_GENDROT
# conduite de projet de traduction 1 GAUMET Sophie Sophie_GAUMET
# coreen LEE Kyung Kyung_LEE
# corpus arbores et parsing HERRERA Santiago Santiago_HERRERA
# corpus paralleles et comparables ZWEIGENBAUM Pierre Pierre_ZWEIGENBAUM
# de la modelisation au traitement automatique des donnees linguistiques ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# document structure JACOBSON Michel Michel_JACOBSON
# documents structures ABROUGUI Rim Rim_ABROUGUI
# ecriture et multilinguisme WANG Ilaine Ilaine_WANG
# enrichissement de corpus ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# extraction d'informations MONNIN-TUILLIER Chloé Chloé_MONNIN-TUILLIER
# fouille de textes 1 GROUIN Cyril Cyril_GROUIN
# genres textes et usages VALETTE Mathieu Mathieu_VALETTE
# gest. info multilinguisme WANG Ilaine Ilaine_WANG
# gestion de projets CARCENAC Benoît Benoît_CARCENAC
# ingenierie des connaissances ['BATTISTELLI', 'ESHKOL-TARAVELLA'] ['Delphine', 'Iris'] ['Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA']
# interfaces pour le web GROBOL Loïc Loïc_GROBOL
# introduction a la fouille de textes DUPONT Yoann Yoann_DUPONT
# khmer NUT Suppya Suppya_NUT
# langages de script (jourdain) JOURDAIN Louis Louis_JOURDAIN
# langages de script (python inalco) ROULOIS Alexandre Alexandre_ROULOIS
# langages de script (roulois) ROULOIS Alexandre Alexandre_ROULOIS
# langages du web semantique ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# langages reguliers NOUVEL Damien Damien_NOUVEL
# langue des signes AKSEN Hatice Hatice_AKSEN
# langues vivantes etrangeres STRICKER Armand Armand_STRICKER
# large corpus linguistics RAINERIE Sophie Sophie_RAINERIE
# lexicologie terminologie et dictionnairique
# lexique et morphologie GABOR Kata Kata_GABOR
# linguistique de la lsf BOGLIOTTI Caroline Caroline_BOGLIOTTI
# linguistique outillee et traitements statistiques BATTISTELLI Delphine Delphine_BATTISTELLI
# mathematiques pour le tal GROBOL Loïc Loïc_GROBOL
# methodologie de la recherche CORI Marcel Marcel_CORI
# modelisation automatique pour l'analyse de textes BATTISTELLI Delphine Delphine_BATTISTELLI
# modelisation des langues KAHANE Sylvain Sylvain_KAHANE
# mooc
# morphologie VILLEOING Florence Florence_VILLEOING
# nlp in english STRICKER Armand Armand_STRICKER
# outils de tao 1 KUBIK Karolina Karolina_KUBIK
# outils de traitement de corpus SAUVAGE Eve Eve_SAUVAGE
# phonetique physiologique et acoustique GENDROT Cedric Cedric_GENDROT
# polonais LASON Natalia Natalia_LASON
# ppe1 ['DUPONT', 'MAGISTRY'] ['Yoann', 'Pierre'] ['Yoann_DUPONT', 'Pierre_MAGISTRY']
# ppe2 ['DUPONT', 'MAGISTRY'] ['Yoann', 'Pierre'] ['Yoann_DUPONT', 'Pierre_MAGISTRY']
# pratiques textuelles et traduction LICHAO Zhu Zhu_LICHAO
# principes de bases de donnees
# programmation et algorithmique 1 ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# programmation et algorithmique 2 DEHOUCK Mathieu Mathieu_DEHOUCK
# programmation objet 1 JACQUEMARD Florent Florent_JACQUEMARD
# programmation objet 2 JACQUEMARD Florent Florent_JACQUEMARD
# programmation orientee objet 1 LECAILLIEZ Louis Louis_LECAILLIEZ
# recueil de donnees et statistiques WANG Xibin Xibin_WANG
# redaction professionnelle
# semantique computationnelle AMSILI Pascal Pascal_AMSILI
# semantique des textes multilingues 1 VALETTE Mathieu Mathieu_VALETTE
# semantique lexicale et textuelle VALETTE Mathieu Mathieu_VALETTE
# seminaire: tal et linguistique de corpus ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# sens multiple
# sociolinguistique COSTA James James_COSTA
# statistiques textuelles
# synthese de la parole NOUVEL Damien Damien_NOUVEL
# traduction automatique et assistee GENDROT Cedric Cedric_GENDROT
# traduction technique 1 SEMMAR Nasredine Nasredine_SEMMAR
# traductologie 1 BONNAFOUS Marie-Paule Marie-Paule_BONNAFOUS
# traitement statistique de corpus LICHAO Zhu Zhu_LICHAO

# %%
### ON AJOUTE LA COLONNE ANNEE ET ÉTABLISSEMENT À LA DF COURS

# %%
dico_cours["annee"] = ["2024-2025", "2024-2025", "2023-2024", "2024-2025", "2024-2025", "2024-2025", "2024-2025", "2023-2024", "2024-2025", "2023-2024", "2024-2025", "2024-2025", "2023-2024", "2023-2024", "2023-2024", "2024-2025", "2023-2024", "2024-2025", "2024-2025", "2023-2024", "2023-2024", "2024-2025", "2024-2025", "2023-2024", "2024-2025", "2024-2025", "2024-2025", "2023-2024", "2023-2024", "2024-2025", "2023-2024", "2024-2025", "2024-2025", "2023-2024", "2024-2025", "2023-2024", "2023-2024", "2024-2025", "2023-2024", "2023-2024", "2024-2025", "2023-2024", "2024-2025", "2023-2024", "2024-2025", "2023-2024", "2023-2024", "2023-2024", "2024-2025", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2024-2025", "2023-2024", "2023-2024", "2024-2025", "2024-2025", "2023-2024", "2024-2025", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2023-2024", "2024-2025", "2024-2025", "2024-2025"]
dico_cours["etablissement"] = ["Inalco", "SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "Nanterre", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "Inalco", "Nanterre", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Inalco", "Nanterre", "Nanterre", "Nanterre", "SorbonneNouvelle", "Inalco", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Nanterre", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Inalco", "SorbonneNouvelle", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "SorbonneNouvelle", "Inalco", "Inalco", "Inalco", "Nanterre", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "SorbonneNouvelle", "SorbonneNouvelle", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco"]

print(len(dico_cours["annee"]), len(dico_cours["nom_cours"]), len(dico_cours["nom_prof"]), len(dico_cours["prenom_prof"]), len(dico_cours["id_prof"]), len(dico_cours["etablissement"]))
# Out:
# 75 75 151 151 151 75

# %%
### ON AJOUTE UNE COLONNE ID_COURS À LA DF COURS

# %%
noms_cours = dico_cours["nom_cours"]
annees_cours = dico_cours["annee"]

id_cours = []

for nom, annee in zip(noms_cours, annees_cours):
    nom_very_clean = nom.replace(" ", "_").replace("'", "_").replace("/", "_").replace(".", "_")
    annee_very_clean = annee.replace("-", "_")
    id_cours.append(f"{nom_very_clean}_{annee_very_clean}")


dico_cours["id_cours"] = id_cours
print(dico_cours["id_cours"])
# Out:
# ['acquisition_modelisation_representation_2024_2025', 'actualite_dans_le_monde_anglophone_2024_2025', 'anglais_de_specialite_2_2023_2024', 'anglais_pro_2024_2025', 'annotations_semantiques_et_applications_en_recherche_d_information_2024_2025', 'apprentissage_automatique_2024_2025', 'arbres_graphes_2024_2025', 'bases_de_donnees_pour_linguistes_2023_2024', 'calculabilite_2024_2025', 'changements_linguistiques_2023_2024', 'cnn_2024_2025', 'conduite_de_projet_de_traduction_1_2024_2025', 'coreen_2023_2024', 'corpus_arbores_et_parsing_2023_2024', 'corpus_paralleles_et_comparables_2023_2024', 'de_la_modelisation_au_traitement_automatique_des_donnees_linguistiques_2024_2025', 'document_structure_2023_2024', 'documents_structures_2024_2025', 'ecriture_et_multilinguisme_2024_2025', 'enrichissement_de_corpus_2023_2024', 'extraction_d_informations_2023_2024', 'fouille_de_textes_1_2024_2025', 'genres_textes_et_usages_2024_2025', 'gest__info_multilinguisme_2023_2024', 'gestion_de_projets_2024_2025', 'ingenierie_des_connaissances_2024_2025', 'interfaces_pour_le_web_2024_2025', 'introduction_a_la_fouille_de_textes_2023_2024', 'khmer_2023_2024', 'langages_de_script_(jourdain)_2024_2025', 'langages_de_script_(python_inalco)_2023_2024', 'langages_de_script_(roulois)_2024_2025', 'langages_du_web_semantique_2024_2025', 'langages_reguliers_2023_2024', 'langue_des_signes_2024_2025', 'langues_vivantes_etrangeres_2023_2024', 'large_corpus_linguistics_2023_2024', 'lexicologie_terminologie_et_dictionnairique_2024_2025', 'lexique_et_morphologie_2023_2024', 'linguistique_de_la_lsf_2023_2024', 'linguistique_outillee_et_traitements_statistiques_2024_2025', 'mathematiques_pour_le_tal_2023_2024', 'methodologie_de_la_recherche_2024_2025', 'modelisation_automatique_pour_l_analyse_de_textes_2023_2024', 'modelisation_des_langues_2024_2025', 'mooc_2023_2024', 'morphologie_2023_2024', 'nlp_in_english_2023_2024', 'outils_de_tao_1_2024_2025', 'outils_de_traitement_de_corpus_2023_2024', 'phonetique_physiologique_et_acoustique_2023_2024', 'polonais_2023_2024', 'ppe1_2023_2024', 'ppe2_2023_2024', 'pratiques_textuelles_et_traduction_2023_2024', 'principes_de_bases_de_donnees_2023_2024', 'programmation_et_algorithmique_1_2023_2024', 'programmation_et_algorithmique_2_2023_2024', 'programmation_objet_1_2023_2024', 'programmation_objet_2_2023_2024', 'programmation_orientee_objet_1_2024_2025', 'recueil_de_donnees_et_statistiques_2023_2024', 'redaction_professionnelle_2023_2024', 'semantique_computationnelle_2024_2025', 'semantique_des_textes_multilingues_1_2024_2025', 'semantique_lexicale_et_textuelle_2023_2024', 'seminaire:_tal_et_linguistique_de_corpus_2024_2025', 'sens_multiple_2023_2024', 'sociolinguistique_2023_2024', 'statistiques_2023_2024', 'statistiques_textuelles_2023_2024', 'synthese_de_la_parole_2023_2024', 'traduction_automatique_et_assistee_2024_2025', 'traduction_technique_1_2024_2025', 'traductologie_1_2024_2025']

# %%
# ON ENREGISTRE LA DF COURS

# %%
df_cours = pd.DataFrame(dico_cours)
df_cours.to_csv("df_cours.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_cours = pd.DataFrame(dico_cours)
#       2 df_cours.to_csv("df_cours.csv", index=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# # POUR AJOUTER LES COURS SUIVIS DANS LA DATAFRAME ELEVES

# %%
df_eleves = pd.read_csv("dataframe_eleves.csv")
print(df_eleves.head())
# Out:
#                       id      prenom             nom  \
# 0          Pauline_DÉGEZ     Pauline           DÉGEZ
# 1      Perrine_QUENNEHEN     Perrine       QUENNEHEN
# 2          Ashley_RATIER      Ashley          RATIER
# 3       Valentine_FLEITH  Valentine           FLEITH
# 4  Débora_VAN_DEN_ZANDE       Débora  VAN-DEN-ZANDE
#
#                                           genre date_naissance nationalite  \
# 0                                         Femme     10/04/1988          FR
# 1                                         Femme     14/02/1997          FR
# 2                                         Femme     24/11/1998          FR
# 3  Morphologie, Recueil de données statistiques     06/07/2001          FR
# 4                                         Femme     13/04/2002          FR
#
#   redoublement     inscription_M1                      parcours_M2  \
# 0          non           Nanterre            Alternance (Nanterre)
# 1          non             INALCO  Ingénierie Multilingue (INALCO)
# 2          non           Nanterre            Alternance (Nanterre)
# 3          non  Sorbonne-Nouvelle            Alternance (Nanterre)
# 4          non  Sorbonne-Nouvelle            Alternance (Nanterre)
#
#   tiers_temps  ... difficulte_RD difficulte_tetradom  \
# 0         non  ...           NaN                 NaN
# 1         non  ...           NaN                 4.0
# 2         non  ...           NaN                 NaN
# 3         non  ...           NaN                 NaN
# 4         non  ...           NaN                 NaN
#
#                                    jeter_linux  \
# 0                                    Ça arrive
# 1                                          NaN
# 2                                          NaN
# 3  Non rien à dire moi et Linux on est besties
# 4                                TOUT LE TEMPS
#
#                                    jeter_mac admin_nanterre admin_sorbonne  \
# 0                                        NaN            4.0            NaN
# 1                                  Ça arrive            NaN            NaN
# 2  Non rien à dire moi et Mac on est besties            3.0            NaN
# 3                                        NaN            3.0            1.0
# 4                                        NaN            3.0            3.0
#
#   admin_inalco                                 conseil_eleve  \
# 0          NaN  Morphologie, Recueil de données statistiques
# 1          4.0                                           NaN
# 2          NaN                                           NaN
# 3          4.0                                 Ne venez pas
# 4          NaN                                  Ne pas venir
#
#           recommandation                                       conseil_prof
# 0                    NaN  Parlez vous pour vous coordonner (surtout quan...
# 1                    NaN                                                NaN
# 2  À VOTRE ENNEMI JURÉ !                                                NaN
# 3            À personne.                                  Fermez le master
# 4            À personne.                       EMBAUCHEZ DES GENS QUALIFIES
#
# [5 rows x 41 columns]

# %%
formulaire.columns
# Out:
# Index(['Horodateur', 'Score', 'Nom de famille', 'Prénom', 'Genre',
#        'Date de naissance', 'Nationalité',
#        'Avez-vous redoublé le master ? Si oui, indiquez quelle année et quel niveau. ',
#        'Dans quelle université étiez-vous inscrits au M1 ? ',
#        'Dans quel parcours êtes-vous inscrits au M2 ?',
#        'Disposez vous ou avez-vous disposé d'un aménagement handicap pour le master (tiers-temps, autres...) ?',
#        'Si vous êtes inscrits (ou avez été inscrits) dans un autre établissement pendant le master, indiquez lequel :\n\nExemple :\nÉtudiant en M2 TAL Ingénierie Multilingue et à 42 en même temps.',
#        'Si vous avez obtenu un baccalauréat français, quelle était votre filière : ',
#        'Indiquez si cette licence appartient à l'une des mentions suivantes :',
#        'Avez-vous déjà un master ?\nSi oui, veuillez indiquer son nom original (langue d'origine) au format :\nNOM, UNIVERSITÉ\n\nExemple:\nMaster Linguistique Anglaise, Université Sorbonne Nouvelle',
#        'Si vous travaillez (ou avez travaillé) pendant le master, indiquez sur quel poste (hors stage TAL) :\n\nExemple :\nActuellement employé polyvalent à Décathlon.',
#        'Si vous avez exercé une activité professionnelle de longue durée avant le master (reconversion, reprise d'études ou autres), indiquez laquelle :\n\nExemple:\nProfesseure à l'alliance française de Bogotá. ',
#        'Avez-vous eu un premier stage en NLP pendant le M1 ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?',
#        'Quel était le nom de l'organisme d'accueil ? ',
#        'Quelle était la durée du stage ?', 'Quel était le sujet du stage ?',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :',
#        'Avez-vous eu un second stage en NLP pendant le M1 ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?.1',
#        'Quel était le nom de l'organisme d'accueil ? .1',
#        'Quelle était la durée du stage ?.1',
#        'Quel était le sujet du stage ?.1',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :.1',
#        'Avez-vous eu un stage en NLP pendant le M2 (hors celui du second semestre à venir) ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?.2',
#        'Quel était le nom de l'organisme d'accueil ? .2',
#        'Quelle était la durée du stage ?.2',
#        'Quel était le sujet du stage ?.2',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :.2',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M1 numéro 1',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M1 numéro 2',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M2',
#        'Pour les M2 en parcours recherche, IM ou TETRADOM, avez-vous déjà trouvé un stage ?',
#        'Si oui, serez-vous en entreprise, laboratoire ou autre ?',
#        'Quel est le nom de l'organisme d'accueil ?',
#        'Quelle sera la durée du stage ?',
#        'Pour les M2 en parcours recherche, le sujet de votre mémoire est-il lié à votre stage de M2 ?',
#        'Pour les M2 en parcours recherche, si vous le connaissez déjà, quel est le sujet de votre mémoire ?',
#        'Pour les M2 en parcours recherche, si vous les connaissez déjà, qui sont vos directeurs de mémoire ? ',
#        'Pour les M2 en parcours alternance, avez-vous trouvé une alternance, un stage, ou autre ?',
#        'Pour les M2 en parcours alternance ayant trouvé une alternance, dans quel organisme êtes-vous ?',
#        'Quelle sont vos missions ?',
#        'Pour les M2 en parcours alternance ayant trouvé un stage, dans quel organisme êtes-vous/serez-vous ?',
#        'Quelle est/sera la durée du stage ?',
#        'Quelles sont/seront vos missions ?',
#        'Quels cours avez-vous suivis au premier semestre du M1 ?',
#        'Quelles ont été vos options de linguistique au premier semestre du M1 ?\nSéparer les cours par des virgules. ',
#        'Avons-nous oublié quelque cours au premier semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels cours avez-vous suivis au second semestre du M1 ?',
#        'Avons-nous oublié quelque cours au second semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels cours avez-vous suivis au premier semestre du M2 ?',
#        'Avons-nous oublié quelque cours au premier semestre du M2 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels sont vos sujets préférés en cours ? ',
#        'Quelle(s) modalité(s) d'évaluation préférez-vous ?',
#        'Quel aspect aimeriez-vous voir plus mis en avant pendant le master ? Ça peut être un sujet en particulier, des compétences spécifiques ou autre.',
#        'Qui est votre ennemi juré dans le master parmi les élèves (soyez pas sérieux c'est pour rigoler) ? ',
#        'Sur combien notez-vous votre santé mentale avant le master ?',
#        'Sur combien notez-vous votre santé mentale après le master ? ',
#        'À quelle fréquence pleurez-vous à cause du master ?\nex: x/mois ou x/semaine ou x/jour ...',
#        'Combien d'heures par nuit dormez-vous en moyenne ?',
#        'Sur combien notez-vous la difficulté du M1 ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Recherche et Développement ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Alternance ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Ingénierie Multilingue ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Technologies de la Traduction et Traitement des Données Multilingues ?',
#        'Pour les adeptes de Linux, voulez-vous régulièrement jeter votre ordinateur par la fenêtre ?',
#        'Pour les adeptes de Mac, voulez-vous régulièrement jeter votre ordinateur par la fenêtre ?',
#        'Si vous deviez élire le meilleur cours de tout le master, lequel choisiriez-vous ? ',
#        'Pour les étudiants de Nanterre, sur combien notez-vous l'efficacité de votre administration ?',
#        'Pour les étudiants de la Sorbonne-Nouvelle, sur combien notez-vous l'efficacité de votre administration ?',
#        'Pour les étudiants de l'INALCO, sur combien notez-vous l'efficacité de votre administration ?',
#        'Quel conseil donneriez-vous aux futurs élèves pour survivre au master TAL ?',
#        'À qui recommanderiez-vous le master TAL ?',
#        'Quel conseil donneriez-vous aux professeurs du master TAL ? ',
#        'Avez-vous eu une expérience professionnelle en lien avec le master pendant le M1 ou le M2 ? (hors alternance et stage)',
#        'Quel était le nom de l'organisme employeur ?',
#        'Quel était le type de contrat ? ', 'Quelles étaient vos missions ?',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu Master in social studies, Cambridge University à la question précédente.\n\nVeuillez ici répondre :\nMaster en Sciences Sociales, Université de Cambridge',
#        'Indiquez si ce master appartient à une des mentions suivantes : ',
#        'Si vous avez obtenu un autre type de diplôme (hors licence et master), indiquez son nom original (langue d'origine) au format :\nNOM, ÉTABLISSEMENT\n\nExemple:\nBTS en communication, Lycée Paul Eluard, Saint-Denis',
#        'Avez-vous déjà une licence ?\nSi oui, veuillez indiquer son nom original (langue d'origine) au format :\nNOM, UNIVERSITÉ\n\nExemple:\nLicence en biologie, Université Paris Saclay',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu Bachelor in social studies, Cambridge University à la question précédente.\n\nVeuillez ici répondre :\nLicence en Sciences Sociales, Université de Cambridge',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu NVQ hairstylist, Freddie Mercury High School, Cambridge à la question précédente.\n\nVeuillez ici répondre :\nCAP coiffure, Lycée Freddie Mercury, Cambridge',
#        'Colonne 84', 'normalised_m1_s1_courses', 'normalised_m1_s1_optionnal',
#        'normalised_m1_s1_extra', 'normalised_m1_s2_courses',
#        'normalised_m1_s2_extra', 'normalised_m2_s1_courses',
#        'normalised_m2_s1_extra'],
#       dtype='object')

# %%
df_eleves_avec_cours = pd.merge(df_eleves, formulaire[["Nom de famille", "normalised_m1_s1_courses", "normalised_m1_s1_optionnal", "normalised_m1_s1_extra", "normalised_m1_s2_courses", "normalised_m1_s2_extra", "normalised_m2_s1_courses", "normalised_m2_s1_extra"]], left_on="nom", right_on="Nom de famille", how="left")

# %%
df_eleves_avec_cours.to_csv("eleves_avec_cours.csv", index=False)

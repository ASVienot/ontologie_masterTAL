# %%
import pandas as pd
from unidecode import unidecode

# %%
formulaire = pd.read_csv("formulaire.csv")
formulaire.columns
# Out:
# Index(['Horodateur', 'Score', 'Nom de famille', 'Prénom', 'Genre',
#        'Date de naissance', 'Nationalité',
#        'Avez-vous redoublé le master ? Si oui, indiquez quelle année et quel niveau. ',
#        'Dans quelle université étiez-vous inscrits au M1 ? ',
#        'Dans quel parcours êtes-vous inscrits au M2 ?',
#        'Disposez vous ou avez-vous disposé d'un aménagement handicap pour le master (tiers-temps, autres...) ?',
#        'Si vous êtes inscrits (ou avez été inscrits) dans un autre établissement pendant le master, indiquez lequel :\n\nExemple :\nÉtudiant en M2 TAL Ingénierie Multilingue et à 42 en même temps.',
#        'Si vous avez obtenu un baccalauréat français, quelle était votre filière : ',
#        'Indiquez si cette licence appartient à l'une des mentions suivantes :',
#        'Avez-vous déjà un master ?\nSi oui, veuillez indiquer son nom original (langue d'origine) au format :\nNOM, UNIVERSITÉ\n\nExemple:\nMaster Linguistique Anglaise, Université Sorbonne Nouvelle',
#        'Si vous travaillez (ou avez travaillé) pendant le master, indiquez sur quel poste (hors stage TAL) :\n\nExemple :\nActuellement employé polyvalent à Décathlon.',
#        'Si vous avez exercé une activité professionnelle de longue durée avant le master (reconversion, reprise d'études ou autres), indiquez laquelle :\n\nExemple:\nProfesseure à l'alliance française de Bogotá. ',
#        'Avez-vous eu un premier stage en NLP pendant le M1 ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?',
#        'Quel était le nom de l'organisme d'accueil ? ',
#        'Quelle était la durée du stage ?', 'Quel était le sujet du stage ?',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :',
#        'Avez-vous eu un second stage en NLP pendant le M1 ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?.1',
#        'Quel était le nom de l'organisme d'accueil ? .1',
#        'Quelle était la durée du stage ?.1',
#        'Quel était le sujet du stage ?.1',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :.1',
#        'Avez-vous eu un stage en NLP pendant le M2 (hors celui du second semestre à venir) ?',
#        'Si oui, étiez-vous en entreprise, laboratoire, ou autre ?.2',
#        'Quel était le nom de l'organisme d'accueil ? .2',
#        'Quelle était la durée du stage ?.2',
#        'Quel était le sujet du stage ?.2',
#        'Si votre tuteur de stage était un enseignant du master, indiquez lequel :.2',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M1 numéro 1',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M1 numéro 2',
#        'Si vous deviez noter votre expérience globale de stagiaire, quelle notre mettriez vous ? \nStage M2',
#        'Pour les M2 en parcours recherche, IM ou TETRADOM, avez-vous déjà trouvé un stage ?',
#        'Si oui, serez-vous en entreprise, laboratoire ou autre ?',
#        'Quel est le nom de l'organisme d'accueil ?',
#        'Quelle sera la durée du stage ?',
#        'Pour les M2 en parcours recherche, le sujet de votre mémoire est-il lié à votre stage de M2 ?',
#        'Pour les M2 en parcours recherche, si vous le connaissez déjà, quel est le sujet de votre mémoire ?',
#        'Pour les M2 en parcours recherche, si vous les connaissez déjà, qui sont vos directeurs de mémoire ? ',
#        'Pour les M2 en parcours alternance, avez-vous trouvé une alternance, un stage, ou autre ?',
#        'Pour les M2 en parcours alternance ayant trouvé une alternance, dans quel organisme êtes-vous ?',
#        'Quelle sont vos missions ?',
#        'Pour les M2 en parcours alternance ayant trouvé un stage, dans quel organisme êtes-vous/serez-vous ?',
#        'Quelle est/sera la durée du stage ?',
#        'Quelles sont/seront vos missions ?',
#        'Quels cours avez-vous suivis au premier semestre du M1 ?',
#        'Quelles ont été vos options de linguistique au premier semestre du M1 ?\nSéparer les cours par des virgules. ',
#        'Avons-nous oublié quelque cours au premier semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels cours avez-vous suivis au second semestre du M1 ?',
#        'Avons-nous oublié quelque cours au second semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels cours avez-vous suivis au premier semestre du M2 ?',
#        'Avons-nous oublié quelque cours au premier semestre du M2 ? Indiquez-le ici !\nSéparez les cours par des virgules. ',
#        'Quels sont vos sujets préférés en cours ? ',
#        'Quelle(s) modalité(s) d'évaluation préférez-vous ?',
#        'Quel aspect aimeriez-vous voir plus mis en avant pendant le master ? Ça peut être un sujet en particulier, des compétences spécifiques ou autre.',
#        'Qui est votre ennemi juré dans le master parmi les élèves (soyez pas sérieux c'est pour rigoler) ? ',
#        'Sur combien notez-vous votre santé mentale avant le master ?',
#        'Sur combien notez-vous votre santé mentale après le master ? ',
#        'À quelle fréquence pleurez-vous à cause du master ?\nex: x/mois ou x/semaine ou x/jour ...',
#        'Combien d'heures par nuit dormez-vous en moyenne ?',
#        'Sur combien notez-vous la difficulté du M1 ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Recherche et Développement ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Alternance ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Ingénierie Multilingue ?',
#        'Sur combien notez-vous la difficulté du M2 parcours Technologies de la Traduction et Traitement des Données Multilingues ?',
#        'Pour les adeptes de Linux, voulez-vous régulièrement jeter votre ordinateur par la fenêtre ?',
#        'Pour les adeptes de Mac, voulez-vous régulièrement jeter votre ordinateur par la fenêtre ?',
#        'Si vous deviez élire le meilleur cours de tout le master, lequel choisiriez-vous ? ',
#        'Pour les étudiants de Nanterre, sur combien notez-vous l'efficacité de votre administration ?',
#        'Pour les étudiants de la Sorbonne-Nouvelle, sur combien notez-vous l'efficacité de votre administration ?',
#        'Pour les étudiants de l'INALCO, sur combien notez-vous l'efficacité de votre administration ?',
#        'Quel conseil donneriez-vous aux futurs élèves pour survivre au master TAL ?',
#        'À qui recommanderiez-vous le master TAL ?',
#        'Quel conseil donneriez-vous aux professeurs du master TAL ? ',
#        'Avez-vous eu une expérience professionnelle en lien avec le master pendant le M1 ou le M2 ? (hors alternance et stage)',
#        'Quel était le nom de l'organisme employeur ?',
#        'Quel était le type de contrat ? ', 'Quelles étaient vos missions ?',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu Master in social studies, Cambridge University à la question précédente.\n\nVeuillez ici répondre :\nMaster en Sciences Sociales, Université de Cambridge',
#        'Indiquez si ce master appartient à une des mentions suivantes : ',
#        'Si vous avez obtenu un autre type de diplôme (hors licence et master), indiquez son nom original (langue d'origine) au format :\nNOM, ÉTABLISSEMENT\n\nExemple:\nBTS en communication, Lycée Paul Eluard, Saint-Denis',
#        'Avez-vous déjà une licence ?\nSi oui, veuillez indiquer son nom original (langue d'origine) au format :\nNOM, UNIVERSITÉ\n\nExemple:\nLicence en biologie, Université Paris Saclay',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu Bachelor in social studies, Cambridge University à la question précédente.\n\nVeuillez ici répondre :\nLicence en Sciences Sociales, Université de Cambridge',
#        'Si vous avez répondu à la question précédente et que votre diplôme est étranger, veuillez indiquer sous le même format un nom équivalent en français.\n\nExemple :\nSi vous avez répondu NVQ hairstylist, Freddie Mercury High School, Cambridge à la question précédente.\n\nVeuillez ici répondre :\nCAP coiffure, Lycée Freddie Mercury, Cambridge',
#        'Colonne 84'],
#       dtype='object')

# %%
dico_prof = {"nom_prof": [
    "DUPONT",
    "BATTISTELLI",
    "ESHKOL-TARAVELLA", 
    "GROBOL",
    "KAHANE", 
    "MAGISTRY", 
    "NOUVEL", 
    "WANG", 
    "GENDROT", 
    "HERRERA", 
    "WANG", 
    "BOGLIOTTI", 
    "VILLEOING", 
    "STRICKER", 
    "DEHOUCK", 
    "JACOBSON", 
    "SAUVAGE", 
    "ZWEIGENBAUM", 
    "KOSMALA" , 
    "VALETTE", 
    "GABOR", 
    "LICHAO", 
    "JACQUEMARD",
    "ROULOIS",
    "MONNIN-TUILLIER",
    "AMSILI",
    "JOURDAIN", 
    "AOUINA", 
    "LECAILLIEZ",
    "AKSEN", 
    "GAUMET", 
    "GROUIN", 
    "KUBIK",
    "BONNAFOUS", 
    "ABROUGUI", 
    "PAROUBECK",
    "RAINERIE", 
    "SEMMAR",
    "LASON",
    "NUT",
    "CARCENAC",
    "LEE",
    "HUP",
    "COSTA"
    ],
        "prenom_prof": ["Yoann", "Delphine", "Iris", "Loïc", "Sylvain", "Pierre", "Damien", "Ilaine", "Cedric", "Santiago", "Xibin", "Caroline", "Florence", "Armand", "Mathieu", "Michel", "Eve", "Pierre", "Loulou", "Mathieu", "Kata", "Zhu","Florent", "Alexandre", "Chloé", "Pascal", "Louis", "Ons","Louis", "Hatice", "Sophie", "Cyril", "Karolina", "Marie-Paule", "Rim", "Patrick", "Sophie", "Nasredine", "Natalia", "Suppya", "Benoît", "Kyung", "Christophe", "James"],
        "etablissement": ["SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "SorbonneNouvelle", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco","Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Nanterre", "SorbonneNouvelle"],
		"genre" : [
      "Homme",
      "Femme",
      "Femme",
      "Autre", 
      "Homme", 
      "Homme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Homme", 
      "Homme",
      "Femme", 
      "Femme", 
      "Homme", 
      "Homme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Homme",
      "Homme",
      "Homme",
      "Femme",
      "Homme",
      "Homme", 
      "Femme", 
      "Homme",
      "Femme", 
      "Femme", 
      "Homme", 
      "Femme", 
      "Femme",
      "Femme",
      "Homme",
      "Femme",
        "Homme",
        "Femme",
      "Femme",
      "Homme",
      "Femme",
      "Homme",
      "Homme"
      ],
		"cours": [
      ["PPE1", "PPE2", "Introduction a la fouille de textes"],
      ["Modelisation automatique pour l'analyse de textes","Annotations semantiques et applications en recherche d'information", "Ingenierie des connaissances", "Linguistique outillee et traitements statistiques"],
      ["Programmation et algorithmique 1", "Bases de donnees pour linguistes", "Enrichissement de corpus", "De la modelisation au traitement automatique des donnees linguistiques", "Ingenierie des connaissances", "Langages du web semantique", "seminaire: tal et linguistique de corpus"],
      ["Mathematiques pour le TAL", "Apprentissage automatique", "Arbres graphes", "Interfaces pour le web"],
      ["Modelisation des langues"],
      ["PPE1", "PPE2"],
      ["Langages reguliers", "Statistiques textuelles", "Traitement statistique de corpus"],
      ["Gest. Info Multilinguisme", "Ecriture et multilinguisme"],
      ["Synthese de la parole", "CNN", "Phonetique physiologique et acoustique"],
      ["Corpus arbores et parsing"], 
      ["Recueil de données et statistiques"],
      ["Linguistique de la langue de signes"], 
      ["Morphologie"],
      ["NLP in english", "Langues vivantes etrangeres"], 
      ["Programmation et algorithmique 2"],
      ["Document structure"],
      ["Outils de traitement de corpus"], 
      ["Corpus paralleles et comparables"], 
      ["Anglais de specialite"],
      ["Semantique lexicale et textuelle", "Genres textes et usages", "Semantique de textes multilangues"],
      ["Lexique et morphologie"], 
      ["Pratiques textuelles et traduction", "Traductologie 1"],
      ["Programmation objet 2"],
      ["Langages de script (python inalco)"],
      ["Extraction d'informations"],
      ["Semantique computationnelle"], 
      ["Langages de script"], 
      ["Acquisition modelisation/representation"],
      ["Programmation objet 1"],
      ["Langue des signes"], 
      ["Conduite de projet de traduction 1"],
      ["Fouille de textes 1"], 
      ["Outils de TAO 1"], 
      ["Traduction technique 1"], 
      ["Documents structures"],
      ["Calculabilite"],
      ["Large corpus linguistics"],
      ["Traduction automatique et assistee"],
      ["Polonais"],
      ["Khmer"],
      ["Gestion de projets"],
      ["Coreen"],
      ["Anglais pro"],
      ["sociolinguistique"]
    #   ["actualite dans le monde anglophone"]

      
      
            ],
        "directeur_memoire_de" : [None,["Florian PHILIPPE"], None, ["Patricia AUGUSTYN", "Marie DELPORTE-LANDAT", "Florian PHILIPPE"], ["Ioana-Madalina SILAI", "Maria Paz BOTERO"], None, None, None, ["Lise BRISSET"], None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
        
}

# print(len(prof["nom_prof"]), len(prof["prenom_prof"]), len(prof["etablissement"]), len(prof["genre"]), len(prof["cours"]), len(prof["directeur_memoire_de"]))

df_prof = pd.DataFrame(dico_prof)
# df_prof.to_csv("prof_try.csv", index=False)
# for cle, value in prof.items():
#     print(len(value))

# for (i, a), (j, b) in zip(enumerate(prof['prenom_prof']), enumerate(prof['genre'])):
#     print(f"{i, a}, {j, b}")

# %%
print(df_prof.head())
# Out:
#            nom_prof prenom_prof     etablissement  genre  \
# 0            DUPONT       Yoann  SorbonneNouvelle  Homme
# 1       BATTISTELLI    Delphine          Nanterre  Femme
# 2  ESHKOL-TARAVELLA        Iris          Nanterre  Femme
# 3            GROBOL        Loïc          Nanterre  Autre
# 4            KAHANE     Sylvain          Nanterre  Homme
#
#                                                cours  \
# 0  [PPE1, PPE2, Introduction a la fouille de textes]
# 1  [Modelisation automatique pour l'analyse de te...
# 2  [Programmation et algorithmique 1, Bases de do...
# 3  [Mathematiques pour le TAL, Apprentissage auto...
# 4                         [Modelisation des langues]
#
#                                 directeur_memoire_de
# 0                                               None
# 1                                 [Florian PHILIPPE]
# 2                                               None
# 3  [Patricia AUGUSTYN, Marie DELPORTE-LANDAT, Flo...
# 4           [Ioana-Madalina SILAI, Maria Paz BOTERO]

# %%
eleves = formulaire['Nom de famille'] + formulaire['']

# %%
def normalisation_m1_s1(list_courses):

    ### On sépare les cours, on enlève les diacritiques et on met tout en minuscule
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    ### On renomme ou on uniformise les cours pour une meilleure correspondance
    dico_correspondance = {
        "ppe 1" : "ppe1",
        "langages regulieres" : "Langages reguliers",
        "gest. info multilinguisme (gim)" : "gest. info multilinguisme",
        "programmation et algorithmique 1 (python nanterre)" : "programmation et algorithmique 1",
        "modalisation automatique pour l'analyse de textes" : "modelisation automatique pour l'analyse de textes",
        "programmation objet" : "programmation objet 1",
        "pratiques textuelles" : "pratiques textuelles et traduction",
        "langues vivantes" : "langues vivantes etrangeres",
    }

    cleaned_courses = []
    for course in list_courses:
        if course != "linguistique au choix" and course != "principes de bases de données":
            if course in dico_correspondance.keys():
                cleaned_courses.append(dico_correspondance[course])
            else:
                cleaned_courses.append(course)

    print(cleaned_courses)

    return cleaned_courses

# %%
### POUR LES COURS OBLIGATOIRES DU M1 S1
formulaire["normalised_m1_s1_courses"] = formulaire["Quels cours avez-vous suivis au premier semestre du M1 ?"].apply(normalisation_m1_s1)
# Out:
# ['Langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de scripts (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'lexique et morphologie']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'corpus arbores et parsing', 'langages de scripts (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'principes de bases de donnees', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de scripts (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'principes de bases de donnees', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'lexique et morphologie']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'lexique et morphologie']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de scripts (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'principes de bases de donnees', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de scripts (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', 'corpus arbores et parsing', 'langues vivantes etrangeres', 'langages de scripts (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'pratiques textuelles et traduction']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'synthese de la parole', "modelisation automatique pour l'analyse de textes", 'base de donnees pour linguistes', 'programmation et algorithmique 1', 'corpus arbores et parsing', 'langues vivantes etrangeres']
# ['langages reguliers', 'gest. info multilinguisme', 'ppe1', 'langages de scripts (python inalco)', 'lexique et morphologie', 'programmation objet 1', 'principes de bases de donnees']

# %%
def normalisation_m1_s1_optional(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    dico_correspondance = {
        "recueil de donnees et statistiques (nanterre)" : "recueil de données et statistiques",
        "lexique et morphologie (inalco)" : "lexique et morphologie",
        "nlp in english" : "langues vivantes etrangeres",
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)

    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m1_s1_optionnal"] = formulaire["Quelles ont été vos options de linguistique au premier semestre du M1 ?\nSéparer les cours par des virgules. "].apply(normalisation_m1_s1_optional)
# Out:
# ['recueil de donnees et statistiques', 'morphologie']
# []
# ['morphologie', 'recueil de donnees et statistiques']
# ['recueil de donnees et statistiques', 'morphologie']
# ['morphologie', 'recueil de donnees et statistiques']
# ['sociolinguistique', 'phonetique physiologique et acoustique']
# ['large corpus linguistics', 'langues vivantes etrangeres']
# ['recueil de donnees et statistiques', 'phonetique physiologique et acoustique']
# ['morphologie', 'recueil de donnees et statistiques']
# ['morphologie', 'recueil de donnees et statistiques']
# ['anglais']
# ['langues vivantes etrangeres']
# ['recueil de donnees et statistiques', 'linguistique de la lsf']
# ['recueil de donnees et statistiques', 'morphologie']
# ['morphologie', 'changements linguistiques']
# []
# ['morphologie']
# ['recueil de données et statistiques', 'lexique et morphologie']
# []
# []
# ['sens multiple', 'phonetique physiologique et acoustique']
# []
# ['morphologie', 'redaction professionnelle']
# []

# %%
def normalisation_m1_s1_extra(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]
    
    dico_correspondance = {
        "recueil de donnees et statistiques (nanterre)" : "recueil de données et statistiques",
        "lexique et morphologie (inalco)" : "lexique et morphologie"
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)
    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m1_s1_extra"] = formulaire["Avons-nous oublié quelque cours au premier semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].apply(normalisation_m1_s1_extra)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
def normalisation_m1_s2(list_courses):

    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    dico_correspondance = {
        "anglais de specialite" : "anglais de specialite 2",
        "programmation objet" : "programmation objet 2",
        "outil de traitement de corpus" : "outils de traitement de corpus"
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)
    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m1_s2_courses"] = formulaire["Quels cours avez-vous suivis au second semestre du M1 ?"].apply(normalisation_m1_s2)
# Out:
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2']
# ['corpus paralleles et comparables', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', "extraction d'informations", 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'ppe2', 'programmation et algorithmique 2', 'anglais de specialite 2', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'anglais de specialite 2', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'anglais de specialite 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'traduction automatique et assistee', 'semantique lexicale et textuelle', "extraction d'informations", 'programmation objet 2', 'outils de traitement de corpus']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'introduction a la fouille de textes', 'enrichissement de corpus', 'mathematiques pour le tal', 'outils de traitement de corpus', 'mooc']
# ['corpus paralleles et comparables', 'statistiques textuelles', 'document structure', 'ppe2', 'programmation et algorithmique 2', 'anglais de specialite 2', 'traduction automatique et assistee', 'programmation objet 2', 'outils de traitement de corpus']

# %%
def normalisation_m1_s2_extra(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    print(list_courses)
    # # dico_correspondance = {
        
    # # }

    # cleaned_courses = []
    # for course in list_courses:
    #     if course in dico_correspondance.keys():
    #         cleaned_courses.append(dico_correspondance[course])
    #     else:
    #         cleaned_courses.append(course)
    # print(cleaned_courses)
    return list_courses

# %%
formulaire["normalised_m1_s2_extra"] = formulaire["Avons-nous oublié quelque cours au second semestre du M1 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].apply(normalisation_m1_s2_extra)
# Out:
# []
# []
# []
# []
# ['coreen']
# ['polonais']
# []
# []
# ['nlp in english']
# []
# []
# []
# []
# []
# ['nlp in english']
# []
# []
# ['khmer']
# []
# []
# []
# []
# []
# []

# %%
def normalisation_m2_s1(list_courses):
    
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    dico_correspondance = {
        "annotation semantiques et applications en recherche d'information (nanterre)" : "annotations semantiques et applications en recherche d'information",
        "ingenierie de connaissances(nanterre)" : "ingenierie des connaissances", 
        "de la modelisation au traitement automatique des donnees linguistiques (nanterre)" : "de la modelisation au traitement automatique des donnees linguistiques",
        "seminaire: tal et linguistique de corpus (nanterre)" : "seminaire: tal et linguistique de corpus",
        "apprentissage automatique (nanterre)" : "apprentissage automatique",
        "arbres graphes (nanterre)" : "arbres graphes",
        "interfaces pour le web (nanterre)" : "interfaces pour le web",
        "modelisation des langues (nanterre)" : "modelisation des langues",
        "langages du web semantique (nanterre)" : "langages du web semantique",
        "linguistique outille et traitements statistiques (nanterre)" : "linguistique outillee et traitements statistiques",
        "gestion de projets (nanterre)" : "gestion de projets",
        "traitement automatique de corpus (inalco)" : "traitement statistique de corpus",
        "genres textes et usages (inalco)" : "genres textes et usages",
        "semantique des textes multilingues 1 (inalco)" : "semantique des textes multilingues 1",
        "lexicologie terminologie et dictionnairique (inalco)" : "lexicologie terminologie et dictionnairique",
        "acquisition modelisation/representation (inalco)" : "acquisition modelisation/representation",
        "langages de script (inalco) (avec m.jourdain louis)" : "langages de script (jourdain)",
        "langages de script (inalco) (avec m. roulois alexandre)" : "langages de script (roulois)",
        "documents structures (inalco)" : "document structures",
        "cnn (sorbonne nouvelle)" : "cnn",
        "calculabilite (inalco)" : "calculabilite",
        "methodologie de la recherche (nanterre)" : "methodologie de la recherche",
        "conduite de projet de traduction (inalco)" : "conduite de projet de traduction 1",
        "programmation objet 1 (inalco)" : "programmation objet 1",
        "semantique computationnelle (sorbonne nouvelle)" : "semantique computationnelle",
        "anglais (pro) (nanterre)" : "anglais pro",
        "outils de tao 1 (inalco)" : "outils de tao 1",
        "traductologie 1 (inalco)" : "traductologie 1",
        "ecriture et multilinguisme (inalco)" : "ecriture et multilinguisme",
        'traduction technique 1 (inalco)': 'traduction technique 1',
    }

    cleaned_courses = []
    for course in list_courses:
        if course in dico_correspondance.keys():
            cleaned_courses.append(dico_correspondance[course])
        else:
            cleaned_courses.append(course)

    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m2_s1_courses"] = formulaire['Quels cours avez-vous suivis au premier semestre du M2 ?'].apply(normalisation_m2_s1)
# Out:
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'document structures', 'calculabilite', 'programmation objet 1', 'cnn']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'interfaces pour le web', 'arbres graphes', 'genres textes et usages', 'semantique des textes multilingues 1']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'arbres graphes', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'document structures', 'programmation objet 1', 'cnn', 'semantique computationnelle']
# ['apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'arbres graphes', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'programmation objet 1', 'cnn', 'mooc']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'interfaces pour le web', 'arbres graphes', 'traitement statistique de corpus', 'genres textes et usages', 'langages de script (jourdain)', 'programmation objet 1', 'semantique computationnelle']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'conduite de projet de traduction 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (roulois)', 'outils de tao 1', 'traduction technique 1', 'document structures', 'traductologie 1', 'ecriture et multilinguisme', 'calculabilite', 'programmation objet 1']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'arbres graphes', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'cnn', 'semantique computationnelle', 'langue des signes']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'arbres graphes', 'anglais pro', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'programmation objet 1', 'semantique computationnelle']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'arbres graphes', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'cnn', 'semantique computationnelle']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['seminaire: tal et linguistique de corpus', 'apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'interfaces pour le web', 'arbres graphes', 'anglais pro', 'traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'programmation objet 1', 'semantique computationnelle']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'conduite de projet de traduction 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'document structures', 'calculabilite', 'programmation objet 1', 'cnn']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'document structures', 'calculabilite', 'programmation objet 1', 'cnn']
# ['apprentissage automatique', 'modelisation des langues', 'methodologie de la recherche', 'langages du web semantique', 'interfaces pour le web', 'arbres graphes', 'cnn', 'semantique computationnelle']
# ['genres textes et usages', 'semantique des textes multilingues 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'document structures', 'calculabilite', 'programmation objet 1', 'cnn']
# ["annotations semantiques et applications en recherche d'information", 'de la modelisation au traitement automatique des donnees linguistiques', 'seminaire: tal et linguistique de corpus', 'ingenierie des connaissances', 'apprentissage automatique', 'modelisation des langues', 'linguistique outillee et traitements statistiques', 'langages du web semantique', 'gestion de projets', 'interfaces pour le web', 'arbres graphes', 'anglais pro']
# ['traitement statistique de corpus', 'genres textes et usages', 'semantique des textes multilingues 1', 'conduite de projet de traduction 1', 'lexicologie terminologie et dictionnairique', 'acquisition modelisation/representation', 'langages de script (jourdain)', 'cnn']

# %%
def normalisation_m2_s1_extra(list_courses):

    if pd.isna(list_courses):
        print("[]")
        return []
    
    list_courses = list_courses.split(", ")
    list_courses = [unidecode(course.strip().lower()) for course in list_courses]

    dico_correspondance = {
        "traitement statistique de corpus (inalco)" : "traitement statistique de corpus",
        "actualite dans le monde anglophone (anglais sorbonne nouvelle )" : "actualite dans le monde anglophone",
        "fouille de textes (inalco)" : "fouille de textes 1"
    }

    cleaned_courses = []
    for course in list_courses:
        if course != "choix de linguistique" and course != "langue vivante":
            if course in dico_correspondance.keys():
                cleaned_courses.append(dico_correspondance[course])
            else:
                cleaned_courses.append(course)

    print(cleaned_courses)
    return cleaned_courses

# %%
formulaire["normalised_m2_s1_extra"] = formulaire["Avons-nous oublié quelque cours au premier semestre du M2 ? Indiquez-le ici !\nSéparez les cours par des virgules. "].apply(normalisation_m2_s1_extra)
# Out:
# []
# []
# []
# []
# []
# ['traitement statistique de corpus']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['traitement statistique de corpus', 'sociolinguistique', 'actualite dans le monde anglophone']
# ['fouille de textes 1']
# []
# []

# %%
#===== Initialisation du dictionnaire des cours =====#
dico_cours = {"nom_cours": [],
         "id_prof": [],
         "nom_prof" : [],
         "prenom_prof" : [],
         "etablissement": [],
         "annee": [],
         "horaires": [],
         "evaluation": [],
         "list_eleves": []}

# %%
#===== Remplissage du dictionnaire des cours =====#

courses_m1_s1 = formulaire["normalised_m1_s1_courses"].to_list()
courses_m1_s2 = formulaire["normalised_m1_s2_courses"].to_list()
courses_m2_s1 = formulaire["normalised_m2_s1_courses"].to_list()

mandatory_courses = courses_m1_s1 + courses_m1_s2 + courses_m2_s1
mandatory_courses = [value for sublist in mandatory_courses for value in sublist]
mandatory_courses = list(set(mandatory_courses))

optional_courses_m1_s1 = formulaire["normalised_m1_s1_optionnal"].dropna().to_list()
optional_courses_m1_s1 = optional_courses_m1_s1 + formulaire["normalised_m1_s1_extra"].dropna().to_list()
optional_courses_m1_s2 = formulaire["normalised_m1_s2_extra"].dropna().to_list()
optional_courses_m2_s1 = formulaire["normalised_m2_s1_extra"].dropna().to_list()
optional_courses = optional_courses_m1_s1 + optional_courses_m1_s2 + optional_courses_m2_s1
optional_courses = [value for sublist in optional_courses for value in sublist]
optional_courses = list(set(optional_courses))

cours = mandatory_courses + optional_courses
cours = list(set(cours))

dico_cours["nom_cours"] = cours

# %%
for course in dico_cours["nom_cours"]:
    profs_noms = dico_prof["nom_prof"]
    profs_prenoms = dico_prof["prenom_prof"]
    courses = dico_prof["cours"]
    found = False
    print("On cherche le cours", course)

    for prof_nom, prof_prenom, subcourses in zip(profs_noms, profs_prenoms, courses):
        print("on cherche le cours", course, "dans la liste de cours :")
        subcourses = [subcourse.lower() for subcourse in subcourses]
        print(subcourses)
        print("qui est rattachée à:")
        print(prof_nom, prof_nom)
        if course in subcourses:
            found = True
            print(f"le cours {course} a été trouvé")
            print("donc, found est égal à ", found)
            dico_cours["nom_prof"].append(prof_nom)
            dico_cours["prenom_prof"].append(prof_prenom)
            dico_cours["id_prof"].append(f"{prof_prenom}_{prof_nom}")
            print("on a rempli le dico en conséquence")
            for key, value in dico_cours.items():
                print(key, value)
    
    if found == False:
        dico_cours["nom_prof"].append("")
        dico_cours["prenom_prof"].append("")
        dico_cours["id_prof"].append("")
    #     dico_cours["professeur"].append(df_prof["nom_prof"][df_prof["cours"].index(course)])
    # else:
    #     dico_cours["professeur"].append("Non défini")
# Out:
# On cherche le cours introduction a la fouille de textes
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['ppe1', 'ppe2', 'introduction a la fouille de textes']
# qui est rattachée à:
# DUPONT DUPONT
# le cours introduction a la fouille de textes a été trouvé
# donc, found est égal à  True
# on a rempli le dico en conséquence
# nom_cours ['introduction a la fouille de textes', 'corpus arbores et parsing', 'anglais pro', 'coreen', 'document structure', 'conduite de projet de traduction 1', 'corpus paralleles et comparables', 'anglais', 'large corpus linguistics', 'polonais', 'de la modelisation au traitement automatique des donnees linguistiques', 'mathematiques pour le tal', 'genres textes et usages', 'modelisation des langues', 'pratiques textuelles et traduction', 'calculabilite', 'traduction technique 1', 'cnn', 'semantique computationnelle', 'programmation objet 1', 'ecriture et multilinguisme', 'ingenierie des connaissances', 'programmation et algorithmique 2', 'interfaces pour le web', 'synthese de la parole', 'statistiques textuelles', 'langages de script (jourdain)', 'programmation et algorithmique 1', 'semantique lexicale et textuelle', 'recueil de données et statistiques', 'outils de traitement de corpus', 'programmation objet 2', 'base de donnees pour linguistes', 'traitement statistique de corpus', 'langages de script (roulois)', 'traduction automatique et assistee', "annotations semantiques et applications en recherche d'information", 'ppe1', 'apprentissage automatique', 'phonetique physiologique et acoustique', 'sens multiple', 'Langages reguliers', 'nlp in english', 'langages reguliers', 'anglais de specialite 2', 'acquisition modelisation/representation', 'langages de scripts (python inalco)', 'enrichissement de corpus', 'lexicologie terminologie et dictionnairique', 'redaction professionnelle', 'khmer', 'langages du web semantique', 'methodologie de la recherche', 'gestion de projets', 'principes de bases de donnees', 'actualite dans le monde anglophone', 'traductologie 1', 'langue des signes', "modelisation automatique pour l'analyse de textes", 'morphologie', 'gest. info multilinguisme', 'semantique des textes multilingues 1', 'langues vivantes etrangeres', 'fouille de textes 1', 'document structures', 'ppe2', 'mooc', 'linguistique outillee et traitements statistiques', 'linguistique de la lsf', 'lexique et morphologie', 'sociolinguistique', 'recueil de donnees et statistiques', 'changements linguistiques', 'arbres graphes', 'outils de tao 1', "extraction d'informations", 'seminaire: tal et linguistique de corpus']
# id_prof ['Yoann_DUPONT']
# nom_prof ['DUPONT']
# prenom_prof ['Yoann']
# etablissement []
# annee []
# horaires []
# evaluation []
# list_eleves []
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ["modelisation automatique pour l'analyse de textes", "annotations semantiques et applications en recherche d'information", 'ingenierie des connaissances', 'linguistique outillee et traitements statistiques']
# qui est rattachée à:
# BATTISTELLI BATTISTELLI
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['programmation et algorithmique 1', 'bases de donnees pour linguistes', 'enrichissement de corpus', 'de la modelisation au traitement automatique des donnees linguistiques', 'ingenierie des connaissances', 'langages du web semantique', 'seminaire: tal et linguistique de corpus']
# qui est rattachée à:
# ESHKOL-TARAVELLA ESHKOL-TARAVELLA
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['mathematiques pour le tal', 'apprentissage automatique', 'arbres graphes', 'interfaces pour le web']
# qui est rattachée à:
# GROBOL GROBOL
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['modelisation des langues']
# qui est rattachée à:
# KAHANE KAHANE
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['ppe1', 'ppe2']
# qui est rattachée à:
# MAGISTRY MAGISTRY
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['langages reguliers', 'statistiques textuelles', 'traitement statistique de corpus']
# qui est rattachée à:
# NOUVEL NOUVEL
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['gest. info multilinguisme', 'ecriture et multilinguisme']
# qui est rattachée à:
# WANG WANG
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['synthese de la parole', 'cnn', 'phonetique physiologique et acoustique']
# qui est rattachée à:
# GENDROT GENDROT
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['corpus arbores et parsing']
# qui est rattachée à:
# HERRERA HERRERA
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['recueil de données et statistiques']
# qui est rattachée à:
# WANG WANG
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['linguistique de la langue de signes']
# qui est rattachée à:
# BOGLIOTTI BOGLIOTTI
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['morphologie']
# qui est rattachée à:
# VILLEOING VILLEOING
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['nlp in english', 'langues vivantes etrangeres']
# qui est rattachée à:
# STRICKER STRICKER
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['programmation et algorithmique 2']
# qui est rattachée à:
# DEHOUCK DEHOUCK
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['document structure']
# qui est rattachée à:
# JACOBSON JACOBSON
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['outils de traitement de corpus']
# qui est rattachée à:
# SAUVAGE SAUVAGE
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['corpus paralleles et comparables']
# qui est rattachée à:
# ZWEIGENBAUM ZWEIGENBAUM
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['anglais de specialite']
# qui est rattachée à:
# KOSMALA KOSMALA
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['semantique lexicale et textuelle', 'genres textes et usages', 'semantique de textes multilangues']
# qui est rattachée à:
# VALETTE VALETTE
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['lexique et morphologie']
# qui est rattachée à:
# GABOR GABOR
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['pratiques textuelles et traduction', 'traductologie 1']
# qui est rattachée à:
# LICHAO LICHAO
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['programmation objet 2']
# qui est rattachée à:
# JACQUEMARD JACQUEMARD
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['langages de script (python inalco)']
# qui est rattachée à:
# ROULOIS ROULOIS
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ["extraction d'informations"]
# qui est rattachée à:
# MONNIN-TUILLIER MONNIN-TUILLIER
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['semantique computationnelle']
# qui est rattachée à:
# AMSILI AMSILI
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['langages de script']
# qui est rattachée à:
# JOURDAIN JOURDAIN
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['acquisition modelisation/representation']
# qui est rattachée à:
# AOUINA AOUINA
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['programmation objet 1']
# qui est rattachée à:
# LECAILLIEZ LECAILLIEZ
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['langue des signes']
# qui est rattachée à:
# AKSEN AKSEN
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['conduite de projet de traduction 1']
# qui est rattachée à:
# GAUMET GAUMET
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['fouille de textes 1']
# qui est rattachée à:
# GROUIN GROUIN
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['outils de tao 1']
# qui est rattachée à:
# KUBIK KUBIK
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['traduction technique 1']
# qui est rattachée à:
# BONNAFOUS BONNAFOUS
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['documents structures']
# qui est rattachée à:
# ABROUGUI ABROUGUI
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['calculabilite']
# qui est rattachée à:
# PAROUBECK PAROUBECK
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['large corpus linguistics']
# qui est rattachée à:
# RAINERIE RAINERIE
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['traduction automatique et assistee']
# qui est rattachée à:
# SEMMAR SEMMAR
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['polonais']
# qui est rattachée à:
# LASON LASON
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['khmer']
# qui est rattachée à:
# NUT NUT
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['gestion de projets']
# qui est rattachée à:
# CARCENAC CARCENAC
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['coreen']
# qui est rattachée à:
# LEE LEE
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['anglais pro']
# qui est rattachée à:
# HUP HUP
# on cherche le cours introduction a la fouille de textes dans la liste de cours :
# ['sociolinguistique']
# qui est rattachée à:
# COSTA COSTA
# On cherche le cours corpus arbores et parsing
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['ppe1', 'ppe2', 'introduction a la fouille de textes']
# qui est rattachée à:
# DUPONT DUPONT
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ["modelisation automatique pour l'analyse de textes", "annotations semantiques et applications en recherche d'information", 'ingenierie des connaissances', 'linguistique outillee et traitements statistiques']
# qui est rattachée à:
# BATTISTELLI BATTISTELLI
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['programmation et algorithmique 1', 'bases de donnees pour linguistes', 'enrichissement de corpus', 'de la modelisation au traitement automatique des donnees linguistiques', 'ingenierie des connaissances', 'langages du web semantique', 'seminaire: tal et linguistique de corpus']
# qui est rattachée à:
# ESHKOL-TARAVELLA ESHKOL-TARAVELLA
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['mathematiques pour le tal', 'apprentissage automatique', 'arbres graphes', 'interfaces pour le web']
# qui est rattachée à:
# GROBOL GROBOL
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['modelisation des langues']
# qui est rattachée à:
# KAHANE KAHANE
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['ppe1', 'ppe2']
# qui est rattachée à:
# MAGISTRY MAGISTRY
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['langages reguliers', 'statistiques textuelles', 'traitement statistique de corpus']
# qui est rattachée à:
# NOUVEL NOUVEL
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['gest. info multilinguisme', 'ecriture et multilinguisme']
# qui est rattachée à:
# WANG WANG
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['synthese de la parole', 'cnn', 'phonetique physiologique et acoustique']
# qui est rattachée à:
# GENDROT GENDROT
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['corpus arbores et parsing']
# qui est rattachée à:
# HERRERA HERRERA
# le cours corpus arbores et parsing a été trouvé
# donc, found est égal à  True
# on a rempli le dico en conséquence
# nom_cours ['introduction a la fouille de textes', 'corpus arbores et parsing', 'anglais pro', 'coreen', 'document structure', 'conduite de projet de traduction 1', 'corpus paralleles et comparables', 'anglais', 'large corpus linguistics', 'polonais', 'de la modelisation au traitement automatique des donnees linguistiques', 'mathematiques pour le tal', 'genres textes et usages', 'modelisation des langues', 'pratiques textuelles et traduction', 'calculabilite', 'traduction technique 1', 'cnn', 'semantique computationnelle', 'programmation objet 1', 'ecriture et multilinguisme', 'ingenierie des connaissances', 'programmation et algorithmique 2', 'interfaces pour le web', 'synthese de la parole', 'statistiques textuelles', 'langages de script (jourdain)', 'programmation et algorithmique 1', 'semantique lexicale et textuelle', 'recueil de données et statistiques', 'outils de traitement de corpus', 'programmation objet 2', 'base de donnees pour linguistes', 'traitement statistique de corpus', 'langages de script (roulois)', 'traduction automatique et assistee', "annotations semantiques et applications en recherche d'information", 'ppe1', 'apprentissage automatique', 'phonetique physiologique et acoustique', 'sens multiple', 'Langages reguliers', 'nlp in english', 'langages reguliers', 'anglais de specialite 2', 'acquisition modelisation/representation', 'langages de scripts (python inalco)', 'enrichissement de corpus', 'lexicologie terminologie et dictionnairique', 'redaction professionnelle', 'khmer', 'langages du web semantique', 'methodologie de la recherche', 'gestion de projets', 'principes de bases de donnees', 'actualite dans le monde anglophone', 'traductologie 1', 'langue des signes', "modelisation automatique pour l'analyse de textes", 'morphologie', 'gest. info multilinguisme', 'semantique des textes multilingues 1', 'langues vivantes etrangeres', 'fouille de textes 1', 'document structures', 'ppe2', 'mooc', 'linguistique outillee et traitements statistiques', 'linguistique de la lsf', 'lexique et morphologie', 'sociolinguistique', 'recueil de donnees et statistiques', 'changements linguistiques', 'arbres graphes', 'outils de tao 1', "extraction d'informations", 'seminaire: tal et linguistique de corpus']
# id_prof ['Yoann_DUPONT', 'Santiago_HERRERA']
# nom_prof ['DUPONT', 'HERRERA']
# prenom_prof ['Yoann', 'Santiago']
# etablissement []
# annee []
# horaires []
# evaluation []
# list_eleves []
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['recueil de données et statistiques']
# qui est rattachée à:
# WANG WANG
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['linguistique de la langue de signes']
# qui est rattachée à:
# BOGLIOTTI BOGLIOTTI
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['morphologie']
# qui est rattachée à:
# VILLEOING VILLEOING
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['nlp in english', 'langues vivantes etrangeres']
# qui est rattachée à:
# STRICKER STRICKER
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['programmation et algorithmique 2']
# qui est rattachée à:
# DEHOUCK DEHOUCK
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['document structure']
# qui est rattachée à:
# JACOBSON JACOBSON
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['outils de traitement de corpus']
# qui est rattachée à:
# SAUVAGE SAUVAGE
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['corpus paralleles et comparables']
# qui est rattachée à:
# ZWEIGENBAUM ZWEIGENBAUM
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['anglais de specialite']
# qui est rattachée à:
# KOSMALA KOSMALA
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['semantique lexicale et textuelle', 'genres textes et usages', 'semantique de textes multilangues']
# qui est rattachée à:
# VALETTE VALETTE
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['lexique et morphologie']
# qui est rattachée à:
# GABOR GABOR
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['pratiques textuelles et traduction', 'traductologie 1']
# qui est rattachée à:
# LICHAO LICHAO
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['programmation objet 2']
# qui est rattachée à:
# JACQUEMARD JACQUEMARD
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['langages de script (python inalco)']
# qui est rattachée à:
# ROULOIS ROULOIS
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ["extraction d'informations"]
# qui est rattachée à:
# MONNIN-TUILLIER MONNIN-TUILLIER
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['semantique computationnelle']
# qui est rattachée à:
# AMSILI AMSILI
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['langages de script']
# qui est rattachée à:
# JOURDAIN JOURDAIN
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['acquisition modelisation/representation']
# qui est rattachée à:
# AOUINA AOUINA
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['programmation objet 1']
# qui est rattachée à:
# LECAILLIEZ LECAILLIEZ
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['langue des signes']
# qui est rattachée à:
# AKSEN AKSEN
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['conduite de projet de traduction 1']
# qui est rattachée à:
# GAUMET GAUMET
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['fouille de textes 1']
# qui est rattachée à:
# GROUIN GROUIN
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['outils de tao 1']
# qui est rattachée à:
# KUBIK KUBIK
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['traduction technique 1']
# qui est rattachée à:
# BONNAFOUS BONNAFOUS
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['documents structures']
# qui est rattachée à:
# ABROUGUI ABROUGUI
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['calculabilite']
# qui est rattachée à:
# PAROUBECK PAROUBECK
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['large corpus linguistics']
# qui est rattachée à:
# RAINERIE RAINERIE
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['traduction automatique et assistee']
# qui est rattachée à:
# SEMMAR SEMMAR
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['polonais']
# qui est rattachée à:
# LASON LASON
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['khmer']
# qui est rattachée à:
# NUT NUT
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['gestion de projets']
# qui est rattachée à:
# CARCENAC CARCENAC
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['coreen']
# qui est rattachée à:
# LEE LEE
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['anglais pro']
# qui est rattachée à:
# HUP HUP
# on cherche le cours corpus arbores et parsing dans la liste de cours :
# ['sociolinguistique']
# qui est rattachée à:
# COSTA COSTA
# On cherche le cours anglais pro
# on cherche le cours anglais pro dans la liste de cours :
# ['ppe1', 'ppe2', 'introduction a la fouille de textes']
# qui est rattachée à:
# DUPONT DUPONT
# on cherche le cours anglais pro dans la liste de cours :
# ["modelisation automatique pour l'analyse de textes", "annotations semantiques et applications en recherche d'information", 'ingenierie des connaissances', 'linguistique outillee et traitements statistiques']
# qui est rattachée à:
# BATTISTELLI BATTISTELLI
# on cherche le cours anglais pro dans la liste de cours :
# ['programmation et algorithmique 1', 'bases de donnees pour linguistes', 'enrichissement de corpus', 'de la modelisation au traitement automatique des donnees linguistiques', 'ingenierie des connaissances', 'langages du web semantique', 'seminaire: tal et linguistique de corpus']
# qui est rattachée à:
# ESHKOL-TARAVELLA ESHKOL-TARAVELLA
# on cherche le cours anglais pro dans la liste de cours :
# ['mathematiques pour le tal', 'apprentissage automatique', 'arbres graphes', 'interfaces pour le web']
# qui est rattachée à:
# GROBOL GROBOL
# on cherche le cours anglais pro dans la liste de cours :
# ['modelisation des langues']
# qui est rattachée à:
# KAHANE KAHANE
# on cherche le cours anglais pro dans la liste de cours :
# ['ppe1', 'ppe2']
# qui est rattachée à:
# MAGISTRY MAGISTRY
# on cherche le cours anglais pro dans la liste de cours :
# ['langages reguliers', 'statistiques textuelles', 'traitement statistique de corpus']
# qui est rattachée à:
# NOUVEL NOUVEL
# on cherche le cours anglais pro dans la liste de cours :
# ['gest. info multilinguisme', 'ecriture et multilinguisme']
# qui est rattachée à:
# WANG WANG
# on cherche le cours anglais pro dans la liste de cours :
# ['synthese de la parole', 'cnn', 'phonetique physiologique et acoustique']
# qui est rattachée à:
# GENDROT GENDROT
# on cherche le cours anglais pro dans la liste de cours :
# ['corpus arbores et parsing']
# qui est rattachée à:
# HERRERA HERRERA
# on cherche le cours anglais pro dans la liste de cours :
# ['recueil de données et statistiques']
# qui est rattachée à:
# WANG WANG
# on cherche le cours anglais pro dans la liste de cours :
# ['linguistique de la langue de signes']
# qui est rattachée à:
# BOGLIOTTI BOGLIOTTI
# on cherche le cours anglais pro dans la liste de cours :
# ['morphologie']
# qui est rattachée à:
# VILLEOING VILLEOING
# on cherche le cours anglais pro dans la liste de cours :
# ['nlp in english', 'langues vivantes etrangeres']
# qui est rattachée à:
# STRICKER STRICKER
# on cherche le cours anglais pro dans la liste de cours :
# ['programmation et algorithmique 2']
# qui est rattachée à:
# DEHOUCK DEHOUCK
# on cherche le cours anglais pro dans la liste de cours :
# ['document structure']
# qui est rattachée à:
# JACOBSON JACOBSON
# on cherche le cours anglais pro dans la liste de cours :
# ['outils de traitement de corpus']
# qui est rattachée à:
# SAUVAGE SAUVAGE
# on cherche le cours anglais pro dans la liste de cours :
# ['corpus paralleles et comparables']
# qui est rattachée à:
# ZWEIGENBAUM ZWEIGENBAUM
# on cherche le cours anglais pro dans la liste de cours :
# ['anglais de specialite']
# qui est rattachée à:
# KOSMALA KOSMALA
# on cherche le cours anglais pro dans la liste de cours :
# ['semantique lexicale et textuelle', 'genres textes et usages', 'semantique de textes multilangues']
# qui est rattachée à:
# VALETTE VALETTE
# on cherche le cours anglais pro dans la liste de cours :
# ['lexique et morphologie']
# qui est rattachée à:
# GABOR GABOR
# on cherche le cours anglais pro dans la liste de cours :
# ['pratiques textuelles et traduction', 'traductologie 1']
# qui est rattachée à:
# LICHAO LICHAO
# on cherche le cours anglais pro dans la liste de cours :
# ['programmation objet 2']
# qui est rattachée à:
# JACQUEMARD JACQUEMARD
# on cherche le cours anglais pro dans la liste de cours :
# ['langages de script (python inalco)']
# qui est rattachée à:
# ROULOIS ROULOIS
# on cherche le cours anglais pro dans la liste de cours :
# ["extraction d'informations"]
# qui est rattachée à:
# MONNIN-TUILLIER MONNIN-TUILLIER
# on cherche le cours anglais pro dans la liste de cours :
# ['semantique computationnelle']
# qui est rattachée à:
# AMSILI AMSILI
# on cherche le cours anglais pro dans la liste de cours :
# ['langages de script']
# qui est rattachée à:
# JOURDAIN JOURDAIN
# on cherche le cours anglais pro dans la liste de cours :
# ['acquisition modelisation/representation']
# qui est rattachée à:
# AOUINA AOUINA
# on cherche le cours anglais pro dans la liste de cours :
# ['programmation objet 1']
# qui est rattachée à:
# LECAILLIEZ LECAILLIEZ
# on cherche le cours anglais pro dans la liste de cours :
# ['langue des signes']
# qui est rattachée à:
# AKSEN AKSEN
# on cherche le cours anglais pro dans la liste de cours :
# ['conduite de projet de traduction 1']
# qui est rattachée à:
# GAUMET GAUMET
# on cherche le cours anglais pro dans la liste de cours :
# ['fouille de textes 1']
# qui est rattachée à:
# GROUIN GROUIN
# on cherche le cours anglais pro dans la liste de cours :
# ['outils de tao 1']
# qui est rattachée à:
# KUBIK KUBIK
# on cherche le cours anglais pro dans la liste de cours :
# ['traduction technique 1']
# qui est rattachée à:
# BONNAFOUS BONNAFOUS
# on cherche le cours anglais pro dans la liste de cours :
# ['documents structures']
# qui est rattachée à:
# ABROUGUI ABROUGUI
# on cherche le cours anglais pro dans la liste de cours :
# ['calculabilite']
# qui est rattachée à:
# PAROUBECK PAROUBECK
# on cherche le cours anglais pro dans la liste de cours :
# ['large corpus linguistics']
# qui est rattachée à:
# RAINERIE RAINERIE
# on cherche le cours anglais pro dans la liste de cours :
# ['traduction automatique et assistee']
# qui est rattachée à:
# SEMMAR SEMMAR
# on cherche le cours anglais pro dans la liste de cours :
# ['polonais']
# qui est rattachée à:
# LASON LASON
# on cherche le cours anglais pro dans la liste de cours :
# ['khmer']
# qui est rattachée à:
# NUT NUT
# on cherche le cours anglais pro dans la liste de cours :
# ['gestion de projets']
# qui est rattachée à:
# CARCENAC CARCENAC
# on cherche le cours anglais pro dans la liste de cours :
# ['coreen']
# qui est rattachée à:
# LEE LEE
# on cherche le cours anglais pro dans la liste de cours :
# ['anglais pro']
# qui est rattachée à:
# HUP HUP
# le cours anglais pro a été trouvé
# donc, found est égal à  True
# on a rempli le dico en conséquence
# nom_cours ['introduction a la fouille de textes', 'corpus arbores et parsing', 'anglais pro', 'coreen', 'document structure', 'conduite de projet de traduction 1', 'corpus paralleles et comparables', 'anglais', 'large corpus linguistics', 'polonais', 'de la modelisation au traitement automatique des donnees linguistiques', 'mathematiques pour le tal', 'genres textes et usages', 'modelisation des langues', 'pratiques textuelles et traduction', 'calculabilite', 'traduction technique 1', 'cnn', 'semantique computationnelle', 'programmation objet 1', 'ecriture et multilinguisme', 'ingenierie des connaissances', 'programmation et algorithmique 2', 'interfaces pour le web', 'synthese de la parole', 'statistiques textuelles', 'langages de script (jourdain)', 'programmation et algorithmique 1', 'semantique lexicale et textuelle', 'recueil de données et statistiques', 'outils de traitement de corpus', 'programmation objet 2', 'base de donnees pour linguistes', 'traitement statistique de corpus', 'langages de script (roulois)', 'traduction automatique et assistee', "annotations semantiques et applications en recherche d'information", 'ppe1', 'apprentissage automatique', 'phonetique physiologique et acoustique', 'sens multiple', 'Langages reguliers', 'nlp in english', 'langages reguliers', 'anglais de specialite 2', 'acquisition modelisation/representation', 'langages de scripts (python inalco)', 'enrichissement de corpus', 'lexicologie terminologie et dictionnairique', 'redaction professionnelle', 'khmer', 'langages du web semantique', 'methodologie de la recherche', 'gestion de projets', 'principes de bases de donnees', 'actualite dans le monde anglophone', 'traductologie 1', 'langue des signes', "modelisation automatique pour l'analyse de textes", 'morphologie', 'gest. info multilinguisme', 'semantique des textes multilingues 1', 'langues vivantes etrangeres', 'fouille de textes 1', 'document structures', 'ppe2', 'mooc', 'linguistique outillee et traitements statistiques', 'linguistique de la lsf', 'lexique et morphologie', 'sociolinguistique', 'recueil de donnees et statistiques', 'changements linguistiques', 'arbres graphes', 'outils de tao 1', "extraction d'informations", 'seminaire: tal et linguistique de corpus']
# id_prof ['Yoann_DUPONT', 'Santiago_HERRERA', 'Christophe_HUP']
# nom_prof ['DUPONT', 'HERRERA', 'HUP']
# prenom_prof ['Yoann', 'Santiago', 'Christophe']
# etablissement []
# annee []
# horaires []
# evaluation []
# list_eleves []
# on cherche le cours anglais pro dans la liste de cours :
# ['sociolinguistique']
# qui est rattachée à:
# COSTA COSTA
# On cherche le cours coreen
# on cherche le cours coreen dans la liste de cours :
# ['ppe1', 'ppe2', 'introduction a la fouille de textes']
# qui est rattachée à:
# DUPONT DUPONT
# on cherche le cours coreen dans la liste de cours :
# ["modelisation automatique pour l'analyse de textes", "annotations semantiques et applications en recherche d'information", 'ingenierie des connaissances', 'linguistique outillee et traitements statistiques']
# qui est rattachée à:
# BATTISTELLI BATTISTELLI
# on cherche le cours coreen dans la liste de cours :
# ['programmation et algorithmique 1', 'bases de donnees pour linguistes', 'enrichissement de corpus', 'de la modelisation au traitement automatique des donnees linguistiques', 'ingenierie des connaissances', 'langages du web semantique', 'seminaire: tal et linguistique de corpus']
# qui est rattachée à:
# ESHKOL-TARAVELLA ESHKOL-TARAVELLA
# on cherche le cours coreen dans la liste de cours :
# ['mathematiques pour le tal', 'apprentissage automatique', 'arbres graphes', 'interfaces pour le web']
# qui est rattachée à:
# GROBOL GROBOL
# on cherche le cours coreen dans la liste de cours :
# ['modelisation des langues']
# qui est rattachée à:
# KAHANE KAHANE
# on cherche le cours coreen dans la liste de cours :
# ['ppe1', 'ppe2']
# qui est rattachée à:
# MAGISTRY MAGISTRY
# on cherche le cours coreen dans la liste de cours :
# ['langages reguliers', 'statistiques textuelles', 'traitement statistique de corpus']
# qui est rattachée à:
# NOUVEL NOUVEL
# on cherche le cours coreen dans la liste de cours :
# ['gest. info multilinguisme', 'ecriture et multilinguisme']
# qui est rattachée à:
# WANG WANG
# on cherche le cours coreen dans la liste de cours :
# ['synthese de la parole', 'cnn', 'phonetique physiologique et acoustique']
# qui est rattachée à:
# GENDROT GENDROT
# on cherche le cours coreen dans la liste de cours :
# ['corpus arbores et parsing']
# qui est rattachée à:
# HERRERA HERRERA
# on cherche le cours coreen dans la liste de cours :
# ['recueil de données et statistiques']
# qui est rattachée à:
# WANG WANG
# on cherche le cours coreen dans la liste de cours :
# ['linguistique de la langue de signes']
# qui est rattachée à:
# BOGLIOTTI BOGLIOTTI
# on cherche le cours coreen dans la liste de cours :
# ['morphologie']
# qui est rattachée à:
# VILLEOING VILLEOING
# on cherche le cours coreen dans la liste de cours :
# ['nlp in english', 'langues vivantes etrangeres']
# qui est rattachée à:
# STRICKER STRICKER
# on cherche le cours coreen dans la liste de cours :
# ['programmation et algorithmique 2']
# qui est rattachée à:
# DEHOUCK DEHOUCK
# on cherche le cours coreen dans la liste de cours :
# ['document structure']
# qui est rattachée à:
# JACOBSON JACOBSON
# on cherche le cours coreen dans la liste de cours :
# ['outils de traitement de corpus']
# qui est rattachée à:
# SAUVAGE SAUVAGE
# on cherche le cours coreen dans la liste de cours :
# ['corpus paralleles et comparables']
# qui est rattachée à:
# ZWEIGENBAUM ZWEIGENBAUM
# on cherche le cours coreen dans la liste de cours :
# ['anglais de specialite']
# qui est rattachée à:
# KOSMALA KOSMALA
# on cherche le cours coreen dans la liste de cours :
# ['semantique lexicale et textuelle', 'genres textes et usages', 'semantique de textes multilangues']
# qui est rattachée à:
# VALETTE VALETTE
# on cherche le cours coreen dans la liste de cours :
# ['lexique et morphologie']
# qui est rattachée à:
# GABOR GABOR
# on cherche le cours coreen dans la liste de cours :
# ['pratiques textuelles et traduction', 'traductologie 1']
# qui est rattachée à:
# LICHAO LICHAO
# on cherche le cours coreen dans la liste de cours :
# ['programmation objet 2']
# qui est rattachée à:
# JACQUEMARD JACQUEMARD
# on cherche le cours coreen dans la liste de cours :
# ['langages de script (python inalco)']
# qui est rattachée à:
# ROULOIS ROULOIS
# on cherche le cours coreen dans la liste de cours :
# ["extraction d'informations"]
# qui est rattachée à:
# MONNIN-TUILLIER MONNIN-TUILLIER
# on cherche le cours coreen dans la liste de cours :
# ['semantique computationnelle']
# qui est rattachée à:
# AMSILI AMSILI
# on cherche le cours coreen dans la liste de cours :
# ['langages de script']
# qui est rattachée à:
# JOURDAIN JOURDAIN
# on cherche le cours coreen dans la liste de cours :
# ['acquisition modelisation/representation']
# qui est rattachée à:
# AOUINA AOUINA
# on cherche le cours coreen dans la liste de cours :
# ['programmation objet 1']
# qui est rattachée à:
# LECAILLIEZ LECAILLIEZ
# on cherche le cours coreen dans la liste de cours :
# ['langue des signes']
# qui est rattachée à:
# AKSEN AKSEN
# on cherche le cours coreen dans la liste de cours :
# ['conduite de projet de traduction 1']
# qui est rattachée à:
# GAUMET GAUMET
# on cherche le cours coreen dans la liste de cours :
# ['fouille de textes 1']
# qui est rattachée à:
# GROUIN GROUIN
# on cherche le cours coreen dans la liste de cours :
# ['outils de tao 1']
# qui est rattachée à:
# KUBIK KUBIK
# on cherche le cours coreen dans la liste de cours :
# ['traduction technique 1']
# qui est rattachée à:
# BONNAFOUS BONNAFOUS
# on cherche le cours coreen dans la liste de cours :
# ['documents structures']
# qui est rattachée à:
# ABROUGUI ABROUGUI
# on cherche le cours coreen dans la liste de cours :
# ['calculabilite']
# qui est rattachée à:
# PAROUBECK PAROUBECK
# on cherche le cours coreen dans la liste de cours :
# ['large corpus linguistics']
# qui est rattachée à:
# RAINERIE RAINERIE
# on cherche le cours coreen dans la liste de cours :
# ['traduction automatique et assistee']
# qui est rattachée à:
# SEMMAR SEMMAR
# on cherche le cours coreen dans la liste de cours :
# ['polonais']
# qui est rattachée à:
# LASON LASON
# on cherche le cours coreen dans la liste de cours :
# ['khmer']
# qui est rattachée à:
# NUT NUT
# on cherche le cours coreen dans la liste de cours :
# ['gestion de projets']
# qui est rattachée à:
# CARCENAC CARCENAC
# on cherche le cours coreen dans la liste de cours :
# ['coreen']
# qui est rattachée à:
# LEE LEE
# le cours coreen a été trouvé
# donc, found est égal à  True
# on a rempli le dico en conséquence
# nom_cours ['introduction a la fouille de textes', 'corpus arbores et parsing', 'anglais pro', 'coreen', 'document structure', 'conduite de projet de traduction 1', 'corpus paralleles et comparables', 'anglais', 'large corpus linguistics', 'polonais', 'de la modelisation au traitement automatique des donnees linguistiques', 'mathematiques pour le tal', 'genres textes et usages', 'modelisation des langues', 'pratiques textuelles et traduction', 'calculabilite', 'traduction technique 1', 'cnn', 'semantique computationnelle', 'programmation objet 1', 'ecriture et multilinguisme', 'ingenierie des connaissances', 'programmation et algorithmique 2', 'interfaces pour le web', 'synthese de la parole', 'statistiques textuelles', 'langages de script (jourdain)', 'programmation et algorithmique 1', 'semantique lexicale et textuelle', 'recueil de données et statistiques', 'outils de traitement de corpus', 'programmation objet 2', 'base de donnees pour linguistes', 'traitement statistique de corpus', 'langages de script (roulois)', 'traduction automatique et assistee', "annotations semantiques et applications en recherche d'information", 'ppe1', 'apprentissage automatique', 'phonetique physiologique et acoustique', 'sens multiple', 'Langages reguliers', 'nlp in english', 'langages reguliers', 'anglais de specialite 2', 'acquisition modelisation/representation', 'langages de scripts (python inalco)', 'enrichissement de corpus', 'lexicologie terminologie et dictionnairique', 'redaction professionnelle', 'khmer', 'langages du web semantique', 'methodologie de la recherche', 'gestion de projets', 'principes de bases de donnees', 'actualite dans le monde anglophone', 'traductologie 1', 'langue des signes', "modelisation automatique pour l'analyse de textes", 'morphologie', 'gest. info multilinguisme', 'semantique des textes multilingues 1', 'langues vivantes etrangeres', 'fouille de textes 1', 'document structures', 'ppe2', 'mooc', 'linguistique outillee et traitements statistiques', 'linguistique de la lsf', 'lexique et morphologie', 'sociolinguistique', 'recueil de donnees et statistiques', 'changements linguistiques', 'arbres graphes', 'outils de tao 1', "extraction d'informations", 'seminaire: tal et linguistique de corpus']
# id_prof ['Yoann_DUPONT', 'Santiago_HERRERA', 'Christophe_HUP', 'Kyung_LEE']
# nom_prof ['DUPONT', 'HERRERA', 'HUP', 'LEE']
# prenom_prof ['Yoann', 'Santiago', 'Christophe', 'Kyung']
# etablissement []
# annee []
# horaires []
# evaluation []
# list_eleves []
# on cherche le cours coreen dans la liste de cours :
# ['anglais pro']
# qui est rattachée à:
# HUP HUP
# on cherche le cours coreen dans la liste de cours :
# ['sociolinguistique']
# qui est rattachée à:
# COSTA COSTA
# On cherche le cours document structure
# on cherche le cours document structure dans la liste de cours :
# ['ppe1', 'ppe2', 'introduction a la fouille de textes']
# qui est rattachée à:
# DUPONT DUPONT
# on cherche le cours document structure dans la liste de cours :
# ["modelisation automatique pour l'analyse de textes", "annotations semantiques et applications en recherche d'information", 'ingenierie des connaissances', 'linguistique outillee et traitements statistiques']
# qui est rattachée à:
# BATTISTELLI BATTISTELLI
# on cherche le cours document structure dans la liste de cours :
# ['programmation et algorithmique 1', 'bases de donnees pour linguistes', 'enrichissement de corpus', 'de la modelisation au traitement automatique des donnees linguistiques', 'ingenierie des connaissances', 'langages du web semantique', 'seminaire: tal et linguistique de corpus']
# qui est rattachée à:
# ESHKOL-TARAVELLA ESHKOL-TARAVELLA
# on cherche le cours document structure dans la liste de cours :
# ['mathematiques pour le tal', 'apprentissage automatique', 'arbres graphes', 'interfaces pour le web']
# qui est rattachée à:
# GROBOL GROBOL
# on cherche le cours document structure dans la liste de cours :
# ['modelisation des langues']
# qui est rattachée à:
# KAHANE KAHANE
# on cherche le cours document structure dans la liste de cours :
# ['ppe1', 'ppe2']
# qui est rattachée à:
# MAGISTRY MAGISTRY
# on cherche le cours document structure dans la liste de cours :
# ['langages reguliers', 'statistiques textuelles', 'traitement statistique de corpus']
# qui est rattachée à:
# NOUVEL NOUVEL
# on cherche le cours document structure dans la liste de cours :
# ['gest. info multilinguisme', 'ecriture et multilinguisme']
# qui est rattachée à:
# WANG WANG
# on cherche le cours document structure dans la liste de cours :
# ['synthese de la parole', 'cnn', 'phonetique physiologique et acoustique']
# qui est rattachée à:
# GENDROT GENDROT
# on cherche le cours document structure dans la liste de cours :
# ['corpus arbores et parsing']
# qui est rattachée à:
# HERRERA HERRERA
# on cherche le cours document structure dans la liste de cours :
# ['recueil de données et statistiques']
# qui est rattachée à:
# WANG WANG
# on cherche le cours document structure dans la liste de cours :
# ['linguistique de la langue de signes']
# qui est rattachée à:
# BOGLIOTTI BOGLIOTTI
# on cherche le cours document structure dans la liste de cours :
# ['morphologie']
# qui est rattachée à:
# VILLEOING VILLEOING
# on cherche le cours document structure dans la liste de cours :
# ['nlp in english', 'langues vivantes etrangeres']
# qui est rattachée à:
# STRICKER STRICKER
# on cherche le cours document structure dans la liste de cours :
# ['programmation et algorithmique 2']
# qui est rattachée à:
# DEHOUCK DEHOUCK
# on cherche le cours document structure dans la liste de cours :
# ['document structure']
# qui est rattachée à:
# JACOBSON JACOBSON
# le cours document structure a été trouvé
# donc, found est égal à  True
# on a rempli le dico en conséquence
# nom_cours ['introduction a la fouille de textes', 'corpus arbores et parsing', 'anglais pro', 'coreen', 'document structure', 'conduite de projet de traduction 1', 'corpus paralleles et comparables', 'anglais', 'large corpus linguistics', 'polonais', 'de la modelisation au traitement automatique des donnees linguistiques', 'mathematiques pour le tal', 'genres textes et usages', 'modelisation des langues', 'pratiques textuelles et traduction', 'calculabilite', 'traduction technique 1', 'cnn', 'semantique computationnelle', 'programmation objet 1', 'ecriture et multilinguisme', 'ingenierie des connaissances', 'programmation et algorithmique 2', 'interfaces pour le web', 'synthese de la parole', 'statistiques textuelles', 'langages de script (jourdain)', 'programmation et algorithmique 1', 'semantique lexicale et textuelle', 'recueil de données et statistiques', 'outils de traitement de corpus', 'programmation objet 2', 'base de donnees pour linguistes', 'traitement statistique de corpus', 'langages de script (roulois)', 'traduction automatique et assistee', "annotations semantiques et applications en recherche d'information", 'ppe1', 'apprentissage automatique', 'phonetique physiologique et acoustique', 'sens multiple', 'Langages reguliers', 'nlp in english', 'langages reguliers', 'anglais de specialite 2', 'acquisition modelisation/representation', 'langages de scripts (python inalco)', 'enrichissement de corpus', 'lexicologie terminologie et dictionnairique', 'redaction professionnelle', 'khmer', 'langages du web semantique', 'methodologie de la recherche', 'gestion de projets', 'principes de bases de donnees', 'actualite dans le monde anglophone', 'traductologie 1', 'langue des signes', "modelisation automatique pour l'analyse de textes", 'morphologie', 'gest. info multilinguisme', 'semantique des textes multilingues 1', 'langues vivantes etrangeres', 'fouille de textes 1', 'document structures', 'ppe2', 'mooc', 'linguistique outillee et traitements statistiques', 'linguistique de la lsf', 'lexique et morphologie', 'sociolinguistique', 'recueil de donnees et statistiques', 'changements linguistiques', 'arbres graphes', 'outils de tao 1', "extraction d'informations", 'seminaire: tal et linguistique de corpus']
# id_prof ['Yoann_DUPONT', 'Santiago_HERRERA', 'Christophe_HUP', 'Kyung_LEE', 'Michel_JACOBSON']
# nom_prof ['DUPONT', 'HERRERA', 'HUP', 'LEE', 'JACOBSON']
# prenom_prof ['Yoann', 'Santiago', 'Christophe', 'Kyung', 'Michel']
# etablissement []
# annee []
# horaires []
# evaluation []
# list_eleves []
# on cherche le cours document structure dans la liste de cours :
# ['outils de traitement de corpus']
# qui est rattachée à:
# SAUVAGE SAUVAGE
# on cherche le cours document structure dans la liste de cours :
# ['corpus paralleles et comparables']
# qui est rattachée à:
# ZWEIGENBAUM ZWEIGENBAUM
# on cherche le cours document structure dans la liste de cours :
# ['anglais de specialite']
# qui est rattachée à:
# KOSMALA KOSMALA
# on cherche le cours document structure dans la liste de cours :
# ['semantique lexicale et textuelle', 'genres textes et usages', 'semantique de textes multilangues']
# qui est rattachée à:
# VALETTE VALETTE
# on cherche le cours document structure dans la liste de cours :
# ['lexique et morphologie']
# qui est rattachée à:
# GABOR GABOR
# on cherche le cours document structure dans la liste de cours :
# ['pratiques textuelles et traduction', 'traductologie 1']
# qui est rattachée à:
# LICHAO LICHAO
# on cherche le cours document structure dans la liste de cours :
# ['programmation objet 2']
# qui est rattachée à:
# JACQUEMARD JACQUEMARD
# on cherche le cours document structure dans la liste de cours :
# ['langages de script (python inalco)']
# qui est rattachée à:
# ROULOIS ROULOIS
# on cherche le cours document structure dans la liste de cours :
# ["extraction d'informations"]
# qui est rattachée à:
# MONNIN-TUILLIER MONNIN-TUILLIER
# on cherche le cours document structure dans la liste de cours :
# ['semantique computationnelle']
# qui est rattachée à:
# AMSILI AMSILI
# on cherche le cours document structure dans la liste de cours :
# ['langages de script']
# qui est rattachée à:
# JOURDAIN JOURDAIN
# on cherche le cours document structure dans la liste de cours :
# ['acquisition modelisation/representation']
# qui est rattachée à:
# AOUINA AOUINA
# on cherche le cours document structure dans la liste de cours :
# ['programmation objet 1']
# qui est rattachée à:
# LECAILLIEZ LECAILLIEZ
# on cherche le cours document structure dans la liste de cours :
# ['langue des signes']
# qui est rattachée à:
# AKSEN AKSEN
# on cherche le cours document structure dans la liste de cours :
# ['conduite de projet de traduction 1']
# qui est rattachée à:
# GAUMET GAUMET
# on cherche le cours document structure dans la liste de cours :
# ['fouille de textes 1']
# qui est rattachée à:
# GROUIN GROUIN
# on cherche le cours document structure dans la liste de cours :
# ['outils de tao 1']
# qui est rattachée à:
# KUBIK KUBIK
# on cherche le cours document structure dans la liste de cours :
# ['traduction technique 1']
# qui est rattachée à:
# BONNAFOUS BONNAFOUS
# on cherche le cours document structure dans la liste de cours :
# ['documents structures']
# qui est rattachée à:
# ABROUGUI ABROUGUI
# on cherche le cours document structure dans la liste de cours :
# ['calculabilite']
# qui est rattachée à:
# PAROUBECK PAROUBECK
# on cherche le cours document structure dans la liste de cours :
# ['large corpus linguistics']
# qui est rattachée à:
# RAINERIE RAINERIE
# on cherche le cours document structure dans la liste de cours :
# ['traduction automatique et assistee']
# qui est rattachée à:
# SEMMAR SEMMAR
# on cherche le cours document structure dans la liste de cours :
# ['polonais']
# qui est rattachée à:
# LASON LASON
# on cherche le cours document structure dans la liste de cours :
# ['khmer']
# qui est rattachée à:
# NUT NUT
# on cherche le cours document structure dans la liste de cours :
# ['gestion de projets']
# qui est rattachée à:
# CARCENAC CARCENAC
# on cherche le cours document structure dans la liste de cours :
# ['coreen']
# qui est rattachée à:
# LEE LEE
# on cherche le cours document structure dans la liste de cours :
# ['anglais pro']
# qui est rattachée à:
# HUP HUP
# on cherche le cours document structure dans la liste de cours :
# ['sociolinguistique']
# qui est rattachée à:
# COSTA COSTA
# On cherche le cours conduite de projet de traduction 1
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['ppe1', 'ppe2', 'introduction a la fouille de textes']
# qui est rattachée à:
# DUPONT DUPONT
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ["modelisation automatique pour l'analyse de textes", "annotations semantiques et applications en recherche d'information", 'ingenierie des connaissances', 'linguistique outillee et traitements statistiques']
# qui est rattachée à:
# BATTISTELLI BATTISTELLI
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['programmation et algorithmique 1', 'bases de donnees pour linguistes', 'enrichissement de corpus', 'de la modelisation au traitement automatique des donnees linguistiques', 'ingenierie des connaissances', 'langages du web semantique', 'seminaire: tal et linguistique de corpus']
# qui est rattachée à:
# ESHKOL-TARAVELLA ESHKOL-TARAVELLA
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['mathematiques pour le tal', 'apprentissage automatique', 'arbres graphes', 'interfaces pour le web']
# qui est rattachée à:
# GROBOL GROBOL
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['modelisation des langues']
# qui est rattachée à:
# KAHANE KAHANE
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['ppe1', 'ppe2']
# qui est rattachée à:
# MAGISTRY MAGISTRY
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['langages reguliers', 'statistiques textuelles', 'traitement statistique de corpus']
# qui est rattachée à:
# NOUVEL NOUVEL
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['gest. info multilinguisme', 'ecriture et multilinguisme']
# qui est rattachée à:
# WANG WANG
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['synthese de la parole', 'cnn', 'phonetique physiologique et acoustique']
# qui est rattachée à:
# GENDROT GENDROT
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['corpus arbores et parsing']
# qui est rattachée à:
# HERRERA HERRERA
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['recueil de données et statistiques']
# qui est rattachée à:
# WANG WANG
# on cherche le cours conduite de projet de traduction 1 dans la liste de cours :
# ['linguistique de la langue de signes']
# qui est rattachée à:
# ...
# id_prof ['Yoann_DUPONT', 'Santiago_HERRERA', 'Christophe_HUP', 'Kyung_LEE', 'Michel_JACOBSON', 'Sophie_GAUMET', 'Pierre_ZWEIGENBAUM', '', 'Sophie_RAINERIE', 'Natalia_LASON', 'Iris_ESHKOL-TARAVELLA', 'Loïc_GROBOL', 'Mathieu_VALETTE', 'Sylvain_KAHANE', 'Zhu_LICHAO', 'Patrick_PAROUBECK', 'Marie-Paule_BONNAFOUS', 'Cedric_GENDROT', 'Pascal_AMSILI', 'Louis_LECAILLIEZ', 'Ilaine_WANG', 'Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Loïc_GROBOL', 'Cedric_GENDROT', 'Damien_NOUVEL', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_VALETTE', 'Xibin_WANG', 'Eve_SAUVAGE', 'Florent_JACQUEMARD', '', 'Damien_NOUVEL', '', 'Nasredine_SEMMAR', 'Delphine_BATTISTELLI', 'Yoann_DUPONT', 'Pierre_MAGISTRY', 'Loïc_GROBOL', 'Cedric_GENDROT', '', '', 'Armand_STRICKER', 'Damien_NOUVEL', '', 'Ons_AOUINA', '', 'Iris_ESHKOL-TARAVELLA', '', '', 'Suppya_NUT', 'Iris_ESHKOL-TARAVELLA', '', 'Benoît_CARCENAC', '', '', 'Zhu_LICHAO', 'Hatice_AKSEN', 'Delphine_BATTISTELLI', 'Florence_VILLEOING', 'Ilaine_WANG', '', 'Armand_STRICKER', 'Cyril_GROUIN', '', 'Yoann_DUPONT', 'Pierre_MAGISTRY', '', 'Delphine_BATTISTELLI', '', 'Kata_GABOR', 'James_COSTA', '', '', 'Loïc_GROBOL', 'Karolina_KUBIK', 'Chloé_MONNIN-TUILLIER', 'Iris_ESHKOL-TARAVELLA']
# nom_prof ['DUPONT', 'HERRERA', 'HUP', 'LEE', 'JACOBSON', 'GAUMET', 'ZWEIGENBAUM', '', 'RAINERIE', 'LASON', 'ESHKOL-TARAVELLA', 'GROBOL', 'VALETTE', 'KAHANE', 'LICHAO', 'PAROUBECK', 'BONNAFOUS', 'GENDROT', 'AMSILI', 'LECAILLIEZ', 'WANG', 'BATTISTELLI', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'GROBOL', 'GENDROT', 'NOUVEL', '', 'ESHKOL-TARAVELLA', 'VALETTE', 'WANG', 'SAUVAGE', 'JACQUEMARD', '', 'NOUVEL', '', 'SEMMAR', 'BATTISTELLI', 'DUPONT', 'MAGISTRY', 'GROBOL', 'GENDROT', '', '', 'STRICKER', 'NOUVEL', '', 'AOUINA', '', 'ESHKOL-TARAVELLA', '', '', 'NUT', 'ESHKOL-TARAVELLA', '', 'CARCENAC', '', '', 'LICHAO', 'AKSEN', 'BATTISTELLI', 'VILLEOING', 'WANG', '', 'STRICKER', 'GROUIN', '', 'DUPONT', 'MAGISTRY', '', 'BATTISTELLI', '', 'GABOR', 'COSTA', '', '', 'GROBOL', 'KUBIK', 'MONNIN-TUILLIER', 'ESHKOL-TARAVELLA']
# prenom_prof ['Yoann', 'Santiago', 'Christophe', 'Kyung', 'Michel', 'Sophie', 'Pierre', '', 'Sophie', 'Natalia', 'Iris', 'Loïc', 'Mathieu', 'Sylvain', 'Zhu', 'Patrick', 'Marie-Paule', 'Cedric', 'Pascal', 'Louis', 'Ilaine', 'Delphine', 'Iris', 'Mathieu', 'Loïc', 'Cedric', 'Damien', '', 'Iris', 'Mathieu', 'Xibin', 'Eve', 'Florent', '', 'Damien', '', 'Nasredine', 'Delphine', 'Yoann', 'Pierre', 'Loïc', 'Cedric', '', '', 'Armand', 'Damien', '', 'Ons', '', 'Iris', '', '', 'Suppya', 'Iris', '', 'Benoît', '', '', 'Zhu', 'Hatice', 'Delphine', 'Florence', 'Ilaine', '', 'Armand', 'Cyril', '', 'Yoann', 'Pierre', '', 'Delphine', '', 'Kata', 'James', '', '', 'Loïc', 'Karolina', 'Chloé', 'Iris']
# etablissement []
# annee []
# horaires []
# evaluation []
# list_eleves []
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['mathematiques pour le tal', 'apprentissage automatique', 'arbres graphes', 'interfaces pour le web']
# qui est rattachée à:
# GROBOL GROBOL
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['modelisation des langues']
# qui est rattachée à:
# KAHANE KAHANE
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['ppe1', 'ppe2']
# qui est rattachée à:
# MAGISTRY MAGISTRY
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['langages reguliers', 'statistiques textuelles', 'traitement statistique de corpus']
# qui est rattachée à:
# NOUVEL NOUVEL
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['gest. info multilinguisme', 'ecriture et multilinguisme']
# qui est rattachée à:
# WANG WANG
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['synthese de la parole', 'cnn', 'phonetique physiologique et acoustique']
# qui est rattachée à:
# GENDROT GENDROT
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['corpus arbores et parsing']
# qui est rattachée à:
# HERRERA HERRERA
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['recueil de données et statistiques']
# qui est rattachée à:
# WANG WANG
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['linguistique de la langue de signes']
# qui est rattachée à:
# BOGLIOTTI BOGLIOTTI
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['morphologie']
# qui est rattachée à:
# VILLEOING VILLEOING
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['nlp in english', 'langues vivantes etrangeres']
# qui est rattachée à:
# STRICKER STRICKER
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['programmation et algorithmique 2']
# qui est rattachée à:
# DEHOUCK DEHOUCK
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['document structure']
# qui est rattachée à:
# JACOBSON JACOBSON
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['outils de traitement de corpus']
# qui est rattachée à:
# SAUVAGE SAUVAGE
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['corpus paralleles et comparables']
# qui est rattachée à:
# ZWEIGENBAUM ZWEIGENBAUM
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['anglais de specialite']
# qui est rattachée à:
# KOSMALA KOSMALA
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['semantique lexicale et textuelle', 'genres textes et usages', 'semantique de textes multilangues']
# qui est rattachée à:
# VALETTE VALETTE
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['lexique et morphologie']
# qui est rattachée à:
# GABOR GABOR
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['pratiques textuelles et traduction', 'traductologie 1']
# qui est rattachée à:
# LICHAO LICHAO
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['programmation objet 2']
# qui est rattachée à:
# JACQUEMARD JACQUEMARD
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['langages de script (python inalco)']
# qui est rattachée à:
# ROULOIS ROULOIS
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ["extraction d'informations"]
# qui est rattachée à:
# MONNIN-TUILLIER MONNIN-TUILLIER
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['semantique computationnelle']
# qui est rattachée à:
# AMSILI AMSILI
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['langages de script']
# qui est rattachée à:
# JOURDAIN JOURDAIN
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['acquisition modelisation/representation']
# qui est rattachée à:
# AOUINA AOUINA
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['programmation objet 1']
# qui est rattachée à:
# LECAILLIEZ LECAILLIEZ
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['langue des signes']
# qui est rattachée à:
# AKSEN AKSEN
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['conduite de projet de traduction 1']
# qui est rattachée à:
# GAUMET GAUMET
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['fouille de textes 1']
# qui est rattachée à:
# GROUIN GROUIN
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['outils de tao 1']
# qui est rattachée à:
# KUBIK KUBIK
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['traduction technique 1']
# qui est rattachée à:
# BONNAFOUS BONNAFOUS
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['documents structures']
# qui est rattachée à:
# ABROUGUI ABROUGUI
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['calculabilite']
# qui est rattachée à:
# PAROUBECK PAROUBECK
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['large corpus linguistics']
# qui est rattachée à:
# RAINERIE RAINERIE
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['traduction automatique et assistee']
# qui est rattachée à:
# SEMMAR SEMMAR
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['polonais']
# qui est rattachée à:
# LASON LASON
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['khmer']
# qui est rattachée à:
# NUT NUT
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['gestion de projets']
# qui est rattachée à:
# CARCENAC CARCENAC
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['coreen']
# qui est rattachée à:
# LEE LEE
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['anglais pro']
# qui est rattachée à:
# HUP HUP
# on cherche le cours seminaire: tal et linguistique de corpus dans la liste de cours :
# ['sociolinguistique']
# qui est rattachée à:
# COSTA COSTA
# nom_cours:['introduction a la fouille de textes', 'corpus arbores et parsing', 'anglais pro', 'coreen', 'document structure', 'conduite de projet de traduction 1', 'corpus paralleles et comparables', 'anglais', 'large corpus linguistics', 'polonais', 'de la modelisation au traitement automatique des donnees linguistiques', 'mathematiques pour le tal', 'genres textes et usages', 'modelisation des langues', 'pratiques textuelles et traduction', 'calculabilite', 'traduction technique 1', 'cnn', 'semantique computationnelle', 'programmation objet 1', 'ecriture et multilinguisme', 'ingenierie des connaissances', 'programmation et algorithmique 2', 'interfaces pour le web', 'synthese de la parole', 'statistiques textuelles', 'langages de script (jourdain)', 'programmation et algorithmique 1', 'semantique lexicale et textuelle', 'recueil de données et statistiques', 'outils de traitement de corpus', 'programmation objet 2', 'base de donnees pour linguistes', 'traitement statistique de corpus', 'langages de script (roulois)', 'traduction automatique et assistee', "annotations semantiques et applications en recherche d'information", 'ppe1', 'apprentissage automatique', 'phonetique physiologique et acoustique', 'sens multiple', 'Langages reguliers', 'nlp in english', 'langages reguliers', 'anglais de specialite 2', 'acquisition modelisation/representation', 'langages de scripts (python inalco)', 'enrichissement de corpus', 'lexicologie terminologie et dictionnairique', 'redaction professionnelle', 'khmer', 'langages du web semantique', 'methodologie de la recherche', 'gestion de projets', 'principes de bases de donnees', 'actualite dans le monde anglophone', 'traductologie 1', 'langue des signes', "modelisation automatique pour l'analyse de textes", 'morphologie', 'gest. info multilinguisme', 'semantique des textes multilingues 1', 'langues vivantes etrangeres', 'fouille de textes 1', 'document structures', 'ppe2', 'mooc', 'linguistique outillee et traitements statistiques', 'linguistique de la lsf', 'lexique et morphologie', 'sociolinguistique', 'recueil de donnees et statistiques', 'changements linguistiques', 'arbres graphes', 'outils de tao 1', "extraction d'informations", 'seminaire: tal et linguistique de corpus']
# id_prof:['Yoann_DUPONT', 'Santiago_HERRERA', 'Christophe_HUP', 'Kyung_LEE', 'Michel_JACOBSON', 'Sophie_GAUMET', 'Pierre_ZWEIGENBAUM', '', 'Sophie_RAINERIE', 'Natalia_LASON', 'Iris_ESHKOL-TARAVELLA', 'Loïc_GROBOL', 'Mathieu_VALETTE', 'Sylvain_KAHANE', 'Zhu_LICHAO', 'Patrick_PAROUBECK', 'Marie-Paule_BONNAFOUS', 'Cedric_GENDROT', 'Pascal_AMSILI', 'Louis_LECAILLIEZ', 'Ilaine_WANG', 'Delphine_BATTISTELLI', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_DEHOUCK', 'Loïc_GROBOL', 'Cedric_GENDROT', 'Damien_NOUVEL', '', 'Iris_ESHKOL-TARAVELLA', 'Mathieu_VALETTE', 'Xibin_WANG', 'Eve_SAUVAGE', 'Florent_JACQUEMARD', '', 'Damien_NOUVEL', '', 'Nasredine_SEMMAR', 'Delphine_BATTISTELLI', 'Yoann_DUPONT', 'Pierre_MAGISTRY', 'Loïc_GROBOL', 'Cedric_GENDROT', '', '', 'Armand_STRICKER', 'Damien_NOUVEL', '', 'Ons_AOUINA', '', 'Iris_ESHKOL-TARAVELLA', '', '', 'Suppya_NUT', 'Iris_ESHKOL-TARAVELLA', '', 'Benoît_CARCENAC', '', '', 'Zhu_LICHAO', 'Hatice_AKSEN', 'Delphine_BATTISTELLI', 'Florence_VILLEOING', 'Ilaine_WANG', '', 'Armand_STRICKER', 'Cyril_GROUIN', '', 'Yoann_DUPONT', 'Pierre_MAGISTRY', '', 'Delphine_BATTISTELLI', '', 'Kata_GABOR', 'James_COSTA', '', '', 'Loïc_GROBOL', 'Karolina_KUBIK', 'Chloé_MONNIN-TUILLIER', 'Iris_ESHKOL-TARAVELLA']
# nom_prof:['DUPONT', 'HERRERA', 'HUP', 'LEE', 'JACOBSON', 'GAUMET', 'ZWEIGENBAUM', '', 'RAINERIE', 'LASON', 'ESHKOL-TARAVELLA', 'GROBOL', 'VALETTE', 'KAHANE', 'LICHAO', 'PAROUBECK', 'BONNAFOUS', 'GENDROT', 'AMSILI', 'LECAILLIEZ', 'WANG', 'BATTISTELLI', 'ESHKOL-TARAVELLA', 'DEHOUCK', 'GROBOL', 'GENDROT', 'NOUVEL', '', 'ESHKOL-TARAVELLA', 'VALETTE', 'WANG', 'SAUVAGE', 'JACQUEMARD', '', 'NOUVEL', '', 'SEMMAR', 'BATTISTELLI', 'DUPONT', 'MAGISTRY', 'GROBOL', 'GENDROT', '', '', 'STRICKER', 'NOUVEL', '', 'AOUINA', '', 'ESHKOL-TARAVELLA', '', '', 'NUT', 'ESHKOL-TARAVELLA', '', 'CARCENAC', '', '', 'LICHAO', 'AKSEN', 'BATTISTELLI', 'VILLEOING', 'WANG', '', 'STRICKER', 'GROUIN', '', 'DUPONT', 'MAGISTRY', '', 'BATTISTELLI', '', 'GABOR', 'COSTA', '', '', 'GROBOL', 'KUBIK', 'MONNIN-TUILLIER', 'ESHKOL-TARAVELLA']
# prenom_prof:['Yoann', 'Santiago', 'Christophe', 'Kyung', 'Michel', 'Sophie', 'Pierre', '', 'Sophie', 'Natalia', 'Iris', 'Loïc', 'Mathieu', 'Sylvain', 'Zhu', 'Patrick', 'Marie-Paule', 'Cedric', 'Pascal', 'Louis', 'Ilaine', 'Delphine', 'Iris', 'Mathieu', 'Loïc', 'Cedric', 'Damien', '', 'Iris', 'Mathieu', 'Xibin', 'Eve', 'Florent', '', 'Damien', '', 'Nasredine', 'Delphine', 'Yoann', 'Pierre', 'Loïc', 'Cedric', '', '', 'Armand', 'Damien', '', 'Ons', '', 'Iris', '', '', 'Suppya', 'Iris', '', 'Benoît', '', '', 'Zhu', 'Hatice', 'Delphine', 'Florence', 'Ilaine', '', 'Armand', 'Cyril', '', 'Yoann', 'Pierre', '', 'Delphine', '', 'Kata', 'James', '', '', 'Loïc', 'Karolina', 'Chloé', 'Iris']
# etablissement:[]
# annee:[]
# horaires:[]
# evaluation:[]
# list_eleves:[]

# %%
cours = dico_cours["nom_cours"]
profs_noms = dico_cours["nom_prof"]
profs_prenoms = dico_cours["prenom_prof"]
id_profs = dico_cours["id_prof"]

for cour, nom, prenom, id_p in zip(cours, profs_noms, profs_prenoms, id_profs):
    print(cour, nom, prenom, id_p)
# Out:
# introduction a la fouille de textes DUPONT Yoann Yoann_DUPONT
# corpus arbores et parsing HERRERA Santiago Santiago_HERRERA
# anglais pro HUP Christophe Christophe_HUP
# coreen LEE Kyung Kyung_LEE
# document structure JACOBSON Michel Michel_JACOBSON
# conduite de projet de traduction 1 GAUMET Sophie Sophie_GAUMET
# corpus paralleles et comparables ZWEIGENBAUM Pierre Pierre_ZWEIGENBAUM
# anglais
# large corpus linguistics RAINERIE Sophie Sophie_RAINERIE
# polonais LASON Natalia Natalia_LASON
# de la modelisation au traitement automatique des donnees linguistiques ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# mathematiques pour le tal GROBOL Loïc Loïc_GROBOL
# genres textes et usages VALETTE Mathieu Mathieu_VALETTE
# modelisation des langues KAHANE Sylvain Sylvain_KAHANE
# pratiques textuelles et traduction LICHAO Zhu Zhu_LICHAO
# calculabilite PAROUBECK Patrick Patrick_PAROUBECK
# traduction technique 1 BONNAFOUS Marie-Paule Marie-Paule_BONNAFOUS
# cnn GENDROT Cedric Cedric_GENDROT
# semantique computationnelle AMSILI Pascal Pascal_AMSILI
# programmation objet 1 LECAILLIEZ Louis Louis_LECAILLIEZ
# ecriture et multilinguisme WANG Ilaine Ilaine_WANG
# ingenierie des connaissances BATTISTELLI Delphine Delphine_BATTISTELLI
# programmation et algorithmique 2 ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# interfaces pour le web DEHOUCK Mathieu Mathieu_DEHOUCK
# synthese de la parole GROBOL Loïc Loïc_GROBOL
# statistiques textuelles GENDROT Cedric Cedric_GENDROT
# langages de script (jourdain) NOUVEL Damien Damien_NOUVEL
# programmation et algorithmique 1
# semantique lexicale et textuelle ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# recueil de données et statistiques VALETTE Mathieu Mathieu_VALETTE
# outils de traitement de corpus WANG Xibin Xibin_WANG
# programmation objet 2 SAUVAGE Eve Eve_SAUVAGE
# base de donnees pour linguistes JACQUEMARD Florent Florent_JACQUEMARD
# traitement statistique de corpus
# langages de script (roulois) NOUVEL Damien Damien_NOUVEL
# traduction automatique et assistee
# annotations semantiques et applications en recherche d'information SEMMAR Nasredine Nasredine_SEMMAR
# ppe1 BATTISTELLI Delphine Delphine_BATTISTELLI
# apprentissage automatique DUPONT Yoann Yoann_DUPONT
# phonetique physiologique et acoustique MAGISTRY Pierre Pierre_MAGISTRY
# sens multiple GROBOL Loïc Loïc_GROBOL
# Langages reguliers GENDROT Cedric Cedric_GENDROT
# nlp in english
# langages reguliers
# anglais de specialite 2 STRICKER Armand Armand_STRICKER
# acquisition modelisation/representation NOUVEL Damien Damien_NOUVEL
# langages de scripts (python inalco)
# enrichissement de corpus AOUINA Ons Ons_AOUINA
# lexicologie terminologie et dictionnairique
# redaction professionnelle ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# khmer
# langages du web semantique
# methodologie de la recherche NUT Suppya Suppya_NUT
# gestion de projets ESHKOL-TARAVELLA Iris Iris_ESHKOL-TARAVELLA
# principes de bases de donnees
# actualite dans le monde anglophone CARCENAC Benoît Benoît_CARCENAC
# traductologie 1
# langue des signes
# modelisation automatique pour l'analyse de textes LICHAO Zhu Zhu_LICHAO
# morphologie AKSEN Hatice Hatice_AKSEN
# gest. info multilinguisme BATTISTELLI Delphine Delphine_BATTISTELLI
# semantique des textes multilingues 1 VILLEOING Florence Florence_VILLEOING
# langues vivantes etrangeres WANG Ilaine Ilaine_WANG
# fouille de textes 1
# document structures STRICKER Armand Armand_STRICKER
# ppe2 GROUIN Cyril Cyril_GROUIN
# mooc
# linguistique outillee et traitements statistiques DUPONT Yoann Yoann_DUPONT
# linguistique de la lsf MAGISTRY Pierre Pierre_MAGISTRY
# lexique et morphologie
# sociolinguistique BATTISTELLI Delphine Delphine_BATTISTELLI
# recueil de donnees et statistiques
# changements linguistiques GABOR Kata Kata_GABOR
# arbres graphes COSTA James James_COSTA
# outils de tao 1
# extraction d'informations
# seminaire: tal et linguistique de corpus GROBOL Loïc Loïc_GROBOL

# %%
prof = {"nom_prof": ["DUPONT", "BATTISTELLI", "ESHKOL-TARAVELLA", "GROBOL", "KAHANE", "MAGISTRY", "NOUVEL", "WANG", "GENDROT", "HERRERA", "WANG", "BOGLIOTTI", "VILLEOING", "STRICKER", "DEHOUCK", "JACOBSON", "SAUVAGE", "ZWEIGENBAUM", "KOSMALA" , "VALETTE", "GABOR", "LICHAO", "JACQUEMARD", "ROULOIS", "MONNIN-TUILLIER", "AMSILI", "JOURDAIN", "AOUINA", "LECAILLIEZ", "AKSEN", "GAUMET", "GROUIN", "KUBIK", "BONNAFOUS", "ABROUGUI", "PAROUBECK"],
        "prenom_prof": ["Yoann", "Delphine", "Iris", "Loïc", "Sylvain", "Pierre", "Damien", "Ilaine", "Cedric", "Santiago", "Xibin", "Caroline", "Florence", "Armand", "Mathieu", "Michel", "Eve", "Pierre", "Loulou", "Mathieu", "Kata", "Zhu","Florent", "Alexandre", "Chloé", "Pascal", "Louis", "Ons","Louis", "Hatice", "Sophie", "Cyril", "Karolina", "Marie-Paule", "Rim", "Patrick"],
        "etablissement": ["SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Nanterre", "Nanterre", "Nanterre", "Nanterre", "Inalco", "SorbonneNouvelle", "SorbonneNouvelle", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco","Inalco", "Inalco", "Inalco", "SorbonneNouvelle", "Inalco", "Inalco", "Inalco", "Nanterre", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco", "Inalco"],
		"genre" : [],
		"cours": [[],],
        "directeur_memoire_de" : [],}


# Faire un Id avec Lastname + Firstname

# %%
dico_stage = {"nom_stage": [],
              "nom_etudiant": [],
              "type_organisme": [],
              "nom_organisme": [],
              "duree": [],
              "sujet": [],
              "tuteur": [],
              "note": [],
              "type_contrat": [],
              }

# %%
dico_parcours = {"nom_parcours": ["M1_Nanterre_23-24", "M1_Inalco_23-24", "M1_Sorbonne_23-24", "M2_RD_Nanterre_24-25", "M2_RD_Inalco_24-25", "M2_RD_Sorbonne_24-25", "M2_Alterance_24-25", "M2_IM_24-25", "M2_TetraDom_24-25"],
                 "etablissement": ["Nanterre", "Inalco", "SorbonneNouvelle", "Nanterre", "Inalco", "SorbonneNouvelle", "Nanterre", "Inalco", "Inalco"],
                 "liste_eleves" : [[]],
                 "annee" : ["2023-2024", "2023-2024", "2023-2024", "2024-2025", "2024-2025", "2024-2025", "2024-2025", "2024-2025", "2024-2025"],}
